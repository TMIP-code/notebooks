# %% [markdown]
# # ACCESS-MOPPeR Getting Started
#
# Welcome to the ACCESS-MOPPeR Getting Started guide!
#
# This notebook will walk you through the initial setup and basic usage of ACCESS-MOPPeR, a tool designed to post-process ACCESS model output and produce CMIP-compliant datasets. You’ll learn how to configure your environment, prepare your data, and run the CMORisation workflow using both the Python API and Dask for scalable processing.
#
# By following this guide, you’ll be able to:
# - Set up your user configuration
# - Select input data files
# - Run the CMORisation process for selected variables
# - Inspect and save the processed output

# %% [markdown]
# ## Set up configuration
#
# When you first import `access_mopper` in a Python environment, the package will automatically create a `user.yml` file in your home directory (`~/.mopper/user.yml`).
#
# During this initial setup, you will be prompted to provide some basic information, including:
# - Your name
# - Your email address
# - Your work organization
# - Your ORCID
#
# This information is stored in `user.yml` and will be used as global attributes in the files generated during the CMORisation process. This ensures that each CMORised file includes metadata identifying who performed the CMORisation, allowing us to track data provenance and follow up with the responsible person if needed.

# %%
# %pip install access_mopper
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: access_mopper in ./.local/lib/python3.11/site-packages (2.3.0a24)
# Requirement already satisfied: numpy in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (2.2.5)
# Requirement already satisfied: pandas in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (2.2.3)
# Requirement already satisfied: xarray in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (2025.4.0)
# Requirement already satisfied: netCDF4 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (1.7.2)
# Requirement already satisfied: cftime in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (1.6.4)
# Requirement already satisfied: dask in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (2025.5.0)
# Requirement already satisfied: pyyaml in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (6.0.2)
# Requirement already satisfied: tqdm in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (4.67.1)
# Requirement already satisfied: requests in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (2.32.3)
# Requirement already satisfied: parsl in ./.local/lib/python3.11/site-packages (from access_mopper) (2025.9.8)
# Requirement already satisfied: jinja2 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from access_mopper) (3.1.6)
# Requirement already satisfied: click>=8.1 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from dask->access_mopper) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask->access_mopper) (3.21.0)
# Requirement already satisfied: locket in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from partd>=1.4.0->dask->access_mopper) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from jinja2->access_mopper) (3.0.2)
# Requirement already satisfied: certifi in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from netCDF4->access_mopper) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from pandas->access_mopper) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from pandas->access_mopper) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from pandas->access_mopper) (2025.2)
# Requirement already satisfied: six>=1.5 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->access_mopper) (1.17.0)
# Requirement already satisfied: pyzmq>=17.1.2 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from parsl->access_mopper) (26.3.0)
# Requirement already satisfied: typeguard!=3.*,<5,>=2.10 in ./.local/lib/python3.11/site-packages (from parsl->access_mopper) (4.4.4)
# Requirement already satisfied: typing-extensions<5,>=4.6 in ./.local/lib/python3.11/site-packages (from parsl->access_mopper) (4.15.0)
# Requirement already satisfied: globus-sdk in ./.local/lib/python3.11/site-packages (from parsl->access_mopper) (3.63.0)
# Requirement already satisfied: dill in ./.local/lib/python3.11/site-packages (from parsl->access_mopper) (0.4.0)
# Requirement already satisfied: tblib in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from parsl->access_mopper) (3.1.0)
# Requirement already satisfied: sortedcontainers in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from parsl->access_mopper) (2.4.0)
# Requirement already satisfied: psutil>=5.5.1 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from parsl->access_mopper) (5.9.8)
# Requirement already satisfied: setproctitle in ./.local/lib/python3.11/site-packages (from parsl->access_mopper) (1.3.7)
# Requirement already satisfied: filelock<4,>=3.13 in ./.local/lib/python3.11/site-packages (from parsl->access_mopper) (3.19.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.0.0 in ./.local/lib/python3.11/site-packages (from pyjwt[crypto]<3.0.0,>=2.0.0->globus-sdk->parsl->access_mopper) (2.10.1)
# Requirement already satisfied: cryptography!=3.4.0,>=3.3.1 in ./.local/lib/python3.11/site-packages (from globus-sdk->parsl->access_mopper) (45.0.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from requests->access_mopper) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from requests->access_mopper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from requests->access_mopper) (2.3.0)
# Requirement already satisfied: cffi>=1.14 in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from cryptography!=3.4.0,>=3.3.1->globus-sdk->parsl->access_mopper) (1.17.1)
# Requirement already satisfied: pycparser in /g/data/xp65/public/apps/med_conda/envs/access-vis-0.4/lib/python3.11/site-packages (from cffi>=1.14->cryptography!=3.4.0,>=3.3.1->globus-sdk->parsl->access_mopper) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from access_mopper import ACCESS_ESM_CMORiser
# Out:
# Loaded Configuration:
# Creator Name: Benoit Pasquier
# Organisation: UNSW CCRC
# Creator Email: b.pasquier@unsw.edu.au
# Creator URL: 0000-0002-3838-5976

# %% [markdown]
# ## Dask support
#
# ACCESS-MOPPeR supports Dask for parallel processing, which can significantly speed up the CMORisation workflow, especially when working with large datasets. To use Dask with ACCESS-MOPPeR, you can create a Dask client it will be used to manage the distributed computation. This allows you to take advantage of multiple CPU cores or even a cluster of machines, depending on your setup.
# You can configure the Dask client to use a specific number of threads per worker, which can help optimize performance based on your hardware and the size of the datasets you are processing.
#
# Here's an example of how to set up a Dask client:
#
# ```python
# import dask.distributed as dask
#
# client = dask.Client(threads_per_worker=1)
# client
# ```

# %%
import dask.distributed as dask

client = dask.Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:39611' processes=14 threads=14, memory=63.00 GiB>

# %% [markdown]
# ## Data selection
#
# The `ACCESS_ESM_CMORiser` class (described in detail below) takes as input a list of paths to NetCDF files containing the raw model output variables to be CMORised. The CMORiser does **not** assume any specific folder structure, DRS (Data Reference Syntax), or file naming convention. It is intentionally left to the user to ensure that the provided files contain the original variables required for CMORisation.
#
# This design is intentional: ACCESS-NRI plans to integrate ACCESS-MOPPeR into extended workflows that leverage the [ACCESS-NRI Intake Catalog](https://github.com/ACCESS-NRI/access-nri-intake-catalog) or evaluation frameworks such as [ESMValTool](https://www.esmvaltool.org/) and [ILAMB](https://www.ilamb.org/). By decoupling file selection from the CMORiser, ACCESS-MOPPeR can be flexibly used in a variety of data processing and evaluation pipelines.

# %%
# Here we use netcdf file from a raw ACCESS-ESM run.
import glob

# files = glob.glob("../../Test_data/esm1-6/atmosphere/aiihca.pa-0961*_mon.nc")
files = glob.glob("/g/data/cj50/access-om2/raw-output/access-om2/1deg_jra55_ryf9091_kds50_bkd/output000/ocean/*month.nc")
files

# %% [markdown]
# ### Parent experiment information
#
# In CMIP workflows, providing parent experiment information is required for proper data provenance and traceability. This metadata describes the relationship between your experiment and its parent (for example, a historical run branching from a piControl simulation), and is essential for CMIP data publication and compliance.
#
# However, for some applications—such as when using ACCESS-MOPPeR to interact with evaluation frameworks like [ESMValTool](https://www.esmvaltool.org/) or [ILAMB](https://www.ilamb.org/)—strict CMIP compliance is not always necessary. In these cases, you may choose to skip providing parent experiment information to simplify the workflow.
#
# If you choose to skip this step, ACCESS-MOPPeR will issue a warning to let you know that, if you write the output to disk, the resulting file may not be compatible with CMIP requirements for publication. This flexibility allows you to use ACCESS-MOPPeR for rapid evaluation and prototyping, while still supporting full CMIP compliance when needed.

# %%
parent_experiment_config = {
    # "parent_experiment_id": "piControl",
    # "parent_activity_id": "CMIP",
    # "parent_source_id": "ACCESS-ESM1-5",
    # "parent_variant_label": "r1i1p1f1",
    # "parent_time_units": "days since 0001-01-01 00:00:00",
    # "parent_mip_era": "CMIP6",
    # "branch_time_in_child": 0.0,
    # "branch_time_in_parent": 54786.0,
    # "branch_method": "standard",
}

# %% [markdown]
# ## Set up the CMORiser for CMORisation
#
# To begin the CMORisation process, you need to create an instance of the `ACCESS_ESM_CMORiser` class. This class requires several key parameters, including the list of input NetCDF files and metadata describing your experiment.
#
# A crucial parameter is the `compound_name`, which should be specified using the full CMIP convention: `table.variable` (for example, `Amon.rsds`). This format uniquely identifies the variable, its frequency (e.g., monthly, daily), and the associated CMIP table, ensuring that all requirements for grids and metadata are correctly handled. Using the full compound name helps avoid ambiguity and guarantees that the CMORiser applies the correct standards for each variable.
#
# You can also provide additional metadata such as `experiment_id`, `source_id`, `variant_label`, and `grid_label` to ensure your output is CMIP-compliant. Optionally, you may include parent experiment information for full provenance tracking.

# %%
cmoriser = ACCESS_ESM_CMORiser(
    input_paths=files,
    compound_name="Omon.umo",
    experiment_id="omip1",
    source_id="ACCESS-OM2",
    variant_label="r1i1p1f1",
    grid_label="gn",
    # activity_id="CMIP",
    # parent_info=parent_experiment_config,  # <-- This is optional, can be skipped if not needed
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cmoriser = ACCESS_ESM_CMORiser(
#       2     input_paths=files,
#       3     compound_name="Omon.umo",
#       4     experiment_id="omip1",
#       5     source_id="ACCESS-OM2",
#       6     variant_label="r1i1p1f1",
#       7     grid_label="gn",
#       8     # activity_id="CMIP",
#       9     # parent_info=parent_experiment_config,  # <-- This is optional, can be skipped if not needed
#      10 )
#
# File ~/.local/lib/python3.11/site-packages/access_mopper/driver.py:64, in ACCESS_ESM_CMORiser.__init__(self, input_paths, compound_name, experiment_id, source_id, variant_label, grid_label, activity_id, output_path, drs_root, parent_info)
#      61 self.parent_info = {**_default_parent_info, **(parent_info or {})}
#      63 # Create the CMIP6Vocabulary instance
# ---> 64 self.vocab = CMIP6Vocabulary(
#      65     compound_name=compound_name,
#      66     experiment_id=experiment_id,
#      67     source_id=source_id,
#      68     variant_label=variant_label,
#      69     grid_label=grid_label,
#      70     activity_id=activity_id,
#      71     parent_info=self.parent_info,
#      72 )
#      74 # Initialize the CMORiser based on the compound name
#      75 table, cmor_name = compound_name.split(".")
#
# File ~/.local/lib/python3.11/site-packages/access_mopper/vocabulary_processors.py:39, in CMIP6Vocabulary.__init__(self, compound_name, experiment_id, source_id, variant_label, grid_label, activity_id, parent_info)
#      37 self.variable: Dict[str, Any] = self._get_variable_entry()
#      38 self.cmip_table: Dict[str, Any] = self._load_table()
# ---> 39 self.axes: Dict[str, Any] = self._get_axes()
#
# File ~/.local/lib/python3.11/site-packages/access_mopper/vocabulary_processors.py:156, in CMIP6Vocabulary._get_axes(self)
#     153         axes = json.load(f)["axis_entry"]
#     155 dims = self.variable["dimensions"].split()
# --> 156 return {dim: {k: v for k, v in axes[dim].items() if v != ""} for dim in dims}
#
# File ~/.local/lib/python3.11/site-packages/access_mopper/vocabulary_processors.py:156, in <dictcomp>(.0)
#     153         axes = json.load(f)["axis_entry"]
#     155 dims = self.variable["dimensions"].split()
# --> 156 return {dim: {k: v for k, v in axes[dim].items() if v != ""} for dim in dims}
#
# KeyError: 'olevel'

# %% [markdown]
# ## Running the CMORiser
#
# To start the CMORisation process, simply call the `run()` method on your `cmoriser` instance as shown below. This step may take some time, especially if you are processing a large number of files.
#
# We recommend using the [dask-labextension](https://github.com/dask/dask-labextension) with JupyterLab to monitor the progress of your computation. The extension provides a convenient dashboard to track task progress and resource usage directly within your notebook interface.

# %%
cmoriser.run()

# %% [markdown]
# ### In-memory processing with xarray and Dask
#
# The CMORisation workflow processes data entirely in memory using `xarray` and Dask. This approach enables efficient parallel computation and flexible data manipulation, but requires that your system has enough memory to handle the size of your dataset.
#
# Once the CMORisation is complete, you can access the resulting dataset by calling the `to_dataset()` method on your `cmoriser` instance (see below). The returned object is a standard xarray dataset, which means you can slice, analyze, or further process the data using familiar xarray operations.

# %%
ds = cmoriser.to_dataset()

# %%
ds

# %% [markdown]
# ### Writing the output to a NetCDF file
#
# To save your CMORised data to disk, use the `write()` method of the `cmoriser` instance. This will create a NetCDF file with all attributes set according to the CMIP Controlled Vocabulary, ensuring compliance with CMIP metadata standards.
#
# After writing the file, we recommend validating it using [PrePARE](https://github.com/PCMDI/cmor/tree/master/PrePARE), a tool provided by PCMDI to check the conformity of CMIP files. PrePARE will help you identify any issues with metadata or file structure before publication or further analysis.

# %%
cmoriser.write()
