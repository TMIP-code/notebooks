# %% [markdown]
# # Convert B-grid variable to C-grid

# %% [markdown]
# ## 1. Load packages

# %%
# Ignore warnings
from os import environ
environ["PYTHONWARNINGS"] = "ignore"
# Deactivate SSL verification (not sure if/why SSL verification is an issue in my case)
environ['WDM_SSL_VERIFY'] = '0'

# %%
# Import makedirs to create directories where I write new files
from os import makedirs

# %%
# Load dask
from dask.distributed import Client

# Load intake and cosima cookbook
import intake

# Load xarray for N-dimensional arrays
import xarray as xr

# Load xgcm for interpolation between Arakawa grids
import xgcm

# Load datetime to deal with time formats
# import datetime
import cftime

# Load numpy for numbers!
import numpy as np

# Load xmip for preprocessing (trying to get consistent metadata for making matrices down the road)
from xmip.preprocessing import combined_preprocessing

# Load pandas for DataFrame manipulations
import pandas as pd

# %% [markdown]
# ## 2. Define some functions
#
# (to avoid too much boilerplate code)

# %%
########## functions ##########
print("Defining functions")

def time_window_strings(year_start, num_years, timetype=cftime.DatetimeNoLeap):
    """
    return strings for `start_time` and `end_time`

    So if you give it `year_start = 1850` and `num_years = 30`,
    It will return `start_time` as the first second of Jan 1 1850
    and `end_time` as the last second of Dec 31 1879.
    """
    # start_time is first second of year_start
    # start_time = datetime.datetime(year_start, 1, 1, 0, 0, 0)
    start_time =timetype(year_start, 1, 1, 0, 0, 0)
    # end_time is last second of last_year
    # end_time = datetime.datetime(year_start + num_years - 1, 12, 31, 23, 59, 59)
    end_time = timetype(year_start + num_years - 1, 12, 31, 23, 59, 59)

    # Return the weighted average
    return start_time, end_time

def find_latest_version(cat):
    """
    find latest version of selected data
    """
    sorted_versions = cat.df.version.to_list()
    sorted_versions.sort()
    latest_version = sorted_versions[-1]
    return latest_version

def select_latest_cat(cat, **kwargs):
    """
    search latest version of selected data
    """
    selectedcat = cat.search(**kwargs)
    latestselectedcat = selectedcat.search(version=find_latest_version(selectedcat))
    return latestselectedcat

def select_latest_data(cat, xarray_open_kwargs, **kwargs):
    latestselectedcat = select_latest_cat(cat, **kwargs)
    xarray_combine_by_coords_kwargs=dict(
        compat="override",
        data_vars="minimal",
        coords="minimal"
    )
    datadask = latestselectedcat.to_dask(
        xarray_open_kwargs=xarray_open_kwargs,
        xarray_combine_by_coords_kwargs=xarray_combine_by_coords_kwargs,
        parallel=True,
        preprocess=combined_preprocessing,
    )
    return datadask
# Out:
# Defining functions

# %% [markdown]
# ## 3. Load the Pangeo Forge catalog

# %%
# The catalog
# copied from the ReadMe at https://github.com/leap-stc/cmip6-leap-feedstock
url = "https://storage.googleapis.com/cmip6/cmip6-pgf-ingestion-test/catalog/catalog.json" # Only stores that pass current tests
cat = intake.open_esm_datastore(url)
cat
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/connector.py:980, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#     979     async with ceil_timeout(timeout.sock_connect):
# --> 980         return await self._loop.create_connection(*args, **kwargs)  # type: ignore[return-value]  # noqa
#     981 except cert_errors as exc:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/asyncio/base_events.py:1065, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1064 if len(exceptions) == 1:
# -> 1065     raise exceptions[0]
#    1066 else:
#    1067     # If they all have the same str(), raise one.
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/asyncio/base_events.py:1050, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1049 try:
# -> 1050     sock = await self._connect_sock(
#    1051         exceptions, addrinfo, laddr_infos)
#    1052     break
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/asyncio/base_events.py:961, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#     960         raise my_exceptions.pop()
# --> 961 await self.sock_connect(sock, address)
#     962 return sock
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/asyncio/selector_events.py:500, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     499 self._sock_connect(fut, sock, address)
# --> 500 return await fut
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/asyncio/selector_events.py:535, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     533     if err != 0:
#     534         # Jump to any except clause below.
# --> 535         raise OSError(err, f'Connect call failed {address}')
#     536 except (BlockingIOError, InterruptedError):
#     537     # socket is still registered, the callback will be retried later
#
# OSError: [Errno 101] Connect call failed ('172.217.24.59', 443)
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/implementations/http.py:417, in HTTPFileSystem._info(self, url, **kwargs)
#     415 try:
#     416     info.update(
# --> 417         await _file_info(
#     418             self.encode_url(url),
#     419             size_policy=policy,
#     420             session=session,
#     421             **self.kwargs,
#     422             **kwargs,
#     423         )
#     424     )
#     425     if info.get("size") is not None:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/implementations/http.py:833, in _file_info(url, session, size_policy, **kwargs)
#     832 elif size_policy == "get":
# --> 833     r = await session.get(url, allow_redirects=ar, **kwargs)
#     834 else:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/client.py:536, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     535         assert self._connector is not None
# --> 536         conn = await self._connector.connect(
#     537             req, traces=traces, timeout=real_timeout
#     538         )
#     539 except asyncio.TimeoutError as exc:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/connector.py:540, in BaseConnector.connect(self, req, traces, timeout)
#     539 try:
# --> 540     proto = await self._create_connection(req, traces, timeout)
#     541     if self._closed:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/connector.py:901, in TCPConnector._create_connection(self, req, traces, timeout)
#     900 else:
# --> 901     _, proto = await self._create_direct_connection(req, traces, timeout)
#     903 return proto
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/connector.py:1209, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1208 assert last_exc is not None
# -> 1209 raise last_exc
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/connector.py:1178, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1177 try:
# -> 1178     transp, proto = await self._wrap_create_connection(
#    1179         self._factory,
#    1180         host,
#    1181         port,
#    1182         timeout=timeout,
#    1183         ssl=sslcontext,
#    1184         family=hinfo["family"],
#    1185         proto=hinfo["proto"],
#    1186         flags=hinfo["flags"],
#    1187         server_hostname=hinfo["hostname"] if sslcontext else None,
#    1188         local_addr=self._local_addr,
#    1189         req=req,
#    1190         client_error=client_error,
#    1191     )
#    1192 except ClientConnectorError as exc:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/aiohttp/connector.py:988, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#     987     raise
# --> 988 raise client_error(req.connection_key, exc) from exc
#
# ClientConnectorError: Cannot connect to host storage.googleapis.com:443 ssl:default [Connect call failed ('172.217.24.59', 443)]
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 # The catalog
#       2 # copied from the ReadMe at https://github.com/leap-stc/cmip6-leap-feedstock
#       3 url = "https://storage.googleapis.com/cmip6/cmip6-pgf-ingestion-test/catalog/catalog.json" # Only stores that pass current tests
# ----> 4 cat = intake.open_esm_datastore(url)
#       5 cat
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/intake_esm/core.py:107, in esm_datastore.__init__(self, obj, progressbar, sep, registry, read_csv_kwargs, columns_with_iterables, storage_options, **intake_kwargs)
#     105     self.esmcat = ESMCatalogModel.from_dict(obj)
#     106 else:
# --> 107     self.esmcat = ESMCatalogModel.load(
#     108         obj, storage_options=self.storage_options, read_csv_kwargs=read_csv_kwargs
#     109     )
#     111 self.derivedcat = registry or default_registry
#     112 self._entries = {}
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/intake_esm/cat.py:240, in ESMCatalogModel.load(cls, json_file, storage_options, read_csv_kwargs)
#     237 json_file = str(json_file)  # We accept Path, but fsspec doesn't.
#     238 _mapper = fsspec.get_mapper(json_file, **storage_options)
# --> 240 with fsspec.open(json_file, **storage_options) as fobj:
#     241     data = json.loads(fobj.read())
#     242     if 'last_updated' not in data:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/core.py:102, in OpenFile.__enter__(self)
#      99 def __enter__(self):
#     100     mode = self.mode.replace("t", "").replace("b", "") + "b"
# --> 102     f = self.fs.open(self.path, mode=mode)
#     104     self.fobjects = [f]
#     106     if self.compression is not None:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/spec.py:1241, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1239 else:
#    1240     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1241     f = self._open(
#    1242         path,
#    1243         mode=mode,
#    1244         block_size=block_size,
#    1245         autocommit=ac,
#    1246         cache_options=cache_options,
#    1247         **kwargs,
#    1248     )
#    1249     if compression is not None:
#    1250         from fsspec.compression import compr
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/implementations/http.py:356, in HTTPFileSystem._open(self, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#     354 kw["asynchronous"] = self.asynchronous
#     355 kw.update(kwargs)
# --> 356 size = size or self.info(path, **kwargs)["size"]
#     357 session = sync(self.loop, self.set_session)
#     358 if block_size and size:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/asyn.py:121, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     118 @functools.wraps(func)
#     119 def wrapper(*args, **kwargs):
#     120     self = obj or args[0]
# --> 121     return sync(self.loop, func, *args, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/asyn.py:106, in sync(loop, func, timeout, *args, **kwargs)
#     104     raise FSTimeoutError from return_result
#     105 elif isinstance(return_result, BaseException):
# --> 106     raise return_result
#     107 else:
#     108     return return_result
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/asyn.py:61, in _runner(event, coro, result, timeout)
#      59     coro = asyncio.wait_for(coro, timeout=timeout)
#      60 try:
# ---> 61     result[0] = await coro
#      62 except Exception as ex:
#      63     result[0] = ex
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/fsspec/implementations/http.py:430, in HTTPFileSystem._info(self, url, **kwargs)
#     427     except Exception as exc:
#     428         if policy == "get":
#     429             # If get failed, then raise a FileNotFoundError
# --> 430             raise FileNotFoundError(url) from exc
#     431         logger.debug(str(exc))
#     433 return {"name": url, "size": None, **info, "type": "file"}
#
# FileNotFoundError: https://storage.googleapis.com/cmip6/cmip6-pgf-ingestion-test/catalog/catalog.json

# %% [markdown]
# ## 4. Select the model, experiment, ensemble, and time window

# %% [markdown]
# A little detour to list all the models in the catalog that have monthly ocean variables:

# %%
models = np.sort(cat.search(table_id = 'Omon',).df.source_id.unique())
print(*models, sep = "\n")
# Out:
# ACCESS-CM2
# ACCESS-ESM1-5
# AWI-CM-1-1-MR
# AWI-ESM-1-1-LR
# BCC-CSM2-MR
# BCC-ESM1
# CAMS-CSM1-0
# CAS-ESM2-0
# CESM2
# CESM2-FV2
# CESM2-WACCM
# CESM2-WACCM-FV2
# CIESM
# CMCC-CM2-HR4
# CMCC-CM2-SR5
# CMCC-ESM2
# CNRM-CM6-1
# CNRM-CM6-1-HR
# CNRM-ESM2-1
# CanESM5
# CanESM5-1
# CanESM5-CanOE
# E3SM-1-0
# E3SM-1-1
# E3SM-1-1-ECA
# E3SM-2-0
# E3SM-2-0-NARRM
# EC-Earth3
# EC-Earth3-AerChem
# EC-Earth3-CC
# EC-Earth3-LR
# EC-Earth3-Veg
# EC-Earth3-Veg-LR
# FGOALS-f3-L
# FGOALS-g3
# FIO-ESM-2-0
# GFDL-CM4
# GFDL-ESM2M
# GFDL-ESM4
# GFDL-OM4p5B
# GISS-E2-1-G
# GISS-E2-1-G-CC
# GISS-E2-1-H
# GISS-E2-2-G
# GISS-E2-2-H
# HadGEM3-GC31-HH
# HadGEM3-GC31-LL
# HadGEM3-GC31-MM
# ICON-ESM-LR
# IITM-ESM
# INM-CM4-8
# INM-CM5-0
# IPSL-CM5A2-INCA
# IPSL-CM6A-LR
# IPSL-CM6A-LR-INCA
# KACE-1-0-G
# KIOST-ESM
# MCM-UA-1-0
# MIROC-ES2H
# MIROC-ES2L
# MPI-ESM-1-2-HAM
# MPI-ESM1-2-HR
# MPI-ESM1-2-LR
# NESM3
# NorCPM1
# NorESM1-F
# NorESM2-LM
# NorESM2-MM
# SAM0-UNICON
# TaiESM1
# UKESM1-0-LL
# UKESM1-1-LL

# %% [markdown]
# The creation of a matrix can only work if the following set of variables is available:
# - mass transports (`umo` and `vmo`)
# - mixed-layer depth (`mlotst`)
#
# Alternatively, we can use `umo` and `vmo` (in kg/s) can be replaced by `uo` and `vo` (m/s). However, the conversion to mass transport requires the grid-cell volume (`volcello`), grid-cell areas (from vertices and `thkcello`), and density (no variable so I guess constant will do).
#
# So the notebook here will create all the files for transport, if available: `umo`, `vmo`, `uo`, `vo`, `mlotst`.
#
# Although they can vary with time, I think the output from other variables (volumes, areas, thicknesses, vertices) is stored as constant (`table_id = Ofx` if I understand correctly).
#
# So let's list the models and check which ones have ((`umo` and `vmo`) or (`uo` and `vo`)) and `mlotst`.

# %%
def summary_variable_availability(df):

    # Step 1: Filter the dataframe to include only the specified variables
    filtered_df_1 = df[df['variable_id'].isin(['umo', 'vmo', 'mlotst'])]
    filtered_df_2 = df[df['variable_id'].isin(['uo', 'vo', 'mlotst'])]

    # Step 2: Group by 'source_id' and 'member_id'
    grouped_1 = filtered_df_1.groupby(['experiment_id', 'source_id', 'member_id'])
    grouped_2 = filtered_df_2.groupby(['experiment_id', 'source_id', 'member_id'])

    # Step 3: Find groups that contain all the variables in each set
    valid_groups_1 = grouped_1.filter(lambda x: set(['umo', 'vmo', 'mlotst']).issubset(set(x['variable_id'])))
    valid_groups_2 = grouped_2.filter(lambda x: set(['uo', 'vo', 'mlotst']).issubset(set(x['variable_id'])))

    # Step 4: Get the list of source_id and their member_id for each set
    result_1 = valid_groups_1[['experiment_id', 'source_id', 'member_id']].drop_duplicates().reset_index(drop=True)
    result_2 = valid_groups_2[['experiment_id', 'source_id', 'member_id']].drop_duplicates().reset_index(drop=True)

    # Step 5: Group by 'source_id' and aggregate member_id into a list for each set
    final_result_1 = result_1.groupby(['experiment_id', 'source_id'])['member_id'].apply(list).reset_index()
    final_result_2 = result_2.groupby(['experiment_id', 'source_id'])['member_id'].apply(list).reset_index()

    # Step 6: Merge the results into a single dataframe
    merged_result_1 = pd.merge(final_result_1, final_result_2, on=['experiment_id', 'source_id'], how='outer', suffixes=('_with_umo_vmo', '_with_uo_vo'))

    final_restult = merged_result_1.sort_values(by='source_id')

    return final_restult

# %%
df_vars_avail = summary_variable_availability(cat.df)
df_vars_avail
# Out:
#      experiment_id    source_id  \
# 0          1pctCO2   ACCESS-CM2
# 205         ssp585   ACCESS-CM2
# 176         ssp245   ACCESS-CM2
# 155         ssp126   ACCESS-CM2
# 112      piControl   ACCESS-CM2
# ..             ...          ...
# 62   esm-piControl  UKESM1-0-LL
# 34     1pctCO2-bgc  UKESM1-0-LL
# 25         1pctCO2  UKESM1-0-LL
# 54        esm-hist  UKESM1-0-LL
# 226         ssp585  UKESM1-0-LL
#
#                                 member_id_with_umo_vmo  \
# 0                                           [r1i1p1f1]
# 205                                                NaN
# 176                     [r3i1p1f1, r2i1p1f1, r1i1p1f1]
# 155                                         [r1i1p1f1]
# 112                                         [r1i1p1f1]
# ..                                                 ...
# 62                                          [r1i1p1f2]
# 34                                          [r1i1p1f2]
# 25            [r1i1p1f2, r3i1p1f2, r4i1p1f2, r2i1p1f2]
# 54                                          [r1i1p1f2]
# 226  [r8i1p1f2, r3i1p1f2, r4i1p1f2, r2i1p1f2, r1i1p...
#
#                                   member_id_with_uo_vo
# 0                                           [r1i1p1f1]
# 205                                         [r1i1p1f1]
# 176                     [r3i1p1f1, r2i1p1f1, r1i1p1f1]
# 155                                         [r1i1p1f1]
# 112                                         [r1i1p1f1]
# ..                                                 ...
# 62                                                 NaN
# 34                                                 NaN
# 25                                          [r4i1p1f2]
# 54                                          [r1i1p1f2]
# 226  [r8i1p1f2, r2i1p1f2, r4i1p1f2, r1i1p1f2, r3i1p...
#
# [227 rows x 4 columns]

# %% [markdown]
# Let's list those models with the right variables in the historical run to start with. These are the candidates for a historical TMIP!

# %%
# historical_models = np.sort(df_vars_avail[df_vars_avail.experiment_id == 'historical'].source_id.unique())
# print(*historical_models, sep = "\n")
historical_models = df_vars_avail[df_vars_avail.experiment_id == 'historical'].sort_values(by='source_id')
historical_models
# Out:
#     experiment_id          source_id  \
# 63     historical         ACCESS-CM2
# 64     historical      ACCESS-ESM1-5
# 65     historical      AWI-CM-1-1-MR
# 66     historical        BCC-CSM2-MR
# 67     historical           BCC-ESM1
# 68     historical        CAMS-CSM1-0
# 69     historical         CAS-ESM2-0
# 70     historical              CESM2
# 71     historical          CESM2-FV2
# 72     historical        CESM2-WACCM
# 73     historical    CESM2-WACCM-FV2
# 74     historical       CMCC-CM2-HR4
# 75     historical       CMCC-CM2-SR5
# 76     historical          CMCC-ESM2
# 77     historical         CNRM-CM6-1
# 78     historical        CNRM-ESM2-1
# 79     historical            CanESM5
# 80     historical      CanESM5-CanOE
# 81     historical           E3SM-1-0
# 82     historical           E3SM-1-1
# 83     historical       E3SM-1-1-ECA
# 84     historical          EC-Earth3
# 85     historical  EC-Earth3-AerChem
# 86     historical       EC-Earth3-CC
# 87     historical      EC-Earth3-Veg
# 88     historical   EC-Earth3-Veg-LR
# 89     historical           GFDL-CM4
# 90     historical        GISS-E2-1-G
# 91     historical     GISS-E2-1-G-CC
# 92     historical    HadGEM3-GC31-LL
# 93     historical    HadGEM3-GC31-MM
# 94     historical        ICON-ESM-LR
# 95     historical    IPSL-CM5A2-INCA
# 96     historical       IPSL-CM6A-LR
# 97     historical  IPSL-CM6A-LR-INCA
# 98     historical    MPI-ESM-1-2-HAM
# 99     historical      MPI-ESM1-2-HR
# 100    historical      MPI-ESM1-2-LR
# 101    historical              NESM3
# 102    historical            NorCPM1
# 103    historical         NorESM2-LM
# 104    historical         NorESM2-MM
# 105    historical        UKESM1-0-LL
#
#                                 member_id_with_umo_vmo  \
# 63                                [r2i1p1f1, r1i1p1f1]
# 64   [r2i1p1f1, r14i1p1f1, r23i1p1f1, r17i1p1f1, r2...
# 65                                                 NaN
# 66                      [r1i1p1f1, r3i1p1f1, r2i1p1f1]
# 67                      [r2i1p1f1, r3i1p1f1, r1i1p1f1]
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 72                                                 NaN
# 73                                                 NaN
# 74                                          [r1i1p1f1]
# 75                                          [r1i1p1f1]
# 76                                          [r1i1p1f1]
# 77   [r30i1p1f2, r28i1p1f2, r29i1p1f2, r1i1p1f2, r1...
# 78   [r10i1p1f2, r7i1p1f2, r6i1p1f2, r9i1p1f2, r8i1...
# 79   [r6i1p2f1, r4i1p1f1, r4i1p2f1, r7i1p2f1, r9i1p...
# 80                      [r2i1p2f1, r3i1p2f1, r1i1p2f1]
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84   [r16i1p1f1, r25i1p1f1, r14i1p1f1, r21i1p1f1, r...
# 85                                [r4i1p1f1, r1i1p1f1]
# 86                                          [r1i1p1f1]
# 87   [r12i1p1f1, r3i1p1f1, r2i1p1f1, r14i1p1f1, r4i...
# 88                      [r1i1p1f1, r3i1p1f1, r2i1p1f1]
# 89                                                 NaN
# 90   [r1i1p3f1, r10i1p1f2, r7i1p1f2, r1i1p5f1, r10i...
# 91                                          [r1i1p1f1]
# 92   [r5i1p1f3, r4i1p1f3, r3i1p1f3, r2i1p1f3, r1i1p...
# 93                                          [r2i1p1f3]
# 94                                                 NaN
# 95                                          [r1i1p1f1]
# 96   [r32i1p1f1, r3i1p1f1, r4i1p1f1, r13i1p1f1, r14...
# 97                                          [r1i1p1f1]
# 98                      [r2i1p1f1, r3i1p1f1, r1i1p1f1]
# 99   [r4i1p1f1, r6i1p1f1, r8i1p1f1, r7i1p1f1, r5i1p...
# 100  [r8i1p1f1, r6i1p1f1, r2i1p1f1, r4i1p1f1, r1i1p...
# 101                                                NaN
# 102  [r12i1p1f1, r19i1p1f1, r25i1p1f1, r24i1p1f1, r...
# 103                     [r3i1p1f1, r2i1p1f1, r1i1p1f1]
# 104                               [r2i1p1f1, r1i1p1f1]
# 105  [r18i1p1f2, r17i1p1f2, r10i1p1f2, r5i1p1f3, r1...
#
#                                   member_id_with_uo_vo
# 63                      [r3i1p1f1, r2i1p1f1, r1i1p1f1]
# 64   [r2i1p1f1, r3i1p1f1, r10i1p1f1, r4i1p1f1, r8i1...
# 65   [r3i1p1f1, r1i1p1f1, r4i1p1f1, r5i1p1f1, r2i1p...
# 66                      [r2i1p1f1, r1i1p1f1, r3i1p1f1]
# 67                      [r3i1p1f1, r1i1p1f1, r2i1p1f1]
# 68                                [r2i1p1f1, r1i1p1f1]
# 69                                          [r1i1p1f1]
# 70   [r2i1p1f1, r8i1p1f1, r3i1p1f1, r7i1p1f1, r10i1...
# 71                                          [r1i1p1f1]
# 72                      [r2i1p1f1, r3i1p1f1, r1i1p1f1]
# 73                                [r2i1p1f1, r1i1p1f1]
# 74                                                 NaN
# 75                                          [r1i1p1f1]
# 76                                          [r1i1p1f1]
# 77   [r29i1p1f2, r1i1p1f2, r25i1p1f2, r23i1p1f2, r2...
# 78   [r10i1p1f2, r7i1p1f2, r4i1p1f2, r2i1p1f2, r3i1...
# 79   [r6i1p2f1, r7i1p2f1, r5i1p2f1, r9i1p2f1, r4i1p...
# 80                      [r3i1p2f1, r2i1p2f1, r1i1p2f1]
# 81                                [r1i1p1f1, r2i1p1f1]
# 82                                          [r1i1p1f1]
# 83                                          [r1i1p1f1]
# 84         [r21i1p1f1, r7i1p1f1, r10i1p1f1, r24i1p1f1]
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                          [r1i1p1f1]
# 90   [r1i1p3f1, r10i1p1f2, r7i1p1f2, r1i1p5f1, r10i...
# 91                                          [r1i1p1f1]
# 92            [r3i1p1f3, r1i1p1f3, r4i1p1f3, r2i1p1f3]
# 93                                          [r1i1p1f3]
# 94                                          [r1i1p1f1]
# 95                                                 NaN
# 96   [r32i1p1f1, r10i1p1f1, r14i1p1f1, r13i1p1f1, r...
# 97                                                 NaN
# 98                                          [r1i1p1f1]
# 99                               [r1i1p1f1, r10i1p1f1]
# 100                                         [r1i1p1f1]
# 101  [r4i1p1f1, r5i1p1f1, r2i1p1f1, r3i1p1f1, r1i1p...
# 102  [r12i1p1f1, r19i1p1f1, r25i1p1f1, r24i1p1f1, r...
# 103                     [r1i1p1f1, r3i1p1f1, r2i1p1f1]
# 104                               [r2i1p1f1, r1i1p1f1]
# 105  [r18i1p1f2, r17i1p1f2, r10i1p1f2, r5i1p1f3, r1...

# %%
experiment = "historical"

# %%
model = "GFDL-CM4"
# model = "ACCESS-ESM1-5"

# %%
# Check which members are available for the model
members = historical_models[historical_models.source_id == model].member_id_with_umo_vmo.values[0]
# parse numbers in members list of strings, which are formatted as "r%di%dp%df%d"
import re
def extract_first_number(s):
    numbers = re.findall(r'\d+', s)
    return int(numbers[0])
# sort members by the first number in the string
members = sorted(members, key=extract_first_number)

print(*members, sep = "\n")
# Out:
# r1i1p1f1
# r2i1p1f1
# r3i1p1f1
# r4i1p1f1
# r5i1p1f1
# r6i1p1f1
# r7i1p1f1
# r8i1p1f1
# r9i1p1f1
# r11i1p1f1
# r12i1p1f1
# r13i1p1f1
# r14i1p1f1
# r15i1p1f1
# r16i1p1f1
# r17i1p1f1
# r18i1p1f1
# r19i1p1f1
# r20i1p1f1
# r21i1p1f1
# r22i1p1f1
# r23i1p1f1
# r24i1p1f1
# r25i1p1f1
# r26i1p1f1
# r27i1p1f1
# r28i1p1f1
# r29i1p1f1
# r30i1p1f1

# %%
ensemble = "r1i1p1f1"

# %%
year_start = 1870
num_years = 30

# %%
model, experiment, ensemble
# Out:
# ('ACCESS-ESM1-5', 'historical', 'r1i1p1f1')

# %%
# Do the catalog search once first to avoid boiler plate
searched_cat = cat.search(
    experiment_id = experiment,
    source_id = model,
    member_id = ensemble,
    table_id = 'Omon',
    grid_label = 'gn',
    variable_id = ['umo', 'vmo', 'uo', 'vo', 'mlotst'],
)
searched_cat.df
# Out:
#   activity_id institution_id      source_id experiment_id member_id table_id  \
# 0        CMIP          CSIRO  ACCESS-ESM1-5    historical  r1i1p1f1     Omon
# 1        CMIP          CSIRO  ACCESS-ESM1-5    historical  r1i1p1f1     Omon
# 2        CMIP          CSIRO  ACCESS-ESM1-5    historical  r1i1p1f1     Omon
# 3        CMIP          CSIRO  ACCESS-ESM1-5    historical  r1i1p1f1     Omon
# 4        CMIP          CSIRO  ACCESS-ESM1-5    historical  r1i1p1f1     Omon
#
#   variable_id grid_label sub_experiment_id variant_label    version  \
# 0      mlotst         gn              none      r1i1p1f1  v20191115
# 1          uo         gn              none      r1i1p1f1  v20191115
# 2         umo         gn              none      r1i1p1f1  v20191115
# 3          vo         gn              none      r1i1p1f1  v20191115
# 4         vmo         gn              none      r1i1p1f1  v20191115
#
#                                               zstore
# 0  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...
# 1  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...
# 2  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...
# 3  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...
# 4  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...

# %%
# Create directory on gdata
datadir = '/Users/benoitpasquier/Data'
start_time, end_time = time_window_strings(year_start, num_years)
start_time, end_time
# Out:
# (cftime.DatetimeNoLeap(1870, 1, 1, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeNoLeap(1899, 12, 31, 23, 59, 59, 0, has_year_zero=True))

# %%
start_time_str = start_time.strftime("%b%Y")
end_time_str = end_time.strftime("%b%Y")

outputdir = f'{datadir}/{model}/{experiment}/{ensemble}/{start_time_str}-{end_time_str}'
print(outputdir)
# Out:
# /Users/benoitpasquier/Data/ACCESS-ESM1-5/historical/r1i1p1f1/Jan1870-Dec1899

# %%
makedirs(outputdir, exist_ok=True)

# %%
########## Start the client and make the `.nc` files ##########
print("Starting client")
client = Client(n_workers=4)#, threads_per_worker=1, memory_limit='16GB') # Note: with 1thread/worker cannot plot thetao. Maybe I need to understand why?
client
# Out:
# Starting client
# <Client: 'tcp://127.0.0.1:53213' processes=4 threads=12, memory=32.00 GiB>

# %%
# umo dataset
if (searched_cat.df.variable_id == 'umo').any():
    print("Loading umo data")
    umo_datadask = select_latest_data(searched_cat,
        dict(
            use_cftime=True,
            chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
        ),
        variable_id = "umo",
    )
    # print("\numo_datadask: ", umo_datadask)
umo_datadask
# Out:
# Loading umo data
# <xarray.Dataset> Size: 43GB
# Dimensions:            (variant_label: 1, sub_experiment_id: 1, time: 1980,
#                         lev: 50, y: 300, x: 360, vertex: 4, bnds: 2)
# Coordinates: (12/14)
#     lat                (y, x) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#   * lev                (lev) float64 400B 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#     lon                (y, x) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#   * time               (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 ...
#     lat_verticies      (y, x, vertex) float64 3MB dask.array<chunksize=(60, 60, 4), meta=np.ndarray>
#     lon_verticies      (y, x, vertex) float64 3MB dask.array<chunksize=(60, 60, 4), meta=np.ndarray>
#     ...                 ...
#   * y                  (y) int64 2kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * x                  (x) int64 3kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#     lon_bounds         (bnds, y, x) float64 2MB dask.array<chunksize=(1, 60, 60), meta=np.ndarray>
#     lat_bounds         (bnds, y, x) float64 2MB dask.array<chunksize=(1, 60, 60), meta=np.ndarray>
#   * variant_label      (variant_label) object 8B 'r1i1p1f1'
#   * sub_experiment_id  (sub_experiment_id) object 8B 'none'
# Dimensions without coordinates: vertex, bnds
# Data variables:
#     umo                (variant_label, sub_experiment_id, time, lev, y, x) float32 43GB dask.array<chunksize=(1, 1, 1980, 50, 60, 60), meta=np.ndarray>
# Attributes: (12/64)
#     Conventions:                         CF-1.7 CMIP-6.2
#     activity_id:                         CMIP
#     branch_method:                       standard
#     branch_time_in_child:                0.0
#     branch_time_in_parent:               21915.0
#     cmor_version:                        3.4.0
#     ...                                  ...
#     intake_esm_attrs:sub_experiment_id:  none
#     intake_esm_attrs:variant_label:      r1i1p1f1
#     intake_esm_attrs:version:            v20191115
#     intake_esm_attrs:zstore:             gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-E...
#     intake_esm_attrs:_data_format_:      zarr
#     intake_esm_dataset_key:              CMIP.CSIRO.ACCESS-ESM1-5.historical....

# %%
# Get the time type of umo_datadask
umo_time_type = type(umo_datadask.time.values[0])
umo_time_type
# Out:
# cftime._cftime.DatetimeProlepticGregorian

# %%
# Redefine start_time and end_time to match the time type of umo_datadask
start_time, end_time = time_window_strings(year_start, num_years, umo_time_type)
start_time, end_time
# Out:
# (cftime.DatetimeProlepticGregorian(1870, 1, 1, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1899, 12, 31, 23, 59, 59, 0, has_year_zero=True))

# %%
# Slice umo dataset for the time period
umo_datadask_sel = umo_datadask.sel(time=slice(start_time, end_time))
# Take the time average of the monthly evaporation (using month length as weights)
umo = umo_datadask_sel["umo"].weighted(umo_datadask_sel.time.dt.days_in_month).mean(dim="time")
umo
# Out:
# <xarray.DataArray 'umo' (variant_label: 1, sub_experiment_id: 1, lev: 50,
#                          y: 300, x: 360)> Size: 43MB
# dask.array<truediv, shape=(1, 1, 50, 300, 360), dtype=float64, chunksize=(1, 1, 50, 60, 60), chunktype=numpy.ndarray>
# Coordinates:
#     lat                (y, x) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#   * lev                (lev) float64 400B 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#     lon                (y, x) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#   * y                  (y) int64 2kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * x                  (x) int64 3kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#   * variant_label      (variant_label) object 8B 'r1i1p1f1'
#   * sub_experiment_id  (sub_experiment_id) object 8B 'none'

# %%
# Save to netcdfs (and compute!)
umo.to_netcdf(f'{outputdir}/umo.nc', compute=True)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-16467' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16466' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16468' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16469' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16470' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16471' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16472' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16473' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16474' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16475' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16476' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16477' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16478' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16479' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16480' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16481' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16482' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16483' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16484' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16485' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16486' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16487' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16488' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16489' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16490' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16491' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16492' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16493' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16494' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16495' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16496' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16497' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16498' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16499' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16500' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16501' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16502' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16503' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16504' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16505' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16506' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16507' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16509' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16510' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16511' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16512' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16513' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16514' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16515' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16516' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16517' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16518' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16519' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16521' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16522' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16523' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16524' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16525' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16526' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16527' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16528' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16529' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16530' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16531' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16532' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16533' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16534' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16535' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16536' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16537' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16538' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16539' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16540' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16541' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16542' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16543' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16544' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16545' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16546' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16547' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16548' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16549' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16550' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16551' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16552' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16553' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16554' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-16555' coro=<Client._gather.<locals>.wait() done, defined at /Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2382> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py", line 2391, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2024-09-13 16:33:16,587 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53225 (pid=58712) exceeded 95% memory budget. Restarting...
# 2024-09-13 16:33:19,392 - distributed.nanny - WARNING - Restarting worker
# 2024-09-13 17:16:16,828 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53231 (pid=58714) exceeded 95% memory budget. Restarting...
# 2024-09-13 17:16:19,001 - distributed.nanny - WARNING - Restarting worker
# 2024-09-13 17:38:50,339 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53234 (pid=58715) exceeded 95% memory budget. Restarting...
# 2024-09-13 17:38:51,512 - distributed.nanny - WARNING - Restarting worker
# 2024-09-13 17:48:51,171 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53228 (pid=58713) exceeded 95% memory budget. Restarting...
# 2024-09-13 17:48:52,252 - distributed.nanny - WARNING - Restarting worker
# 2024-09-15 16:25:26,992 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 3 memory: 252 MB fds: 192>>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# 2024-09-15 21:24:49,039 - distributed.scheduler - WARNING - Worker failed to heartbeat for 784s; attempting restart: <WorkerState 'tcp://127.0.0.1:50924', name: 2, status: running, memory: 0, processing: 0>
# 2024-09-15 21:24:49,043 - distributed.scheduler - WARNING - Worker failed to heartbeat for 784s; attempting restart: <WorkerState 'tcp://127.0.0.1:51749', name: 0, status: running, memory: 0, processing: 0>
# 2024-09-15 21:24:49,044 - distributed.scheduler - WARNING - Worker failed to heartbeat for 784s; attempting restart: <WorkerState 'tcp://127.0.0.1:58975', name: 3, status: running, memory: 0, processing: 0>
# 2024-09-15 21:24:49,047 - distributed.scheduler - WARNING - Worker failed to heartbeat for 784s; attempting restart: <WorkerState 'tcp://127.0.0.1:62697', name: 1, status: running, memory: 0, processing: 0>
# 2024-09-15 21:24:49,753 - distributed.nanny - WARNING - Restarting worker
# 2024-09-15 21:24:49,870 - distributed.nanny - WARNING - Restarting worker
# 2024-09-15 21:24:49,882 - distributed.nanny - WARNING - Restarting worker
# 2024-09-15 21:24:49,920 - distributed.nanny - WARNING - Restarting worker
# 2024-09-16 10:31:21,058 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 12 memory: 78 MB fds: 192>>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Save to netcdfs (and compute!)
# ----> 2 umo.to_netcdf(f'{outputdir}/umo.nc', compute=True)
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/xarray/core/dataarray.py:4147, in DataArray.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    4143 else:
#    4144     # No problems with the name - so we're fine!
#    4145     dataset = self.to_dataset()
# -> 4147 return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    4148     dataset,
#    4149     path,
#    4150     mode=mode,
#    4151     format=format,
#    4152     group=group,
#    4153     engine=engine,
#    4154     encoding=encoding,
#    4155     unlimited_dims=unlimited_dims,
#    4156     compute=compute,
#    4157     multifile=False,
#    4158     invalid_netcdf=invalid_netcdf,
#    4159 )
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/xarray/backends/api.py:1429, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1426 if multifile:
#    1427     return writer, store
# -> 1429 writes = writer.sync(compute=compute)
#    1431 if isinstance(target, BytesIO):
#    1432     store.sync()
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/xarray/backends/common.py:268, in ArrayWriter.sync(self, compute, chunkmanager_store_kwargs)
#     265 if chunkmanager_store_kwargs is None:
#     266     chunkmanager_store_kwargs = {}
# --> 268 delayed_store = chunkmanager.store(
#     269     self.sources,
#     270     self.targets,
#     271     lock=self.lock,
#     272     compute=compute,
#     273     flush=True,
#     274     regions=self.regions,
#     275     **chunkmanager_store_kwargs,
#     276 )
#     277 self.sources = []
#     278 self.targets = []
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/xarray/namedarray/daskmanager.py:249, in DaskManager.store(self, sources, targets, **kwargs)
#     241 def store(
#     242     self,
#     243     sources: Any | Sequence[Any],
#     244     targets: Any,
#     245     **kwargs: Any,
#     246 ) -> Any:
#     247     from dask.array import store
# --> 249     return store(
#     250         sources=sources,
#     251         targets=targets,
#     252         **kwargs,
#     253     )
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/dask/array/core.py:1230, in store(***failed resolving arguments***)
#    1228 elif compute:
#    1229     store_dsk = HighLevelGraph(layers, dependencies)
# -> 1230     compute_as_if_collection(Array, store_dsk, map_keys, **kwargs)
#    1231     return None
#    1233 else:
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/dask/base.py:401, in compute_as_if_collection(cls, dsk, keys, scheduler, get, **kwargs)
#     399 schedule = get_scheduler(scheduler=scheduler, cls=cls, get=get)
#     400 dsk2 = optimization_function(cls)(dsk, keys, **kwargs)
# --> 401 return schedule(dsk2, keys, **kwargs)
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:3480, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3478         should_rejoin = False
#    3479 try:
# -> 3480     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3481 finally:
#    3482     for f in futures.values():
#
# File ~/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/client.py:2553, in Client.gather(self, futures, errors, direct, asynchronous)
#    2550     local_worker = None
#    2552 with shorten_traceback():
# -> 2553     return self.sync(
#    2554         self._gather,
#    2555         futures,
#    2556         errors=errors,
#    2557         direct=direct,
#    2558         local_worker=local_worker,
#    2559         asynchronous=asynchronous,
#    2560     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 2024-09-13 16:30:45,291 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.62 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 16:32:54,990 - distributed.worker.memory - WARNING - gc.collect() took 55.564s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2024-09-13 16:32:54,991 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.42 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 16:32:55,083 - distributed.worker.memory - WARNING - Worker is at 35% memory usage. Resuming worker. Process memory: 2.80 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 16:33:10,663 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.41 GiB -- Worker memory limit: 8.00 GiB
# Python(78585) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 2024-09-13 16:56:11,996 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.63 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 16:59:34,645 - distributed.worker.memory - WARNING - gc.collect() took 8.978s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2024-09-13 16:59:34,645 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.41 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 16:59:34,675 - distributed.worker.memory - WARNING - Worker is at 31% memory usage. Resuming worker. Process memory: 2.56 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 17:16:08,374 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.62 GiB -- Worker memory limit: 8.00 GiB
# 2024-09-13 17:16:11,573 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.40 GiB -- Worker memory limit: 8.00 GiB
# Python(98606) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 2024-09-13 17:35:36,024 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.64 GiB -- Worker memory limit: 8.00 GiB
# Python(9169) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 2024-09-13 17:46:09,867 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.61 GiB -- Worker memory limit: 8.00 GiB
# Python(13708) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 2024-09-14 21:35:37,042 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 1 memory: 43 MB fds: 26>>
# Traceback (most recent call last):
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benoitpasquier/Projects/TMIP/notebooks/.venv/lib/python3.12/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# Python(52370) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52371) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52372) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52373) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
# vmo dataset
if (searched_cat.df.variable_id == 'vmo').any():
    print("Loading vmo data")
    vmo_datadask = select_latest_data(searched_cat,
        dict(
            chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
        ),
        variable_id = "vmo",
    )
    print("\nvmo_datadask: ", vmo_datadask)

# %%
# uo dataset
print("Loading uo data")
uo_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "uo",
)
print("\nuo_datadask: ", uo_datadask)

# %%
# Slice uo dataset for the time period
uo_datadask_sel = uo_datadask.sel(time=slice(start_time, end_time))
print("\nuo_datadask_sel: ", uo_datadask_sel)

# %%
# Take the time average of the monthly evaporation (using month length as weights)
uo = uo_datadask_sel["uo"].weighted(uo_datadask_sel.time.dt.days_in_month).mean(dim="time")
print("\nuo_datadask: ", uo)

# %%
uo.to_netcdf(f'{outputdir}/uo.nc', compute=True)

# %%
# vo dataset
if (searched_cat.df.variable_id == 'vo').any():
    print("Loading vo data")
    vo_datadask = select_latest_data(searched_cat,
        dict(
            chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
        ),
        variable_id = "vo",
    )
    print("\nvo_datadask: ", vo_datadask)

# %%
# mlotst dataset
print("Loading mlotst data")
mlotst_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "mlotst",
)
print("\nmlotst_datadask: ", mlotst_datadask)

# %%
# Deal with thkcello for a different script,
# given that its location (fixed or time-dependent) depends on the model and/or project
# # thkcello dataset
# print("Loading thkcello data")
# thkcello_datadask = select_latest_data(searched_cat,
#     dict(
#         chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
#     ),
#     variable_id = "thkcello",
#     frequency = "mon",
# )
# print("\nthkcello_datadask: ", thkcello_datadask)

# %%
# Slice vmo dataset for the time period
vmo_datadask_sel = vmo_datadask.sel(time=slice(start_time, end_time))
# Take the time average of the monthly evaporation (using month length as weights)
vmo = vmo_datadask_sel["vmo"].weighted(vmo_datadask_sel.time.dt.days_in_month).mean(dim="time")
vmo

# %%
# Slice mlotst dataset for the time period
mlotst_datadask_sel = mlotst_datadask.sel(time=slice(start_time, end_time))
# Take the time mean of the yearly maximum of mlotst
mlotst_yearlymax = mlotst_datadask_sel.groupby("time.year").max(dim="time")
mlotst_yearlymax

# %%
mlotst = mlotst_yearlymax.mean(dim="year")
mlotst

# %%
# # Slice thkcello dataset for the time period
# thkcello_datadask_sel = thkcello_datadask.sel(time=slice(start_time, end_time))
# # Take the time average of the monthly evaporation (using month length as weights)
# thkcello = thkcello_datadask_sel["thkcello"].weighted(thkcello_datadask_sel.time.dt.days_in_month).mean(dim="time")

# %%
# Save to netcdfs (and compute!)
vmo.to_netcdf(f'{outputdir}/vmo.nc', compute=True)
mlotst.to_netcdf(f'{outputdir}/mlotst.nc', compute=True)
# thkcello.to_netcdf(f'{outputdir}/thkcello.nc', compute=True)

# %%
client.close()
