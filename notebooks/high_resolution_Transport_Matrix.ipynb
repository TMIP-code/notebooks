# %%
import intake
catalog = intake.cat.access_nri

# %%
catalog
# Out:
# <p><strong>access_nri catalog with 120 source(s) across 2941 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{v, temp_rivermix_on_nrho, scalar_axis, total_volume_seawater, sw_edges_ocean, average_T2, area_u, alidr_ai_m, frazil_3d_int_z, sens_heat, ty_trans, hu, total_net_sfc_heating, total_ocean_lprec, g...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{v, scalar_axis, total_volume_seawater, sw_edges_ocean, average_T2, area_u, frazil_3d_int_z, sens_heat, ty_trans, hu, total_net_sfc_heating, total_ocean_lprec, grid_yu_ocean, average_DT, area_t, t...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{v, scalar_axis, total_volume_seawater, sw_edges_ocean, average_T2, area_u, frazil_3d_int_z, sens_heat, ty_trans, hu, total_net_sfc_heating, total_ocean_lprec, grid_yu_ocean, average_DT, area_t, t...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 3mon, 1day, 3hr, 1mon}</td>
#       <td>{temp_vdiffuse_impl, v, temp_vdiffuse_diff_cbt_conv, scalar_axis, sw_edges_ocean, average_T2, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, ...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, scalar_axis, average_T2, sw_edges_ocean, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total_ocean_lprec, average_DT, gri...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, scalar_axis, average_T2, sw_edges_ocean, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total_ocean_lprec, average_DT, gri...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, scalar_axis, average_T2, sw_edges_ocean, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total_ocean_lprec, average_DT, gri...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, scalar_axis, average_T2, sw_edges_ocean, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total_ocean_lprec, average_DT, gri...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{v, temp_vdiffuse_diff_cbt_conv, scalar_axis, sw_edges_ocean, average_T2, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{v, temp_vdiffuse_diff_cbt_conv, scalar_axis, sw_edges_ocean, average_T2, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, scalar_axis, average_T2, sw_edges_ocean, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total_ocean_lprec, average_DT, gri...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, scalar_axis, average_T2, sw_edges_ocean, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, pot_rho_2, total_ocean_lprec, average_DT, gri...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, dvidtt, scalar_axis, sw_edges_ocean, average_T2, area_u, sfc_salt_flux_restore, frazil_3d_int_z, sens_heat, ty_trans, sfc_salt_flux_coupler, pot_temp, hu, total_net_sfc_heating, pot_rho_2, tot...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{v, dvidtt, scalar_axis, average_T2, sw_edges_ocean, area_u, divu, sfc_salt_flux_restore, frazil_3d

# %%
# catalog.interactive

# %%
variable=[
    "tx_trans", "ty_trans", 
    # "tx_trans_gm", "ty_trans_gm", 
    # "tx_trans_submeso", "ty_trans_submeso",
    # "mlotst", "volcello", "areacello",
    # "mld", "area_t",
    "mld", "area_t", "dzt",
]

# %%
variables_set = set(variable)
variables_set
# Out:
# {'area_t', 'dzt', 'mld', 'tx_trans', 'ty_trans'}

# %%
# Define our query
query = dict(
    model="ACCESS-OM2.*",
    # description=re.compile('.*0.1 degree.*'),
    # description='[^.]*1(?: degree|°).*',
    # name='.*ryf.*',
    variable=variable,
    # frequency="1mon",
)
query
# Out:
# {'model': 'ACCESS-OM2.*',
#  'variable': ['tx_trans', 'ty_trans', 'mld', 'area_t', 'dzt']}

# %%
catalog.search(**query)
# Out:
# <p><strong>Intake dataframe catalog with 85 source(s) across 179 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean}</td>
#       <td>{fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean}</td>
#       <td>{fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean}</td>
#       <td>{fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 3mon, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean}</td>
#       <td>{fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean}</td>
#       <td>{fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle3</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 3 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 6hr, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day, subhr, fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v150_iaf_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{fx, 1mon}</td>
#       <td>{tx_trans, mld, area_t, dzt, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1980-2021)}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{area_t, mld}</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{area_t, dzt, mld}</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0\ninterannual forcing (1980-2019)}</td>
#       <td>{ocean}</td>
#       <td>{1day, fx, 1mon}</td>
#       <td>{area_t, mld}</td>
#     </tr>
#     <tr>
#       <th>025deg_

# %%
df = catalog.search(**query).df
df = df.groupby('name', as_index=False)['variable'].sum()
df['variable'] = df['variable'].apply(lambda x: set(x))
df
# Out:
#                                                  name  \
# 0                             01deg_jra55_ryf_Control
# 1                              01deg_jra55_ryf_ENFull
# 2                              01deg_jra55_ryf_LNFull
# 3                              01deg_jra55v13_ryf9091
# 4            01deg_jra55v13_ryf9091_easterlies_down10
# 5              01deg_jra55v13_ryf9091_easterlies_up10
# 6   01deg_jra55v13_ryf9091_easterlies_up10_meridional
# 7        01deg_jra55v13_ryf9091_easterlies_up10_zonal
# 8                   01deg_jra55v13_ryf9091_qian_wthmp
# 9                    01deg_jra55v13_ryf9091_qian_wthp
# 10               01deg_jra55v13_ryf9091_weddell_down2
# 11                 01deg_jra55v13_ryf9091_weddell_up1
# 12                                01deg_jra55v140_iaf
# 13                         01deg_jra55v140_iaf_cycle2
# 14                         01deg_jra55v140_iaf_cycle3
# 15                         01deg_jra55v140_iaf_cycle4
# 16     01deg_jra55v140_iaf_cycle4_jra55v150_extension
# 17                         01deg_jra55v150_iaf_cycle1
# 18                                    025deg_era5_iaf
# 19                                    025deg_era5_ryf
# 20                    025deg_jra55_iaf_era5comparison
# 21                      025deg_jra55_iaf_omip2_cycle1
# 22                      025deg_jra55_iaf_omip2_cycle2
# 23                      025deg_jra55_iaf_omip2_cycle3
# 24                      025deg_jra55_iaf_omip2_cycle4
# 25                      025deg_jra55_iaf_omip2_cycle5
# 26                      025deg_jra55_iaf_omip2_cycle6
# 27                          025deg_jra55_ryf9091_gadi
# 28                    025deg_jra55_ryf_era5comparison
# 29                                      1deg_era5_iaf
# 30                                      1deg_era5_ryf
# 31                      1deg_jra55_iaf_era5comparison
# 32                        1deg_jra55_iaf_omip2_cycle1
# 33                        1deg_jra55_iaf_omip2_cycle2
# 34                        1deg_jra55_iaf_omip2_cycle3
# 35                        1deg_jra55_iaf_omip2_cycle4
# 36                        1deg_jra55_iaf_omip2_cycle5
# 37                        1deg_jra55_iaf_omip2_cycle6
# 38                  1deg_jra55_iaf_omip2spunup_cycle1
# 39                 1deg_jra55_iaf_omip2spunup_cycle10
# 40                 1deg_jra55_iaf_omip2spunup_cycle11
# 41                 1deg_jra55_iaf_omip2spunup_cycle12
# 42                 1deg_jra55_iaf_omip2spunup_cycle13
# 43                 1deg_jra55_iaf_omip2spunup_cycle14
# 44                 1deg_jra55_iaf_omip2spunup_cycle15
# 45                 1deg_jra55_iaf_omip2spunup_cycle16
# 46                 1deg_jra55_iaf_omip2spunup_cycle17
# 47                 1deg_jra55_iaf_omip2spunup_cycle18
# 48                 1deg_jra55_iaf_omip2spunup_cycle19
# 49                  1deg_jra55_iaf_omip2spunup_cycle2
# 50                 1deg_jra55_iaf_omip2spunup_cycle20
# 51                 1deg_jra55_iaf_omip2spunup_cycle21
# 52                 1deg_jra55_iaf_omip2spunup_cycle22
# 53                 1deg_jra55_iaf_omip2spunup_cycle23
# 54                 1deg_jra55_iaf_omip2spunup_cycle24
# 55                 1deg_jra55_iaf_omip2spunup_cycle25
# 56                 1deg_jra55_iaf_omip2spunup_cycle26
# 57                 1deg_jra55_iaf_omip2spunup_cycle27
# 58                 1deg_jra55_iaf_omip2spunup_cycle28
# 59                 1deg_jra55_iaf_omip2spunup_cycle29
# 60                  1deg_jra55_iaf_omip2spunup_cycle3
# 61                 1deg_jra55_iaf_omip2spunup_cycle30
# 62                 1deg_jra55_iaf_omip2spunup_cycle31
# 63                 1deg_jra55_iaf_omip2spunup_cycle32
# 64                 1deg_jra55_iaf_omip2spunup_cycle33
# 65                 1deg_jra55_iaf_omip2spunup_cycle34
# 66                 1deg_jra55_iaf_omip2spunup_cycle35
# 67                 1deg_jra55_iaf_omip2spunup_cycle36
# 68                 1deg_jra55_iaf_omip2spunup_cycle37
# 69                 1deg_jra55_iaf_omip2spunup_cycle38
# 70                 1deg_jra55_iaf_omip2spunup_cycle39
# 71                  1deg_jra55_iaf_omip2spunup_cycle4
# 72                 1deg_jra55_iaf_omip2spunup_cycle40
# 73                 1deg_jra55_iaf_omip2spunup_cycle41
# 74                 1deg_jra55_iaf_omip2spunup_cycle42
# 75                 1deg_jra55_iaf_omip2spunup_cycle43
# 76                 1deg_jra55_iaf_omip2spunup_cycle44
# 77                 1deg_jra55_iaf_omip2spunup_cycle45
# 78                  1deg_jra55_iaf_omip2spunup_cycle5
# 79                  1deg_jra55_iaf_omip2spunup_cycle6
# 80                  1deg_jra55_iaf_omip2spunup_cycle7
# 81                  1deg_jra55_iaf_omip2spunup_cycle8
# 82                  1deg_jra55_iaf_omip2spunup_cycle9
# 83                            1deg_jra55_ryf9091_gadi
# 84                                  1deg_jra55v14_ryf
#
#                                   variable
# 0   {tx_trans, mld, area_t, dzt, ty_trans}
# 1   {tx_trans, mld, area_t, dzt, ty_trans}
# 2   {tx_trans, mld, area_t, dzt, ty_trans}
# 3   {tx_trans, mld, area_t, dzt, ty_trans}
# 4   {tx_trans, mld, area_t, dzt, ty_trans}
# 5   {tx_trans, mld, area_t, dzt, ty_trans}
# 6   {tx_trans, mld, area_t, dzt, ty_trans}
# 7   {tx_trans, mld, area_t, dzt, ty_trans}
# 8   {tx_trans, mld, area_t, dzt, ty_trans}
# 9   {tx_trans, mld, area_t, dzt, ty_trans}
# 10  {tx_trans, mld, area_t, dzt, ty_trans}
# 11  {tx_trans, mld, area_t, dzt, ty_trans}
# 12  {tx_trans, mld, area_t, dzt, ty_trans}
# 13  {tx_trans, mld, area_t, dzt, ty_trans}
# 14  {tx_trans, mld, area_t, dzt, ty_trans}
# 15  {tx_trans, mld, area_t, dzt, ty_trans}
# 16  {tx_trans, mld, area_t, dzt, ty_trans}
# 17  {tx_trans, mld, area_t, dzt, ty_trans}
# 18                           {area_t, mld}
# 19                      {area_t, dzt, mld}
# 20                           {area_t, mld}
# 21       {tx_trans, area_t, mld, ty_trans}
# 22       {tx_trans, area_t, mld, ty_trans}
# 23       {tx_trans, area_t, mld, ty_trans}
# 24       {tx_trans, area_t, mld, ty_trans}
# 25       {tx_trans, area_t, mld, ty_trans}
# 26       {tx_trans, area_t, mld, ty_trans}
# 27  {tx_trans, mld, area_t, dzt, ty_trans}
# 28                      {area_t, dzt, mld}
# 29  {tx_trans, mld, area_t, dzt, ty_trans}
# 30                      {area_t, dzt, mld}
# 31  {tx_trans, mld, area_t, dzt, ty_trans}
# 32       {tx_trans, area_t, mld, ty_trans}
# 33       {tx_trans, area_t, mld, ty_trans}
# 34       {tx_trans, area_t, mld, ty_trans}
# 35       {tx_trans, area_t, mld, ty_trans}
# 36       {tx_trans, area_t, mld, ty_trans}
# 37       {tx_trans, area_t, mld, ty_trans}
# 38       {tx_trans, area_t, mld, ty_trans}
# 39                                   {mld}
# 40                                   {mld}
# 41                                   {mld}
# 42                                   {mld}
# 43                                   {mld}
# 44                                   {mld}
# 45                                   {mld}
# 46                                   {mld}
# 47                                   {mld}
# 48                                   {mld}
# 49       {tx_trans, area_t, mld, ty_trans}
# 50                                   {mld}
# 51                                   {mld}
# 52                                   {mld}
# 53                                   {mld}
# 54                                   {mld}
# 55                                   {mld}
# 56                                   {mld}
# 57                                   {mld}
# 58                                   {mld}
# 59                                   {mld}
# 60       {tx_trans, area_t, mld, ty_trans}
# 61                                   {mld}
# 62                                   {mld}
# 63                                   {mld}
# 64                                   {mld}
# 65       {tx_trans, area_t, mld, ty_trans}
# 66       {tx_trans, area_t, mld, ty_trans}
# 67       {tx_trans, area_t, mld, ty_trans}
# 68       {tx_trans, area_t, mld, ty_trans}
# 69       {tx_trans, area_t, mld, ty_trans}
# 70       {tx_trans, area_t, mld, ty_trans}
# 71       {tx_trans, area_t, mld, ty_trans}
# 72                                   {mld}
# 73                                   {mld}
# 74                                   {mld}
# 75                                   {mld}
# 76                                   {mld}
# 77                                   {mld}
# 78       {tx_trans, area_t, mld, ty_trans}
# 79       {tx_trans, area_t, mld, ty_trans}
# 80                                   {mld}
# 81                                   {mld}
# 82                                   {mld}
# 83  {tx_trans, mld, area_t, dzt, ty_trans}
# 84                      {area_t, dzt, mld}

# %%
# all in one
variable=[
    "tx_trans", "ty_trans", 
    # "tx_trans_gm", "ty_trans_gm", 
    # "tx_trans_submeso", "ty_trans_submeso",
    "mld", "area_t", "dzt",
]

variables_set = set(variable)

query = dict(model="ACCESS-OM2.*", variable=variable)

df = catalog.search(**query).df
df = df.groupby('name', as_index=False)['variable'].sum()
df['variable'] = df['variable'].apply(lambda x: set(x))

filtered_df = df[df['variable'].apply(lambda x: variables_set.issubset(x))]
filtered_df.name
# Out:
# 0                               01deg_jra55_ryf_Control
# 1                                01deg_jra55_ryf_ENFull
# 2                                01deg_jra55_ryf_LNFull
# 3                                01deg_jra55v13_ryf9091
# 4              01deg_jra55v13_ryf9091_easterlies_down10
# 5                01deg_jra55v13_ryf9091_easterlies_up10
# 6     01deg_jra55v13_ryf9091_easterlies_up10_meridional
# 7          01deg_jra55v13_ryf9091_easterlies_up10_zonal
# 8                     01deg_jra55v13_ryf9091_qian_wthmp
# 9                      01deg_jra55v13_ryf9091_qian_wthp
# 10                 01deg_jra55v13_ryf9091_weddell_down2
# 11                   01deg_jra55v13_ryf9091_weddell_up1
# 12                                  01deg_jra55v140_iaf
# 13                           01deg_jra55v140_iaf_cycle2
# 14                           01deg_jra55v140_iaf_cycle3
# 15                           01deg_jra55v140_iaf_cycle4
# 16       01deg_jra55v140_iaf_cycle4_jra55v150_extension
# 17                           01deg_jra55v150_iaf_cycle1
# 27                            025deg_jra55_ryf9091_gadi
# 29                                        1deg_era5_iaf
# 31                        1deg_jra55_iaf_era5comparison
# 83                              1deg_jra55_ryf9091_gadi
# Name: name, dtype: object

# %%
subcatalog = catalog["1deg_jra55_ryf9091_gadi"]
subcatalog
# Out:
# <p><strong>1deg_jra55_ryf9091_gadi catalog with 11 dataset(s) from 9677 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>9367</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>9677</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>9361</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>9360</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>259</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>261</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
subcatalog.search(variable=variable)
# Out:
# <p><strong>1deg_jra55_ryf9091_gadi catalog with 4 dataset(s) from 161 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>161</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
subcatalog.search(variable=variable).df
# Out:
#            filename  \
# 0     ocean_grid.nc
# 1    ocean_month.nc
# 2     ocean_grid.nc
# 3    ocean_month.nc
# 4     ocean_grid.nc
# 5    ocean_month.nc
# 6     ocean_grid.nc
# 7    ocean_month.nc
# 8     ocean_grid.nc
# 9    ocean_month.nc
# 10    ocean_grid.nc
# 11   ocean_month.nc
# 12    ocean_grid.nc
# 13   ocean_month.nc
# 14    ocean_grid.nc
# 15   ocean_month.nc
# 16    ocean_grid.nc
# 17   ocean_month.nc
# 18    ocean_grid.nc
# 19   ocean_month.nc
# 20    ocean_grid.nc
# 21   ocean_month.nc
# 22    ocean_grid.nc
# 23   ocean_month.nc
# 24    ocean_grid.nc
# 25   ocean_month.nc
# 26    ocean_grid.nc
# 27   ocean_month.nc
# 28    ocean_grid.nc
# 29   ocean_month.nc
# 30    ocean_grid.nc
# 31   ocean_month.nc
# 32    ocean_grid.nc
# 33   ocean_month.nc
# 34    ocean_grid.nc
# 35   ocean_month.nc
# 36    ocean_grid.nc
# 37   ocean_month.nc
# 38    ocean_grid.nc
# 39   ocean_month.nc
# 40    ocean_grid.nc
# 41   ocean_month.nc
# 42    ocean_grid.nc
# 43   ocean_month.nc
# 44    ocean_grid.nc
# 45   ocean_month.nc
# 46    ocean_grid.nc
# 47   ocean_month.nc
# 48    ocean_grid.nc
# 49   ocean_month.nc
# 50    ocean_grid.nc
# 51   ocean_month.nc
# 52    ocean_grid.nc
# 53   ocean_month.nc
# 54    ocean_grid.nc
# 55   ocean_month.nc
# 56    ocean_grid.nc
# 57   ocean_month.nc
# 58    ocean_grid.nc
# 59   ocean_month.nc
# 60         ocean.nc
# 61    ocean_grid.nc
# 62   ocean_month.nc
# 63         ocean.nc
# 64    ocean_grid.nc
# 65   ocean_month.nc
# 66         ocean.nc
# 67    ocean_grid.nc
# 68   ocean_month.nc
# 69    ocean_grid.nc
# 70   ocean_month.nc
# 71    ocean_grid.nc
# 72   ocean_month.nc
# 73    ocean_grid.nc
# 74   ocean_month.nc
# 75    ocean_grid.nc
# 76   ocean_month.nc
# 77    ocean_grid.nc
# 78   ocean_month.nc
# 79    ocean_grid.nc
# 80   ocean_month.nc
# 81    ocean_grid.nc
# 82   ocean_month.nc
# 83    ocean_grid.nc
# 84   ocean_month.nc
# 85    ocean_grid.nc
# 86   ocean_month.nc
# 87    ocean_grid.nc
# 88   ocean_month.nc
# 89    ocean_grid.nc
# 90   ocean_month.nc
# 91    ocean_grid.nc
# 92   ocean_month.nc
# 93    ocean_grid.nc
# 94   ocean_month.nc
# 95    ocean_grid.nc
# 96   ocean_month.nc
# 97    ocean_grid.nc
# 98   ocean_month.nc
# 99    ocean_grid.nc
# 100  ocean_month.nc
# 101   ocean_grid.nc
# 102  ocean_month.nc
# 103   ocean_grid.nc
# 104  ocean_month.nc
# 105        ocean.nc
# 106   ocean_grid.nc
# 107  ocean_month.nc
# 108   ocean_snap.nc
# 109   ocean_grid.nc
# 110  ocean_month.nc
# 111   ocean_grid.nc
# 112  ocean_month.nc
# 113   ocean_grid.nc
# 114  ocean_month.nc
# 115   ocean_grid.nc
# 116  ocean_month.nc
# 117   ocean_grid.nc
# 118  ocean_month.nc
# 119   ocean_grid.nc
# 120  ocean_month.nc
# 121   ocean_grid.nc
# 122  ocean_month.nc
# 123   ocean_grid.nc
# 124  ocean_month.nc
# 125   ocean_grid.nc
# 126  ocean_month.nc
# 127   ocean_grid.nc
# 128  ocean_month.nc
# 129   ocean_grid.nc
# 130  ocean_month.nc
# 131   ocean_grid.nc
# 132  ocean_month.nc
# 133   ocean_grid.nc
# 134  ocean_month.nc
# 135   ocean_grid.nc
# 136  ocean_month.nc
# 137   ocean_grid.nc
# 138  ocean_month.nc
# 139   ocean_grid.nc
# 140  ocean_month.nc
# 141   ocean_grid.nc
# 142  ocean_month.nc
# 143   ocean_grid.nc
# 144  ocean_month.nc
# 145   ocean_grid.nc
# 146  ocean_month.nc
# 147   ocean_grid.nc
# 148  ocean_month.nc
# 149   ocean_grid.nc
# 150  ocean_month.nc
# 151   ocean_grid.nc
# 152  ocean_month.nc
# 153   ocean_grid.nc
# 154  ocean_month.nc
# 155   ocean_grid.nc
# 156  ocean_month.nc
# 157   ocean_grid.nc
# 158  ocean_month.nc
# 159   ocean_grid.nc
# 160  ocean_month.nc
#
#                                                                                        path  \
# 0     /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output000/ocean/ocean_grid.nc
# 1    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output000/ocean/ocean_month.nc
# 2     /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output001/ocean/ocean_grid.nc
# 3    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output001/ocean/ocean_month.nc
# 4     /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output002/ocean/ocean_grid.nc
# 5    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output002/ocean/ocean_month.nc
# 6     /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output003/ocean/ocean_grid.nc
# 7    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output003/ocean/ocean_month.nc
# 8     /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output004/ocean/ocean_grid.nc
# 9    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output004/ocean/ocean_month.nc
# 10    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output005/ocean/ocean_grid.nc
# 11   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output005/ocean/ocean_month.nc
# 12    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output006/ocean/ocean_grid.nc
# 13   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output006/ocean/ocean_month.nc
# 14    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output007/ocean/ocean_grid.nc
# 15   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output007/ocean/ocean_month.nc
# 16    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output008/ocean/ocean_grid.nc
# 17   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output008/ocean/ocean_month.nc
# 18    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output009/ocean/ocean_grid.nc
# 19   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output009/ocean/ocean_month.nc
# 20    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output010/ocean/ocean_grid.nc
# 21   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output010/ocean/ocean_month.nc
# 22    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output011/ocean/ocean_grid.nc
# 23   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output011/ocean/ocean_month.nc
# 24    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output012/ocean/ocean_grid.nc
# 25   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output012/ocean/ocean_month.nc
# 26    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output013/ocean/ocean_grid.nc
# 27   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output013/ocean/ocean_month.nc
# 28    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output014/ocean/ocean_grid.nc
# 29   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output014/ocean/ocean_month.nc
# 30    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output015/ocean/ocean_grid.nc
# 31   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output015/ocean/ocean_month.nc
# 32    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output016/ocean/ocean_grid.nc
# 33   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output016/ocean/ocean_month.nc
# 34    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output017/ocean/ocean_grid.nc
# 35   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output017/ocean/ocean_month.nc
# 36    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output018/ocean/ocean_grid.nc
# 37   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output018/ocean/ocean_month.nc
# 38    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output019/ocean/ocean_grid.nc
# 39   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output019/ocean/ocean_month.nc
# 40    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output020/ocean/ocean_grid.nc
# 41   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output020/ocean/ocean_month.nc
# 42    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output021/ocean/ocean_grid.nc
# 43   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output021/ocean/ocean_month.nc
# 44    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output022/ocean/ocean_grid.nc
# 45   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output022/ocean/ocean_month.nc
# 46    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output023/ocean/ocean_grid.nc
# 47   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output023/ocean/ocean_month.nc
# 48    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output024/ocean/ocean_grid.nc
# 49   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output024/ocean/ocean_month.nc
# 50    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output025/ocean/ocean_grid.nc
# 51   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output025/ocean/ocean_month.nc
# 52    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output026/ocean/ocean_grid.nc
# 53   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output026/ocean/ocean_month.nc
# 54    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output027/ocean/ocean_grid.nc
# 55   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output027/ocean/ocean_month.nc
# 56    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output028/ocean/ocean_grid.nc
# 57   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output028/ocean/ocean_month.nc
# 58    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output029/ocean/ocean_grid.nc
# 59   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output029/ocean/ocean_month.nc
# 60         /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output030/ocean/ocean.nc
# 61    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output030/ocean/ocean_grid.nc
# 62   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output030/ocean/ocean_month.nc
# 63         /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output031/ocean/ocean.nc
# 64    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output031/ocean/ocean_grid.nc
# 65   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output031/ocean/ocean_month.nc
# 66         /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output032/ocean/ocean.nc
# 67    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output032/ocean/ocean_grid.nc
# 68   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output032/ocean/ocean_month.nc
# 69    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output033/ocean/ocean_grid.nc
# 70   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output033/ocean/ocean_month.nc
# 71    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output034/ocean/ocean_grid.nc
# 72   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output034/ocean/ocean_month.nc
# 73    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output035/ocean/ocean_grid.nc
# 74   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output035/ocean/ocean_month.nc
# 75    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output036/ocean/ocean_grid.nc
# 76   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output036/ocean/ocean_month.nc
# 77    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output037/ocean/ocean_grid.nc
# 78   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output037/ocean/ocean_month.nc
# 79    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output038/ocean/ocean_grid.nc
# 80   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output038/ocean/ocean_month.nc
# 81    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output039/ocean/ocean_grid.nc
# 82   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output039/ocean/ocean_month.nc
# 83    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output040/ocean/ocean_grid.nc
# 84   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output040/ocean/ocean_month.nc
# 85    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output041/ocean/ocean_grid.nc
# 86   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output041/ocean/ocean_month.nc
# 87    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output042/ocean/ocean_grid.nc
# 88   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output042/ocean/ocean_month.nc
# 89    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output043/ocean/ocean_grid.nc
# 90   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output043/ocean/ocean_month.nc
# 91    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output044/ocean/ocean_grid.nc
# 92   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output044/ocean/ocean_month.nc
# 93    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output045/ocean/ocean_grid.nc
# 94   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output045/ocean/ocean_month.nc
# 95    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output046/ocean/ocean_grid.nc
# 96   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output046/ocean/ocean_month.nc
# 97    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output047/ocean/ocean_grid.nc
# 98   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output047/ocean/ocean_month.nc
# 99    /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output048/ocean/ocean_grid.nc
# 100  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output048/ocean/ocean_month.nc
# 101   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output049/ocean/ocean_grid.nc
# 102  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output049/ocean/ocean_month.nc
# 103   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output050/ocean/ocean_grid.nc
# 104  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output050/ocean/ocean_month.nc
# 105        /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output051/ocean/ocean.nc
# 106   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output051/ocean/ocean_grid.nc
# 107  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output051/ocean/ocean_month.nc
# 108   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output051/ocean/ocean_snap.nc
# 109   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output052/ocean/ocean_grid.nc
# 110  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output052/ocean/ocean_month.nc
# 111   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output053/ocean/ocean_grid.nc
# 112  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output053/ocean/ocean_month.nc
# 113   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output054/ocean/ocean_grid.nc
# 114  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output054/ocean/ocean_month.nc
# 115   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output055/ocean/ocean_grid.nc
# 116  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output055/ocean/ocean_month.nc
# 117   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output056/ocean/ocean_grid.nc
# 118  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output056/ocean/ocean_month.nc
# 119   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output057/ocean/ocean_grid.nc
# 120  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output057/ocean/ocean_month.nc
# 121   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output058/ocean/ocean_grid.nc
# 122  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output058/ocean/ocean_month.nc
# 123   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output059/ocean/ocean_grid.nc
# 124  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output059/ocean/ocean_month.nc
# 125   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output060/ocean/ocean_grid.nc
# 126  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output060/ocean/ocean_month.nc
# 127   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output061/ocean/ocean_grid.nc
# 128  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output061/ocean/ocean_month.nc
# 129   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output062/ocean/ocean_grid.nc
# 130  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output062/ocean/ocean_month.nc
# 131   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output063/ocean/ocean_grid.nc
# 132  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output063/ocean/ocean_month.nc
# 133   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output064/ocean/ocean_grid.nc
# 134  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output064/ocean/ocean_month.nc
# 135   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output065/ocean/ocean_grid.nc
# 136  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output065/ocean/ocean_month.nc
# 137   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output066/ocean/ocean_grid.nc
# 138  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output066/ocean/ocean_month.nc
# 139   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output067/ocean/ocean_grid.nc
# 140  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output067/ocean/ocean_month.nc
# 141   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output068/ocean/ocean_grid.nc
# 142  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output068/ocean/ocean_month.nc
# 143   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output069/ocean/ocean_grid.nc
# 144  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output069/ocean/ocean_month.nc
# 145   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output070/ocean/ocean_grid.nc
# 146  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output070/ocean/ocean_month.nc
# 147   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output071/ocean/ocean_grid.nc
# 148  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output071/ocean/ocean_month.nc
# 149   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output072/ocean/ocean_grid.nc
# 150  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output072/ocean/ocean_month.nc
# 151   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output073/ocean/ocean_grid.nc
# 152  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output073/ocean/ocean_month.nc
# 153   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output074/ocean/ocean_grid.nc
# 154  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output074/ocean/ocean_month.nc
# 155   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output075/ocean/ocean_grid.nc
# 156  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output075/ocean/ocean_month.nc
# 157   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output076/ocean/ocean_grid.nc
# 158  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output076/ocean/ocean_month.nc
# 159   /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output077/ocean/ocean_grid.nc
# 160  /g/data/ik11/outputs/access-om2/1deg_jra55_ryf9091_gadi/output077/ocean/ocean_month.nc
#
#                                                                                                                             file_id  \
# 0                                                                      ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 1                                                               ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 2                                                                      ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 3                                                               ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 4                                                                      ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 5                                                               ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 6                                                                      ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 7                                                               ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 8                                                                      ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 9                                                               ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 10                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 11                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 12                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 13                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 14                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 15                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 16                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 17                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 18                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 19                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 20                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 21                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 22                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 23                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 24                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 25                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 26                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 27                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 28                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 29                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 30                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 31                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 32                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 33                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 34                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 35                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 36                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 37                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 38                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 39                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 40                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 41                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 42                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 43                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 44                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 45                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 46                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 47                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 48                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 49                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 50                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 51                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 52                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 53                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 54                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 55                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 56                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 57                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 58                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 59                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 60   ocean.1yr.nv:2.st_edges_ocean:51.st_ocean:50.sw_edges_ocean:51.sw_ocean:50.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 61                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 62                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 63   ocean.1yr.nv:2.st_edges_ocean:51.st_ocean:50.sw_edges_ocean:51.sw_ocean:50.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 64                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 65                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 66   ocean.1yr.nv:2.st_edges_ocean:51.st_ocean:50.sw_edges_ocean:51.sw_ocean:50.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 67                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 68                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 69                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 70                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 71                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 72                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 73                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 74                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 75                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 76                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 77                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 78                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 79                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 80                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 81                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 82                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 83                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 84                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 85                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 86                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 87                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 88                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 89                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 90                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 91                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 92                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 93                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 94                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 95                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 96                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 97                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 98                                                              ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 99                                                                     ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 100                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 101                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 102                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 103                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 104                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 105  ocean.1yr.nv:2.st_edges_ocean:51.st_ocean:50.sw_edges_ocean:51.sw_ocean:50.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 106                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 107                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 108                                                 ocean.1yr.scalar_axis:1.st_edges_ocean:51.st_ocean:50.xt_ocean:360.yt_ocean:300
# 109                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 110                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 111                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 112                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 113                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 114                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 115                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 116                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 117                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 118                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 119                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 120                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 121                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 122                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 123                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 124                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 125                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 126                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 127                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 128                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 129                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 130                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 131                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 132                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 133                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 134                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 135                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 136                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 137                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 138                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 139                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 140                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 141                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 142                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 143                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 144                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 145                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 146                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 147                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 148                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 149                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 150                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 151                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 152                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 153                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 154                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 155                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 156                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 157                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 158                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 159                                                                    ocean.fx.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
# 160                                                             ocean.1mon.nv:2.xt_ocean:360.xu_ocean:360.yt_ocean:300.yu_ocean:300
#
#     frequency            start_date              end_date  \
# 0          fx  1910-01-01, 00:00:00  1910-01-01, 00:00:00
# 1        1mon  1900-01-01, 00:00:00  1910-01-01, 00:00:00
# 2          fx  1920-01-01, 00:00:00  1920-01-01, 00:00:00
# 3        1mon  1910-01-01, 00:00:00  1920-01-01, 00:00:00
# 4          fx  1930-01-01, 00:00:00  1930-01-01, 00:00:00
# 5        1mon  1920-01-01, 00:00:00  1930-01-01, 00:00:00
# 6          fx  1940-01-01, 00:00:00  1940-01-01, 00:00:00
# 7        1mon  1930-01-01, 00:00:00  1940-01-01, 00:00:00
# 8          fx  1950-01-01, 00:00:00  1950-01-01, 00:00:00
# 9        1mon  1940-01-01, 00:00:00  1950-01-01, 00:00:00
# 10         fx  1960-01-01, 00:00:00  1960-01-01, 00:00:00
# 11       1mon  1950-01-01, 00:00:00  1960-01-01, 00:00:00
# 12         fx  1970-01-01, 00:00:00  1970-01-01, 00:00:00
# 13       1mon  1960-01-01, 00:00:00  1970-01-01, 00:00:00
# 14         fx  1980-01-01, 00:00:00  1980-01-01, 00:00:00
# 15       1mon  1970-01-01, 00:00:00  1980-01-01, 00:00:00
# 16         fx  1990-01-01, 00:00:00  1990-01-01, 00:00:00
# 17       1mon  1980-01-01, 00:00:00  1990-01-01, 00:00:00
# 18         fx  2000-01-01, 00:00:00  2000-01-01, 00:00:00
# 19       1mon  1990-01-01, 00:00:00  2000-01-01, 00:00:00
# 20         fx  2010-01-01, 00:00:00  2010-01-01, 00:00:00
# 21       1mon  2000-01-01, 00:00:00  2010-01-01, 00:00:00
# 22         fx  2020-01-01, 00:00:00  2020-01-01, 00:00:00
# 23       1mon  2010-01-01, 00:00:00  2020-01-01, 00:00:00
# 24         fx  2030-01-01, 00:00:00  2030-01-01, 00:00:00
# 25       1mon  2020-01-01, 00:00:00  2030-01-01, 00:00:00
# 26         fx  2040-01-01, 00:00:00  2040-01-01, 00:00:00
# 27       1mon  2030-01-01, 00:00:00  2040-01-01, 00:00:00
# 28         fx  2050-01-01, 00:00:00  2050-01-01, 00:00:00
# 29       1mon  2040-01-01, 00:00:00  2050-01-01, 00:00:00
# 30         fx  2060-01-01, 00:00:00  2060-01-01, 00:00:00
# 31       1mon  2050-01-01, 00:00:00  2060-01-01, 00:00:00
# 32         fx  2070-01-01, 00:00:00  2070-01-01, 00:00:00
# 33       1mon  2060-01-01, 00:00:00  2070-01-01, 00:00:00
# 34         fx  2080-01-01, 00:00:00  2080-01-01, 00:00:00
# 35       1mon  2070-01-01, 00:00:00  2080-01-01, 00:00:00
# 36         fx  2090-01-01, 00:00:00  2090-01-01, 00:00:00
# 37       1mon  2080-01-01, 00:00:00  2090-01-01, 00:00:00
# 38         fx  2100-01-01, 00:00:00  2100-01-01, 00:00:00
# 39       1mon  2090-01-01, 00:00:00  2100-01-01, 00:00:00
# 40         fx  2110-01-01, 00:00:00  2110-01-01, 00:00:00
# 41       1mon  2100-01-01, 00:00:00  2110-01-01, 00:00:00
# 42         fx  2120-01-01, 00:00:00  2120-01-01, 00:00:00
# 43       1mon  2110-01-01, 00:00:00  2120-01-01, 00:00:00
# 44         fx  2130-01-01, 00:00:00  2130-01-01, 00:00:00
# 45       1mon  2120-01-01, 00:00:00  2130-01-01, 00:00:00
# 46         fx  2140-01-01, 00:00:00  2140-01-01, 00:00:00
# 47       1mon  2130-01-01, 00:00:00  2140-01-01, 00:00:00
# 48         fx  2150-01-01, 00:00:00  2150-01-01, 00:00:00
# 49       1mon  2140-01-01, 00:00:00  2150-01-01, 00:00:00
# 50         fx  2160-01-01, 00:00:00  2160-01-01, 00:00:00
# 51       1mon  2150-01-01, 00:00:00  2160-01-01, 00:00:00
# 52         fx  2170-01-01, 00:00:00  2170-01-01, 00:00:00
# 53       1mon  2160-01-01, 00:00:00  2170-01-01, 00:00:00
# 54         fx  2180-01-01, 00:00:00  2180-01-01, 00:00:00
# 55       1mon  2170-01-01, 00:00:00  2180-01-01, 00:00:00
# 56         fx  2190-01-01, 00:00:00  2190-01-01, 00:00:00
# 57       1mon  2180-01-01, 00:00:00  2190-01-01, 00:00:00
# 58         fx  2200-01-01, 00:00:00  2200-01-01, 00:00:00
# 59       1mon  2190-01-01, 00:00:00  2200-01-01, 00:00:00
# 60        1yr  2200-01-01, 00:00:00  2210-01-01, 00:00:00
# 61         fx  2210-01-01, 00:00:00  2210-01-01, 00:00:00
# 62       1mon  2200-01-01, 00:00:00  2210-01-01, 00:00:00
# 63        1yr  2210-01-01, 00:00:00  2220-01-01, 00:00:00
# 64         fx  2220-01-01, 00:00:00  2220-01-01, 00:00:00
# 65       1mon  2210-01-01, 00:00:00  2220-01-01, 00:00:00
# 66        1yr  2220-01-01, 00:00:00  2230-01-01, 00:00:00
# 67         fx  2230-01-01, 00:00:00  2230-01-01, 00:00:00
# 68       1mon  2220-01-01, 00:00:00  2230-01-01, 00:00:00
# 69         fx  2240-01-01, 00:00:00  2240-01-01, 00:00:00
# 70       1mon  2230-01-01, 00:00:00  2240-01-01, 00:00:00
# 71         fx  2250-01-01, 00:00:00  2250-01-01, 00:00:00
# 72       1mon  2240-01-01, 00:00:00  2250-01-01, 00:00:00
# 73         fx  2260-01-01, 00:00:00  2260-01-01, 00:00:00
# 74       1mon  2250-01-01, 00:00:00  2260-01-01, 00:00:00
# 75         fx  2270-01-01, 00:00:00  2270-01-01, 00:00:00
# 76       1mon  2260-01-01, 00:00:00  2270-01-01, 00:00:00
# 77         fx  2280-01-01, 00:00:00  2280-01-01, 00:00:00
# 78       1mon  2270-01-01, 00:00:00  2280-01-01, 00:00:00
# 79         fx  2290-01-01, 00:00:00  2290-01-01, 00:00:00
# 80       1mon  2280-01-01, 00:00:00  2290-01-01, 00:00:00
# 81         fx  2300-01-01, 00:00:00  2300-01-01, 00:00:00
# 82       1mon  2290-01-01, 00:00:00  2300-01-01, 00:00:00
# 83         fx  2310-01-01, 00:00:00  2310-01-01, 00:00:00
# 84       1mon  2300-01-01, 00:00:00  2310-01-01, 00:00:00
# 85         fx  2320-01-01, 00:00:00  2320-01-01, 00:00:00
# 86       1mon  2310-01-01, 00:00:00  2320-01-01, 00:00:00
# 87         fx  2330-01-01, 00:00:00  2330-01-01, 00:00:00
# 88       1mon  2320-01-01, 00:00:00  2330-01-01, 00:00:00
# 89         fx  2340-01-01, 00:00:00  2340-01-01, 00:00:00
# 90       1mon  2330-01-01, 00:00:00  2340-01-01, 00:00:00
# 91         fx  2350-01-01, 00:00:00  2350-01-01, 00:00:00
# 92       1mon  2340-01-01, 00:00:00  2350-01-01, 00:00:00
# 93         fx  2360-01-01, 00:00:00  2360-01-01, 00:00:00
# 94       1mon  2350-01-01, 00:00:00  2360-01-01, 00:00:00
# 95         fx  2370-01-01, 00:00:00  2370-01-01, 00:00:00
# 96       1mon  2360-01-01, 00:00:00  2370-01-01, 00:00:00
# 97         fx  2380-01-01, 00:00:00  2380-01-01, 00:00:00
# 98       1mon  2370-01-01, 00:00:00  2380-01-01, 00:00:00
# 99         fx  2390-01-01, 00:00:00  2390-01-01, 00:00:00
# 100      1mon  2380-01-01, 00:00:00  2390-01-01, 00:00:00
# 101        fx  2400-01-01, 00:00:00  2400-01-01, 00:00:00
# 102      1mon  2390-01-01, 00:00:00  2400-01-01, 00:00:00
# 103        fx  2410-01-01, 00:00:00  2410-01-01, 00:00:00
# 104      1mon  2400-01-01, 00:00:00  2410-01-01, 00:00:00
# 105       1yr  2410-01-01, 00:00:00  2420-01-01, 00:00:00
# 106        fx  2420-01-01, 00:00:00  2420-01-01, 00:00:00
# 107      1mon  2410-01-01, 00:00:00  2420-01-01, 00:00:00
# 108       1yr  2411-01-01, 00:00:00  2421-01-01, 00:00:00
# 109        fx  2430-01-01, 00:00:00  2430-01-01, 00:00:00
# 110      1mon  2420-01-01, 00:00:00  2430-01-01, 00:00:00
# 111        fx  2440-01-01, 00:00:00  2440-01-01, 00:00:00
# 112      1mon  2430-01-01, 00:00:00  2440-01-01, 00:00:00
# ...
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 95   ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 96   ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 97   ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 98   ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 99   ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 100  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 101  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 102  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 103  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 104  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 105  ['yr' 'days' 'days since 1900-01-01 00:00:00'
#  'days since 1900-01-01 00:00:00' 'm^2/s' 'm' 'none' 'kg/m^3' 'psu'
#  'meters' 'meters' 'meters' 'meters' 'K' 'days since 1900-01-01 00:00:00'
#  'days' ...
# 106  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 107  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' 'm' 'Watts/m^2' 'none' 'days since 1900-01-01 00:00:00' 'days'
#  'kg/s' 'kg/s' 'degrees_E' 'degrees_E' 'degrees_N'...
# 108                                                                                                       ['m' 'none' 'meters' 'meters' 'K' 'days since 1900-01-01 00:00:00' 'm^3'
#  'degrees_E' 'degrees_N']
# 109  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 110  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 111  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 112  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 113  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 114  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 115  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 116  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 117  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 118  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 119  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 120  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 121  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 122  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 123  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 124  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 125  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 126  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 127  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 128  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 129  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 130  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 131  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 132  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 133  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 134  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 135  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 136  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 137  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 138  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 139  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 140  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 141  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 142  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 143  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 144  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 145  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 146  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 147  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 148  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 149  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 150  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 151  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 152  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 153  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 154  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 155  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 156  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 157  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 158  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
# 159  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
# 160  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'N/m^2' 'N/m^2' 'meter' '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)'
#  '(kg/m^3)*(m/sec)' 'm' 'Watts/m^2' 'none' 'dbar' '...
#
#      realm
# 0    ocean
# 1    ocean
# 2    ocean
# 3    ocean
# 4    ocean
# 5    ocean
# 6    ocean
# 7    ocean
# 8    ocean
# 9    ocean
# 10   ocean
# 11   ocean
# 12   ocean
# 13   ocean
# 14   ocean
# 15   ocean
# 16   ocean
# 17   ocean
# 18   ocean
# 19   ocean
# 20   ocean
# 21   ocean
# 22   ocean
# 23   ocean
# 24   ocean
# 25   ocean
# 26   ocean
# 27   ocean
# 28   ocean
# 29   ocean
# 30   ocean
# 31   ocean
# 32   ocean
# 33   ocean
# 34   ocean
# 35   ocean
# 36   ocean
# 37   ocean
# 38   ocean
# 39   ocean
# 40   ocean
# 41   ocean
# 42   ocean
# 43   ocean
# 44   ocean
# 45   ocean
# 46   ocean
# 47   ocean
# 48   ocean
# 49   ocean
# 50   ocean
# 51   ocean
# 52   ocean
# 53   ocean
# 54   ocean
# 55   ocean
# 56   ocean
# 57   ocean
# 58   ocean
# 59   ocean
# 60   ocean
# 61   ocean
# 62   ocean
# 63   ocean
# 64   ocean
# 65   ocean
# 66   ocean
# 67   ocean
# 68   ocean
# 69   ocean
# 70   ocean
# 71   ocean
# 72   ocean
# 73   ocean
# 74   ocean
# 75   ocean
# 76   ocean
# 77   ocean
# 78   ocean
# 79   ocean
# 80   ocean
# 81   ocean
# 82   ocean
# 83   ocean
# 84   ocean
# 85   ocean
# 86   ocean
# 87   ocean
# 88   ocean
# 89   ocean
# 90   ocean
# 91   ocean
# 92   ocean
# 93   ocean
# 94   ocean
# 95   ocean
# 96   ocean
# 97   ocean
# 98   ocean
# 99   ocean
# 100  ocean
# 101  ocean
# 102  ocean
# 103  ocean
# 104  ocean
# 105  ocean
# 106  ocean
# 107  ocean
# 108  ocean
# 109  ocean
# 110  ocean
# 111  ocean
# 112  ocean
# 113  ocean
# 114  ocean
# 115  ocean
# 116  ocean
# 117  ocean
# 118  ocean
# 119  ocean
# 120  ocean
# 121  ocean
# 122  ocean
# 123  ocean
# 124  ocean
# 125  ocean
# 126  ocean
# 127  ocean
# 128  ocean
# 129  ocean
# 130  ocean
# 131  ocean
# 132  ocean
# 133  ocean
# 134  ocean
# 135  ocean
# 136  ocean
# 137  ocean
# 138  ocean
# 139  ocean
# 140  ocean
# 141  ocean
# 142  ocean
# 143  ocean
# 144  ocean
# 145  ocean
# 146  ocean
# 147  ocean
# 148  ocean
# 149  ocean
# 150  ocean
# 151  ocean
# 152  ocean
# 153  ocean
# 154  ocean
# 155  ocean
# 156  ocean
# 157  ocean
# 158  ocean
# 159  ocean
# 160  ocean

# %%
esm_datastore = catalog["01deg_jra55v13_ryf9091"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_dataframe_catalog/core.py:177, in DfFileCatalog.__getitem__(self, key)
#     176 try:
# --> 177     return self._entries[key]
#     178 except KeyError as e:
#
# KeyError: '01deg_jra55v13_ryf9091'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 esm_datastore = catalog["01deg_jra55v13_ryf9091"]
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_dataframe_catalog/core.py:191, in DfFileCatalog.__getitem__(self, key)
#     186     if len(yamls) > 1:
#     187         assert all(y == yaml_text for y in yamls)
#     189     self._entries[key] = LocalCatalogEntry(
#     190         name=key, **yaml.safe_load(yaml_text)["sources"][key]
# --> 191     ).get()
#     192     return self._entries[key]
#     193 raise KeyError(
#     194     f"key='{key}' not found in catalog. You can access the list of valid source keys via the .keys() method."
#     195 ) from e
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake/catalog/local.py:313, in LocalCatalogEntry.get(self, **user_parameters)
#     310     return self._default_source
#     312 plugin, open_args = self._create_open_args(user_parameters)
# --> 313 data_source = plugin(**open_args)
#     314 data_source.catalog_object = self._catalog
#     315 data_source.name = self.name
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:124, in esm_datastore.__init__(self, obj, progressbar, sep, registry, read_csv_kwargs, columns_with_iterables, storage_options, threaded, **intake_kwargs)
#     122     self.esmcat = ESMCatalogModel.from_dict(obj)
#     123 else:
# --> 124     self.esmcat = ESMCatalogModel.load(
#     125         obj, storage_options=self.storage_options, read_csv_kwargs=read_csv_kwargs
#     126     )
#     128 self.derivedcat = registry or default_registry
#     129 self._entries = {}
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/cat.py:257, in ESMCatalogModel.load(cls, json_file, storage_options, read_csv_kwargs)
#     255 cat = cls.model_validate(data)
#     256 if cat.catalog_file:
# --> 257     cat._frames = cat._df_from_file(cat, _mapper, storage_options, read_csv_kwargs)
#     258 else:
#     259     cat._frames = FramesModel(
#     260         lf=pl.LazyFrame(cat.catalog_dict),
#     261         pl_df=pl.DataFrame(cat.catalog_dict),
#     262         df=pl.DataFrame(cat.catalog_dict).to_pandas(),
#     263     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/cat.py:318, in ESMCatalogModel._df_from_file(self, cat, _mapper, storage_options, read_csv_kwargs)
#     310     converters = read_csv_kwargs.pop('converters', {})  # Hack
#     311     # See https://github.com/pola-rs/polars/issues/13040 - can't use read_csv.
#     312     lf = pl.scan_csv(
#     313         cat.catalog_file,  # type: ignore[arg-type]
#     314         storage_options=storage_options,
#     315         infer_schema=False,
#     316         **read_csv_kwargs,
#     317     ).with_columns(
# --> 318         [
#     319             pl.col(colname)
#     320             .str.replace('^.', '[')  # Replace first/last chars with [ or ].
#     321             .str.replace('.$', ']')  # set/tuple => list
#     322             .str.replace_all("'", '"')
#     323             .str.json_decode()  # This is to do with the way polars reads json - single versus double quotes
#     324             for colname in converters.keys()
#     325         ]
#     326     )
#     327     return FramesModel(lf=lf)
#     328 else:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/cat.py:323, in <listcomp>(.0)
#     310     converters = read_csv_kwargs.pop('converters', {})  # Hack
#     311     # See https://github.com/pola-rs/polars/issues/13040 - can't use read_csv.
#     312     lf = pl.scan_csv(
#     313         cat.catalog_file,  # type: ignore[arg-type]
#     314         storage_options=storage_options,
#     315         infer_schema=False,
#     316         **read_csv_kwargs,
#     317     ).with_columns(
#     318         [
#     319             pl.col(colname)
#     320             .str.replace('^.', '[')  # Replace first/last chars with [ or ].
#     321             .str.replace('.$', ']')  # set/tuple => list
#     322             .str.replace_all("'", '"')
# --> 323             .str.json_decode()  # This is to do with the way polars reads json - single versus double quotes
#     324             for colname in converters.keys()
#     325         ]
#     326     )
#     327     return FramesModel(lf=lf)
#     328 else:
#
# TypeError: ExprStringNameSpace.json_decode() missing 1 required positional argument: 'dtype'

# %%
esm_datastore
# Out:
# <p><strong>01deg_jra55v13_ryf9091 catalog with 22 dataset(s) from 11947 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>3469</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>11947</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>3361</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>3360</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>197</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import re

# %%
[f'{y}-{m:02d}-01, 00:00:00' for y in range(2030, 2040) for m in range(1, 13, 3)]
# Out:
# ['2030-01-01, 00:00:00',
#  '2030-04-01, 00:00:00',
#  '2030-07-01, 00:00:00',
#  '2030-10-01, 00:00:00',
#  '2031-01-01, 00:00:00',
#  '2031-04-01, 00:00:00',
#  '2031-07-01, 00:00:00',
#  '2031-10-01, 00:00:00',
#  '2032-01-01, 00:00:00',
#  '2032-04-01, 00:00:00',
#  '2032-07-01, 00:00:00',
#  '2032-10-01, 00:00:00',
#  '2033-01-01, 00:00:00',
#  '2033-04-01, 00:00:00',
#  '2033-07-01, 00:00:00',
#  '2033-10-01, 00:00:00',
#  '2034-01-01, 00:00:00',
#  '2034-04-01, 00:00:00',
#  '2034-07-01, 00:00:00',
#  '2034-10-01, 00:00:00',
#  '2035-01-01, 00:00:00',
#  '2035-04-01, 00:00:00',
#  '2035-07-01, 00:00:00',
#  '2035-10-01, 00:00:00',
#  '2036-01-01, 00:00:00',
#  '2036-04-01, 00:00:00',
#  '2036-07-01, 00:00:00',
#  '2036-10-01, 00:00:00',
#  '2037-01-01, 00:00:00',
#  '2037-04-01, 00:00:00',
#  '2037-07-01, 00:00:00',
#  '2037-10-01, 00:00:00',
#  '2038-01-01, 00:00:00',
#  '2038-04-01, 00:00:00',
#  '2038-07-01, 00:00:00',
#  '2038-10-01, 00:00:00',
#  '2039-01-01, 00:00:00',
#  '2039-04-01, 00:00:00',
#  '2039-07-01, 00:00:00',
#  '2039-10-01, 00:00:00']

# %%
esm_datastore_filtered = esm_datastore.search(
    # variable=["tx_trans", "ty_trans"], frequency="1mon", require_all_on="path",
    # variable=["tx_trans", "ty_trans"],
    variable=["tx_trans", "ty_trans"],
    frequency="1mon",
    require_all_on="path",
    # start_date='2030-01-01, 00:00:00',
    # start_date=[f'{y}-{m:02d}-01, 00:00:00' for y in range(2030, 2040) for m in range(1, 13, 3)], # Maybe select less data to start with?
    # start_date="203.*", # Maybe select less data to start with?
    # start_date=[f'{y}' for y in range(2030, 2040)], # Maybe select less data to start with?
    # path=".*output100.*"
)

# %%
esm_datastore_filtered
# Out:
# <p><strong>01deg_jra55v13_ryf9091 catalog with 1 dataset(s) from 920 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>920</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>920</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>920</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from distributed import Client

client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:42813' processes=28 threads=28, memory=125.19 GiB>

# %%
# xarray_open_kwargs = {
#     "chunks": {
#         "time": 3, # that size should give ~300 Mib chunks, but it has to happen after (as it's stored in chunks of 3)
#         "st_ocean": 7,
#         "xt_ocean": 400,
#         "yt_ocean": 300,
#         "xu_ocean": 400,
#         "yu_ocean": 300,
#     },
#     "decode_timedelta": False,
# }
xarray_open_kwargs = {"chunks": {"time": -1, "st_ocean": 7, "xt_ocean": 400, "yt_ocean": 300, "xu_ocean": 400, "yu_ocean": 300}, "decode_timedelta": False,}

# %%
ds = esm_datastore_filtered.to_dask(xarray_open_kwargs=xarray_open_kwargs).chunk(chunks={"time": 120,})
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
time = slice("2030", "2039")

# %%
ds_sel = ds.sel(time=time)

# %%
tx_trans_sel = ds_sel["tx_trans"]
# ty_trans_sel = ds_sel["ty_trans"]
tx_trans_sel

# %%
# tx_trans_mean = tx_trans_sel.weighted(tx_trans_sel.time.dt.days_in_month).mean(dim="time")
tx_trans_mean = tx_trans_sel.mean(dim="time")
tx_trans_mean
# Out:
# <xarray.DataArray 'tx_trans' (st_ocean: 75, yt_ocean: 2700, xu_ocean: 3600)> Size: 3GB
# dask.array<mean_agg-aggregate, shape=(75, 2700, 3600), dtype=float32, chunksize=(7, 300, 400), chunktype=numpy.ndarray>
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
#   * st_ocean  (st_ocean) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * xu_ocean  (xu_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.8 79.9 80.0

# %%
# tx_trans_sel.time.dt.days_in_month

# %%
# ty_trans_mean = ty_trans_sel.weighted(ty_trans_sel.time.dt.days_in_month).mean(dim="time")
# ty_trans_mean

# %%
# Saving to: NetCDF:
outputdir = "/scratch/y99/bp3051/hiresTM"

# %%
# tx_trans_mean.to_netcdf(f'{outputdir}/tx_trans.nc', compute=True)
tx_trans_mean.to_netcdf(f'{outputdir}/tx_trans.nc')

# %%
ty_trans_mean.to_netcdf(f'{outputdir}/ty_trans.nc')
