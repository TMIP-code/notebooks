# %%
import intake
catalog = intake.cat.access_nri

# %%
catalog
# Out:
# <p><strong>access_nri catalog with 119 source(s) across 2568 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{tx_trans_nrho, neutral, ty_trans, pme_river, temp_vdiffuse_diff_cbt_on_nrho, nv, aice_m, alidf_ai_m, geolon_t, pme_net, ty_trans_nrho, sw_heat_on_nrho, wt, opening_m, hi_m, divu_m, sfc_hflux_pme_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, frazil_3d, alvd...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, frazil_3d, alvd...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{3hr, 3mon, 1mon, fx, 1day}</td>
#       <td>{yt_ocean_sub02, pot_rho_0, passive_weddell, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, alvd...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, alvd...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, alvd...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, alvd...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{pot_rho_0, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, frazil_3d, al...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{pot_rho_0, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_heat, fswup_m, frazil_3d, al...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, passive_weddell, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_he...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, passive_weddell, neutral, ty_trans, pme_river, nv, aice_m, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, fsalt_ai_m, fmeltt_ai_m, total_ocean_runoff_he...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, neutral, ty_trans, vicen, pme_river, daidtd_m, nv, aice_m, mh_flux, alidf_ai_m, geolon_t, pme_net, hi_m, opening_m, wt, divu_m, HTN, u, strairy_m, hi, dvidtt_m, fsalt_ai_m, fmeltt_ai_m...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{pot_rho_0, neutral, ty_trans, vicen, pme_river, daidtd_m, nv, aice_m, mh_flux, alidf_ai_m, geolon_

# %%
# catalog.interactive

# %%
variable=[
    "tx_trans", "ty_trans", 
    # "tx_trans_gm", "ty_trans_gm", 
    # "tx_trans_submeso", "ty_trans_submeso",
    # "mlotst", "volcello", "areacello",
    # "mld", "area_t",
    "mld", "area_t", "dzt",
]

# %%
variables_set = set(variable)
variables_set
# Out:
# {'area_t', 'dzt', 'mld', 'tx_trans', 'ty_trans'}

# %%
# Define our query
query = dict(
    model="ACCESS-OM2.*",
    # description=re.compile('.*0.1 degree.*'),
    # description='[^.]*1(?: degree|°).*',
    # name='.*ryf.*',
    variable=variable,
    # frequency="1mon",
)
query
# Out:
# {'model': 'ACCESS-OM2.*',
#  'variable': ['tx_trans', 'ty_trans', 'mld', 'area_t', 'dzt']}

# %%
catalog.search(**query)
# Out:
# <p><strong>Intake dataframe catalog with 85 source(s) across 179 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{mld, dzt, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{mld, dzt, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{mld, dzt, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{3mon, 1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{mld, dzt, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{mld, dzt, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle3</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 3 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 6hr, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, subhr, 1day}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v150_iaf_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{dzt, mld, area_t, tx_trans, ty_trans}</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1980-2021)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{area_t, mld}</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{dzt, area_t, mld}</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0\ninterannual forcing (1980-2019)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, fx, 1day}</td>
#       <td>{area_t, mld}</td>
#     </tr>
#     <tr>
#       <th>025deg_

# %%
df = catalog.search(**query).df
df = df.groupby('name', as_index=False)['variable'].sum()
df['variable'] = df['variable'].apply(lambda x: set(x))
df
# Out:
#                                                  name  \
# 0                             01deg_jra55_ryf_Control
# 1                              01deg_jra55_ryf_ENFull
# 2                              01deg_jra55_ryf_LNFull
# 3                              01deg_jra55v13_ryf9091
# 4            01deg_jra55v13_ryf9091_easterlies_down10
# 5              01deg_jra55v13_ryf9091_easterlies_up10
# 6   01deg_jra55v13_ryf9091_easterlies_up10_meridional
# 7        01deg_jra55v13_ryf9091_easterlies_up10_zonal
# 8                   01deg_jra55v13_ryf9091_qian_wthmp
# 9                    01deg_jra55v13_ryf9091_qian_wthp
# 10               01deg_jra55v13_ryf9091_weddell_down2
# 11                 01deg_jra55v13_ryf9091_weddell_up1
# 12                                01deg_jra55v140_iaf
# 13                         01deg_jra55v140_iaf_cycle2
# 14                         01deg_jra55v140_iaf_cycle3
# 15                         01deg_jra55v140_iaf_cycle4
# 16     01deg_jra55v140_iaf_cycle4_jra55v150_extension
# 17                         01deg_jra55v150_iaf_cycle1
# 18                                    025deg_era5_iaf
# 19                                    025deg_era5_ryf
# 20                    025deg_jra55_iaf_era5comparison
# 21                      025deg_jra55_iaf_omip2_cycle1
# 22                      025deg_jra55_iaf_omip2_cycle2
# 23                      025deg_jra55_iaf_omip2_cycle3
# 24                      025deg_jra55_iaf_omip2_cycle4
# 25                      025deg_jra55_iaf_omip2_cycle5
# 26                      025deg_jra55_iaf_omip2_cycle6
# 27                          025deg_jra55_ryf9091_gadi
# 28                    025deg_jra55_ryf_era5comparison
# 29                                      1deg_era5_iaf
# 30                                      1deg_era5_ryf
# 31                      1deg_jra55_iaf_era5comparison
# 32                        1deg_jra55_iaf_omip2_cycle1
# 33                        1deg_jra55_iaf_omip2_cycle2
# 34                        1deg_jra55_iaf_omip2_cycle3
# 35                        1deg_jra55_iaf_omip2_cycle4
# 36                        1deg_jra55_iaf_omip2_cycle5
# 37                        1deg_jra55_iaf_omip2_cycle6
# 38                  1deg_jra55_iaf_omip2spunup_cycle1
# 39                 1deg_jra55_iaf_omip2spunup_cycle10
# 40                 1deg_jra55_iaf_omip2spunup_cycle11
# 41                 1deg_jra55_iaf_omip2spunup_cycle12
# 42                 1deg_jra55_iaf_omip2spunup_cycle13
# 43                 1deg_jra55_iaf_omip2spunup_cycle14
# 44                 1deg_jra55_iaf_omip2spunup_cycle15
# 45                 1deg_jra55_iaf_omip2spunup_cycle16
# 46                 1deg_jra55_iaf_omip2spunup_cycle17
# 47                 1deg_jra55_iaf_omip2spunup_cycle18
# 48                 1deg_jra55_iaf_omip2spunup_cycle19
# 49                  1deg_jra55_iaf_omip2spunup_cycle2
# 50                 1deg_jra55_iaf_omip2spunup_cycle20
# 51                 1deg_jra55_iaf_omip2spunup_cycle21
# 52                 1deg_jra55_iaf_omip2spunup_cycle22
# 53                 1deg_jra55_iaf_omip2spunup_cycle23
# 54                 1deg_jra55_iaf_omip2spunup_cycle24
# 55                 1deg_jra55_iaf_omip2spunup_cycle25
# 56                 1deg_jra55_iaf_omip2spunup_cycle26
# 57                 1deg_jra55_iaf_omip2spunup_cycle27
# 58                 1deg_jra55_iaf_omip2spunup_cycle28
# 59                 1deg_jra55_iaf_omip2spunup_cycle29
# 60                  1deg_jra55_iaf_omip2spunup_cycle3
# 61                 1deg_jra55_iaf_omip2spunup_cycle30
# 62                 1deg_jra55_iaf_omip2spunup_cycle31
# 63                 1deg_jra55_iaf_omip2spunup_cycle32
# 64                 1deg_jra55_iaf_omip2spunup_cycle33
# 65                 1deg_jra55_iaf_omip2spunup_cycle34
# 66                 1deg_jra55_iaf_omip2spunup_cycle35
# 67                 1deg_jra55_iaf_omip2spunup_cycle36
# 68                 1deg_jra55_iaf_omip2spunup_cycle37
# 69                 1deg_jra55_iaf_omip2spunup_cycle38
# 70                 1deg_jra55_iaf_omip2spunup_cycle39
# 71                  1deg_jra55_iaf_omip2spunup_cycle4
# 72                 1deg_jra55_iaf_omip2spunup_cycle40
# 73                 1deg_jra55_iaf_omip2spunup_cycle41
# 74                 1deg_jra55_iaf_omip2spunup_cycle42
# 75                 1deg_jra55_iaf_omip2spunup_cycle43
# 76                 1deg_jra55_iaf_omip2spunup_cycle44
# 77                 1deg_jra55_iaf_omip2spunup_cycle45
# 78                  1deg_jra55_iaf_omip2spunup_cycle5
# 79                  1deg_jra55_iaf_omip2spunup_cycle6
# 80                  1deg_jra55_iaf_omip2spunup_cycle7
# 81                  1deg_jra55_iaf_omip2spunup_cycle8
# 82                  1deg_jra55_iaf_omip2spunup_cycle9
# 83                            1deg_jra55_ryf9091_gadi
# 84                                  1deg_jra55v14_ryf
#
#                                   variable
# 0   {mld, dzt, area_t, tx_trans, ty_trans}
# 1   {mld, dzt, area_t, tx_trans, ty_trans}
# 2   {mld, dzt, area_t, tx_trans, ty_trans}
# 3   {dzt, mld, area_t, tx_trans, ty_trans}
# 4   {dzt, mld, area_t, tx_trans, ty_trans}
# 5   {dzt, mld, area_t, tx_trans, ty_trans}
# 6   {dzt, mld, area_t, tx_trans, ty_trans}
# 7   {dzt, mld, area_t, tx_trans, ty_trans}
# 8   {mld, dzt, area_t, tx_trans, ty_trans}
# 9   {mld, dzt, area_t, tx_trans, ty_trans}
# 10  {dzt, mld, area_t, tx_trans, ty_trans}
# 11  {dzt, mld, area_t, tx_trans, ty_trans}
# 12  {dzt, mld, area_t, tx_trans, ty_trans}
# 13  {dzt, mld, area_t, tx_trans, ty_trans}
# 14  {dzt, mld, area_t, tx_trans, ty_trans}
# 15  {dzt, mld, area_t, tx_trans, ty_trans}
# 16  {dzt, mld, area_t, tx_trans, ty_trans}
# 17  {dzt, mld, area_t, tx_trans, ty_trans}
# 18                           {area_t, mld}
# 19                      {dzt, area_t, mld}
# 20                           {area_t, mld}
# 21       {tx_trans, area_t, mld, ty_trans}
# 22       {tx_trans, area_t, mld, ty_trans}
# 23       {tx_trans, area_t, mld, ty_trans}
# 24       {tx_trans, area_t, mld, ty_trans}
# 25       {tx_trans, area_t, mld, ty_trans}
# 26       {tx_trans, area_t, mld, ty_trans}
# 27  {dzt, mld, area_t, tx_trans, ty_trans}
# 28                      {dzt, area_t, mld}
# 29  {dzt, mld, area_t, tx_trans, ty_trans}
# 30                      {dzt, area_t, mld}
# 31  {dzt, mld, area_t, tx_trans, ty_trans}
# 32       {tx_trans, area_t, mld, ty_trans}
# 33       {tx_trans, area_t, mld, ty_trans}
# 34       {tx_trans, area_t, mld, ty_trans}
# 35       {tx_trans, area_t, mld, ty_trans}
# 36       {tx_trans, area_t, mld, ty_trans}
# 37       {tx_trans, area_t, mld, ty_trans}
# 38       {tx_trans, area_t, mld, ty_trans}
# 39                                   {mld}
# 40                                   {mld}
# 41                                   {mld}
# 42                                   {mld}
# 43                                   {mld}
# 44                                   {mld}
# 45                                   {mld}
# 46                                   {mld}
# 47                                   {mld}
# 48                                   {mld}
# 49       {tx_trans, area_t, mld, ty_trans}
# 50                                   {mld}
# 51                                   {mld}
# 52                                   {mld}
# 53                                   {mld}
# 54                                   {mld}
# 55                                   {mld}
# 56                                   {mld}
# 57                                   {mld}
# 58                                   {mld}
# 59                                   {mld}
# 60       {tx_trans, area_t, mld, ty_trans}
# 61                                   {mld}
# 62                                   {mld}
# 63                                   {mld}
# 64                                   {mld}
# 65       {tx_trans, area_t, mld, ty_trans}
# 66       {tx_trans, area_t, mld, ty_trans}
# 67       {tx_trans, area_t, mld, ty_trans}
# 68       {tx_trans, area_t, mld, ty_trans}
# 69       {tx_trans, area_t, mld, ty_trans}
# 70       {tx_trans, area_t, mld, ty_trans}
# 71       {tx_trans, area_t, mld, ty_trans}
# 72                                   {mld}
# 73                                   {mld}
# 74                                   {mld}
# 75                                   {mld}
# 76                                   {mld}
# 77                                   {mld}
# 78       {tx_trans, area_t, mld, ty_trans}
# 79       {tx_trans, area_t, mld, ty_trans}
# 80                                   {mld}
# 81                                   {mld}
# 82                                   {mld}
# 83  {dzt, mld, area_t, tx_trans, ty_trans}
# 84                      {dzt, area_t, mld}

# %%
# all in one
variable=[
    "tx_trans", "ty_trans", 
    # "tx_trans_gm", "ty_trans_gm", 
    # "tx_trans_submeso", "ty_trans_submeso",
    "mld", "area_t", "dzt",
]

variables_set = set(variable)

query = dict(model="ACCESS-OM2.*", variable=variable)

df = catalog.search(**query).df
df = df.groupby('name', as_index=False)['variable'].sum()
df['variable'] = df['variable'].apply(lambda x: set(x))

filtered_df = df[df['variable'].apply(lambda x: variables_set.issubset(x))]
filtered_df.name
# Out:
# 0                               01deg_jra55_ryf_Control
# 1                                01deg_jra55_ryf_ENFull
# 2                                01deg_jra55_ryf_LNFull
# 3                                01deg_jra55v13_ryf9091
# 4              01deg_jra55v13_ryf9091_easterlies_down10
# 5                01deg_jra55v13_ryf9091_easterlies_up10
# 6     01deg_jra55v13_ryf9091_easterlies_up10_meridional
# 7          01deg_jra55v13_ryf9091_easterlies_up10_zonal
# 8                     01deg_jra55v13_ryf9091_qian_wthmp
# 9                      01deg_jra55v13_ryf9091_qian_wthp
# 10                 01deg_jra55v13_ryf9091_weddell_down2
# 11                   01deg_jra55v13_ryf9091_weddell_up1
# 12                                  01deg_jra55v140_iaf
# 13                           01deg_jra55v140_iaf_cycle2
# 14                           01deg_jra55v140_iaf_cycle3
# 15                           01deg_jra55v140_iaf_cycle4
# 16       01deg_jra55v140_iaf_cycle4_jra55v150_extension
# 17                           01deg_jra55v150_iaf_cycle1
# 27                            025deg_jra55_ryf9091_gadi
# 29                                        1deg_era5_iaf
# 31                        1deg_jra55_iaf_era5comparison
# 83                              1deg_jra55_ryf9091_gadi
# Name: name, dtype: object

# %%
subcatalog = catalog["01deg_jra55v13_ryf9091_qian_wthmp"]
subcatalog.metadata
# Out:
# {'contact': 'Qian Li',
#  'created': '2022-06-11',
#  'description': 'Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w',
#  'email': 'qian_li@mit.edu',
#  'experiment_uuid': '27099610-2f2b-4560-808c-c6f432b605f0',
#  'keywords': ['tenth',
#   'cosima',
#   'access-om2-01',
#   'jra55-do-v1.3',
#   'ryf',
#   'future'],
#  'license': 'Attribution-NonCommercial-NoDerivatives 4.0 International (https://creativecommons.org/licenses/by-nc-nd/4.0/legalcode)',
#  'long_description': '0.1 degree ACCESS-OM2 global model configuration, forced with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) plus time-ramped, zonal-average wind, air  temperature and longwave forcing anomalies from JRA55-do v1.3 interannual (1991-2019)  and CMIP6 multi-model mean SSP5-8.5 (2020-2050). Plus increasing meltwater from Greenland  and Antarctica are linearly added to the runoff over 2001-2050 based on RCP8.5 projections.  This branches off a 200 year spinup of 01deg_jra55v13_ryf9091. More details on the  forcing applied and simulation response in https://www.nature.com/articles/s41586-023-05762-w',
#  'model': ['ACCESS-OM2'],
#  'name': '01deg_jra55v13_ryf9091_qian_wthmp',
#  'nominal_resolution': ['0.1 degrees'],
#  'notes': None,
#  'parent_experiment': '01deg_jra55v13_ryf9091',
#  'reference': None,
#  'related_experiments': [None],
#  'url': 'https://github.com/COSIMA/01deg_jra55_ryf/tree/01deg_jra55v13_ryf9091',
#  'version': 1,
#  'catalog_dir': ''}

# %%
subcatalog.search(variable=variable)
# Out:
# <p><strong>01deg_jra55v13_ryf9091_qian_wthp catalog with 3 dataset(s) from 720 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>720</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>241</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import numpy
numpy.sort(subcatalog.search(variable=variable).df.start_date.unique())
# Out:
# array(['2110-01-01, 00:00:00', '2110-04-01, 00:00:00',
#        '2110-07-01, 00:00:00', '2110-10-01, 00:00:00',
#        '2111-01-01, 00:00:00', '2111-04-01, 00:00:00',
#        '2111-07-01, 00:00:00', '2111-10-01, 00:00:00',
#        '2112-01-01, 00:00:00', '2112-04-01, 00:00:00',
#        '2112-07-01, 00:00:00', '2112-10-01, 00:00:00',
#        '2113-01-01, 00:00:00', '2113-04-01, 00:00:00',
#        '2113-07-01, 00:00:00', '2113-10-01, 00:00:00',
#        '2114-01-01, 00:00:00', '2114-04-01, 00:00:00',
#        '2114-07-01, 00:00:00', '2114-10-01, 00:00:00',
#        '2115-01-01, 00:00:00', '2115-04-01, 00:00:00',
#        '2115-07-01, 00:00:00', '2115-10-01, 00:00:00',
#        '2116-01-01, 00:00:00', '2116-04-01, 00:00:00',
#        '2116-07-01, 00:00:00', '2116-10-01, 00:00:00',
#        '2117-01-01, 00:00:00', '2117-04-01, 00:00:00',
#        '2117-07-01, 00:00:00', '2117-10-01, 00:00:00',
#        '2118-01-01, 00:00:00', '2118-04-01, 00:00:00',
#        '2118-07-01, 00:00:00', '2118-10-01, 00:00:00',
#        '2119-01-01, 00:00:00', '2119-04-01, 00:00:00',
#        '2119-07-01, 00:00:00', '2119-10-01, 00:00:00',
#        '2120-01-01, 00:00:00', '2120-04-01, 00:00:00',
#        '2120-07-01, 00:00:00', '2120-10-01, 00:00:00',
#        '2121-01-01, 00:00:00', '2121-04-01, 00:00:00',
#        '2121-07-01, 00:00:00', '2121-10-01, 00:00:00',
#        '2122-01-01, 00:00:00', '2122-04-01, 00:00:00',
#        '2122-07-01, 00:00:00', '2122-10-01, 00:00:00',
#        '2123-01-01, 00:00:00', '2123-04-01, 00:00:00',
#        '2123-07-01, 00:00:00', '2123-10-01, 00:00:00',
#        '2124-01-01, 00:00:00', '2124-04-01, 00:00:00',
#        '2124-07-01, 00:00:00', '2124-10-01, 00:00:00',
#        '2125-01-01, 00:00:00', '2125-04-01, 00:00:00',
#        '2125-07-01, 00:00:00', '2125-10-01, 00:00:00',
#        '2126-01-01, 00:00:00', '2126-04-01, 00:00:00',
#        '2126-07-01, 00:00:00', '2126-10-01, 00:00:00',
#        '2127-01-01, 00:00:00', '2127-04-01, 00:00:00',
#        '2127-07-01, 00:00:00', '2127-10-01, 00:00:00',
#        '2128-01-01, 00:00:00', '2128-04-01, 00:00:00',
#        '2128-07-01, 00:00:00', '2128-10-01, 00:00:00',
#        '2129-01-01, 00:00:00', '2129-04-01, 00:00:00',
#        '2129-07-01, 00:00:00', '2129-10-01, 00:00:00',
#        '2130-01-01, 00:00:00', '2130-04-01, 00:00:00',
#        '2130-07-01, 00:00:00', '2130-10-01, 00:00:00',
#        '2131-01-01, 00:00:00', '2131-04-01, 00:00:00',
#        '2131-07-01, 00:00:00', '2131-10-01, 00:00:00',
#        '2132-01-01, 00:00:00', '2132-04-01, 00:00:00',
#        '2132-07-01, 00:00:00', '2132-10-01, 00:00:00',
#        '2133-01-01, 00:00:00', '2133-04-01, 00:00:00',
#        '2133-07-01, 00:00:00', '2133-10-01, 00:00:00',
#        '2134-01-01, 00:00:00', '2134-04-01, 00:00:00',
#        '2134-07-01, 00:00:00', '2134-10-01, 00:00:00',
#        '2135-01-01, 00:00:00', '2135-04-01, 00:00:00',
#        '2135-07-01, 00:00:00', '2135-10-01, 00:00:00',
#        '2136-01-01, 00:00:00', '2136-04-01, 00:00:00',
#        '2136-07-01, 00:00:00', '2136-10-01, 00:00:00',
#        '2137-01-01, 00:00:00', '2137-04-01, 00:00:00',
#        '2137-07-01, 00:00:00', '2137-10-01, 00:00:00',
#        '2138-01-01, 00:00:00', '2138-04-01, 00:00:00',
#        '2138-07-01, 00:00:00', '2138-10-01, 00:00:00',
#        '2139-01-01, 00:00:00', '2139-04-01, 00:00:00',
#        '2139-07-01, 00:00:00', '2139-10-01, 00:00:00',
#        '2140-01-01, 00:00:00', '2140-04-01, 00:00:00',
#        '2140-07-01, 00:00:00', '2140-10-01, 00:00:00',
#        '2141-01-01, 00:00:00', '2141-04-01, 00:00:00',
#        '2141-07-01, 00:00:00', '2141-10-01, 00:00:00',
#        '2142-01-01, 00:00:00', '2142-04-01, 00:00:00',
#        '2142-07-01, 00:00:00', '2142-10-01, 00:00:00',
#        '2143-01-01, 00:00:00', '2143-04-01, 00:00:00',
#        '2143-07-01, 00:00:00', '2143-10-01, 00:00:00',
#        '2144-01-01, 00:00:00', '2144-04-01, 00:00:00',
#        '2144-07-01, 00:00:00', '2144-10-01, 00:00:00',
#        '2145-01-01, 00:00:00', '2145-04-01, 00:00:00',
#        '2145-07-01, 00:00:00', '2145-10-01, 00:00:00',
#        '2146-01-01, 00:00:00', '2146-04-01, 00:00:00',
#        '2146-07-01, 00:00:00', '2146-10-01, 00:00:00',
#        '2147-01-01, 00:00:00', '2147-04-01, 00:00:00',
#        '2147-07-01, 00:00:00', '2147-10-01, 00:00:00',
#        '2148-01-01, 00:00:00', '2148-04-01, 00:00:00',
#        '2148-07-01, 00:00:00', '2148-10-01, 00:00:00',
#        '2149-01-01, 00:00:00', '2149-04-01, 00:00:00',
#        '2149-07-01, 00:00:00', '2149-10-01, 00:00:00',
#        '2150-01-01, 00:00:00', '2150-04-01, 00:00:00',
#        '2150-07-01, 00:00:00', '2150-10-01, 00:00:00',
#        '2151-01-01, 00:00:00', '2151-04-01, 00:00:00',
#        '2151-07-01, 00:00:00', '2151-10-01, 00:00:00',
#        '2152-01-01, 00:00:00', '2152-04-01, 00:00:00',
#        '2152-07-01, 00:00:00', '2152-10-01, 00:00:00',
#        '2153-01-01, 00:00:00', '2153-04-01, 00:00:00',
#        '2153-07-01, 00:00:00', '2153-10-01, 00:00:00',
#        '2154-01-01, 00:00:00', '2154-04-01, 00:00:00',
#        '2154-07-01, 00:00:00', '2154-10-01, 00:00:00',
#        '2155-01-01, 00:00:00', '2155-04-01, 00:00:00',
#        '2155-07-01, 00:00:00', '2155-10-01, 00:00:00',
#        '2156-01-01, 00:00:00', '2156-04-01, 00:00:00',
#        '2156-07-01, 00:00:00', '2156-10-01, 00:00:00',
#        '2157-01-01, 00:00:00', '2157-04-01, 00:00:00',
#        '2157-07-01, 00:00:00', '2157-10-01, 00:00:00',
#        '2158-01-01, 00:00:00', '2158-04-01, 00:00:00',
#        '2158-07-01, 00:00:00', '2158-10-01, 00:00:00',
#        '2159-01-01, 00:00:00', '2159-04-01, 00:00:00',
#        '2159-07-01, 00:00:00', '2159-10-01, 00:00:00',
#        '2160-01-01, 00:00:00'], dtype=object)

# %%
esm_datastore = catalog["01deg_jra55v13_ryf9091"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_dataframe_catalog/core.py:177, in DfFileCatalog.__getitem__(self, key)
#     176 try:
# --> 177     return self._entries[key]
#     178 except KeyError as e:
#
# KeyError: '01deg_jra55v13_ryf9091'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 esm_datastore = catalog["01deg_jra55v13_ryf9091"]
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_dataframe_catalog/core.py:191, in DfFileCatalog.__getitem__(self, key)
#     186     if len(yamls) > 1:
#     187         assert all(y == yaml_text for y in yamls)
#     189     self._entries[key] = LocalCatalogEntry(
#     190         name=key, **yaml.safe_load(yaml_text)["sources"][key]
# --> 191     ).get()
#     192     return self._entries[key]
#     193 raise KeyError(
#     194     f"key='{key}' not found in catalog. You can access the list of valid source keys via the .keys() method."
#     195 ) from e
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake/catalog/local.py:313, in LocalCatalogEntry.get(self, **user_parameters)
#     310     return self._default_source
#     312 plugin, open_args = self._create_open_args(user_parameters)
# --> 313 data_source = plugin(**open_args)
#     314 data_source.catalog_object = self._catalog
#     315 data_source.name = self.name
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:124, in esm_datastore.__init__(self, obj, progressbar, sep, registry, read_csv_kwargs, columns_with_iterables, storage_options, threaded, **intake_kwargs)
#     122     self.esmcat = ESMCatalogModel.from_dict(obj)
#     123 else:
# --> 124     self.esmcat = ESMCatalogModel.load(
#     125         obj, storage_options=self.storage_options, read_csv_kwargs=read_csv_kwargs
#     126     )
#     128 self.derivedcat = registry or default_registry
#     129 self._entries = {}
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/cat.py:257, in ESMCatalogModel.load(cls, json_file, storage_options, read_csv_kwargs)
#     255 cat = cls.model_validate(data)
#     256 if cat.catalog_file:
# --> 257     cat._frames = cat._df_from_file(cat, _mapper, storage_options, read_csv_kwargs)
#     258 else:
#     259     cat._frames = FramesModel(
#     260         lf=pl.LazyFrame(cat.catalog_dict),
#     261         pl_df=pl.DataFrame(cat.catalog_dict),
#     262         df=pl.DataFrame(cat.catalog_dict).to_pandas(),
#     263     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/cat.py:318, in ESMCatalogModel._df_from_file(self, cat, _mapper, storage_options, read_csv_kwargs)
#     310     converters = read_csv_kwargs.pop('converters', {})  # Hack
#     311     # See https://github.com/pola-rs/polars/issues/13040 - can't use read_csv.
#     312     lf = pl.scan_csv(
#     313         cat.catalog_file,  # type: ignore[arg-type]
#     314         storage_options=storage_options,
#     315         infer_schema=False,
#     316         **read_csv_kwargs,
#     317     ).with_columns(
# --> 318         [
#     319             pl.col(colname)
#     320             .str.replace('^.', '[')  # Replace first/last chars with [ or ].
#     321             .str.replace('.$', ']')  # set/tuple => list
#     322             .str.replace_all("'", '"')
#     323             .str.json_decode()  # This is to do with the way polars reads json - single versus double quotes
#     324             for colname in converters.keys()
#     325         ]
#     326     )
#     327     return FramesModel(lf=lf)
#     328 else:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/cat.py:323, in <listcomp>(.0)
#     310     converters = read_csv_kwargs.pop('converters', {})  # Hack
#     311     # See https://github.com/pola-rs/polars/issues/13040 - can't use read_csv.
#     312     lf = pl.scan_csv(
#     313         cat.catalog_file,  # type: ignore[arg-type]
#     314         storage_options=storage_options,
#     315         infer_schema=False,
#     316         **read_csv_kwargs,
#     317     ).with_columns(
#     318         [
#     319             pl.col(colname)
#     320             .str.replace('^.', '[')  # Replace first/last chars with [ or ].
#     321             .str.replace('.$', ']')  # set/tuple => list
#     322             .str.replace_all("'", '"')
# --> 323             .str.json_decode()  # This is to do with the way polars reads json - single versus double quotes
#     324             for colname in converters.keys()
#     325         ]
#     326     )
#     327     return FramesModel(lf=lf)
#     328 else:
#
# TypeError: ExprStringNameSpace.json_decode() missing 1 required positional argument: 'dtype'

# %%
esm_datastore
# Out:
# <p><strong>01deg_jra55v13_ryf9091 catalog with 22 dataset(s) from 11947 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>3469</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>11947</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>3361</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>3360</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>197</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import re

# %%
[f'{y}-{m:02d}-01, 00:00:00' for y in range(2030, 2040) for m in range(1, 13, 3)]
# Out:
# ['2030-01-01, 00:00:00',
#  '2030-04-01, 00:00:00',
#  '2030-07-01, 00:00:00',
#  '2030-10-01, 00:00:00',
#  '2031-01-01, 00:00:00',
#  '2031-04-01, 00:00:00',
#  '2031-07-01, 00:00:00',
#  '2031-10-01, 00:00:00',
#  '2032-01-01, 00:00:00',
#  '2032-04-01, 00:00:00',
#  '2032-07-01, 00:00:00',
#  '2032-10-01, 00:00:00',
#  '2033-01-01, 00:00:00',
#  '2033-04-01, 00:00:00',
#  '2033-07-01, 00:00:00',
#  '2033-10-01, 00:00:00',
#  '2034-01-01, 00:00:00',
#  '2034-04-01, 00:00:00',
#  '2034-07-01, 00:00:00',
#  '2034-10-01, 00:00:00',
#  '2035-01-01, 00:00:00',
#  '2035-04-01, 00:00:00',
#  '2035-07-01, 00:00:00',
#  '2035-10-01, 00:00:00',
#  '2036-01-01, 00:00:00',
#  '2036-04-01, 00:00:00',
#  '2036-07-01, 00:00:00',
#  '2036-10-01, 00:00:00',
#  '2037-01-01, 00:00:00',
#  '2037-04-01, 00:00:00',
#  '2037-07-01, 00:00:00',
#  '2037-10-01, 00:00:00',
#  '2038-01-01, 00:00:00',
#  '2038-04-01, 00:00:00',
#  '2038-07-01, 00:00:00',
#  '2038-10-01, 00:00:00',
#  '2039-01-01, 00:00:00',
#  '2039-04-01, 00:00:00',
#  '2039-07-01, 00:00:00',
#  '2039-10-01, 00:00:00']

# %%
esm_datastore_filtered = esm_datastore.search(
    # variable=["tx_trans", "ty_trans"], frequency="1mon", require_all_on="path",
    # variable=["tx_trans", "ty_trans"],
    variable=["tx_trans", "ty_trans"],
    frequency="1mon",
    require_all_on="path",
    # start_date='2030-01-01, 00:00:00',
    # start_date=[f'{y}-{m:02d}-01, 00:00:00' for y in range(2030, 2040) for m in range(1, 13, 3)], # Maybe select less data to start with?
    # start_date="203.*", # Maybe select less data to start with?
    # start_date=[f'{y}' for y in range(2030, 2040)], # Maybe select less data to start with?
    # path=".*output100.*"
)

# %%
esm_datastore_filtered
# Out:
# <p><strong>01deg_jra55v13_ryf9091 catalog with 1 dataset(s) from 920 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>920</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>920</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>920</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from distributed import Client

client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:42813' processes=28 threads=28, memory=125.19 GiB>

# %%
# xarray_open_kwargs = {
#     "chunks": {
#         "time": 3, # that size should give ~300 Mib chunks, but it has to happen after (as it's stored in chunks of 3)
#         "st_ocean": 7,
#         "xt_ocean": 400,
#         "yt_ocean": 300,
#         "xu_ocean": 400,
#         "yu_ocean": 300,
#     },
#     "decode_timedelta": False,
# }
xarray_open_kwargs = {"chunks": {"time": -1, "st_ocean": 7, "xt_ocean": 400, "yt_ocean": 300, "xu_ocean": 400, "yu_ocean": 300}, "decode_timedelta": False,}

# %%
ds = esm_datastore_filtered.to_dask(xarray_open_kwargs=xarray_open_kwargs).chunk(chunks={"time": 120,})
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
time = slice("2030", "2039")

# %%
ds_sel = ds.sel(time=time)

# %%
tx_trans_sel = ds_sel["tx_trans"]
# ty_trans_sel = ds_sel["ty_trans"]
tx_trans_sel

# %%
# tx_trans_mean = tx_trans_sel.weighted(tx_trans_sel.time.dt.days_in_month).mean(dim="time")
tx_trans_mean = tx_trans_sel.mean(dim="time")
tx_trans_mean
# Out:
# <xarray.DataArray 'tx_trans' (st_ocean: 75, yt_ocean: 2700, xu_ocean: 3600)> Size: 3GB
# dask.array<mean_agg-aggregate, shape=(75, 2700, 3600), dtype=float32, chunksize=(7, 300, 400), chunktype=numpy.ndarray>
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
#   * st_ocean  (st_ocean) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * xu_ocean  (xu_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.8 79.9 80.0

# %%
# tx_trans_sel.time.dt.days_in_month

# %%
# ty_trans_mean = ty_trans_sel.weighted(ty_trans_sel.time.dt.days_in_month).mean(dim="time")
# ty_trans_mean

# %%
# Saving to: NetCDF:
outputdir = "/scratch/y99/bp3051/hiresTM"

# %%
# tx_trans_mean.to_netcdf(f'{outputdir}/tx_trans.nc', compute=True)
tx_trans_mean.to_netcdf(f'{outputdir}/tx_trans.nc')

# %%
ty_trans_mean.to_netcdf(f'{outputdir}/ty_trans.nc')
