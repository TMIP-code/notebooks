# %% [markdown]
# # Catalog checks
#
# This notebook is just to check things in the catalog.
#
# job script options used for gdata storage/access:
#
# ```bash
# "-l storage=gdata/xv83+gdata/gh0+gdata/oi10+gdata/dk92+gdata/hh5+gdata/rr3+gdata/al33+gdata/fs38+gdata/xp65"
# ```

# %% [markdown]
# ## 1. Load packages

# %%
# Ignore warnings
import os
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

# %%
import glob

# %%
# Load intake and cosima cookbook
import intake

# Load numpy for numbers!
import numpy as np

# Load pandas for DataFrame manipulations
import pandas as pd

# %%
import xarray as xr

# %%
import datetime

# %%
import xmip

# %%
ls /g/data/p66
# Out:
# ls: cannot access '/g/data/p66': No such file or directory

# %%
ls /g/data/p73/archive
# Out:
# CMIP6/  CMIP7-test/  machine_learning/  non-CMIP/  README.txt  tmp/

# %%
cat /g/data/p73/archive/README.txt
# Out:
# ACCESS GCM Model Output Archive
#
# contact: chloe.mackallah@csiro.au
#
# This purpose of this project is the mid- to long-term archiving of ACCESS GCM simulation data;
# and is a sibling to p66 (my.nci.org.au/mancini/project/p66).
# Primarily, this archive contains model output from ACCESS-CM2 and ACCESS-ESM1.5
# production runs for CMIP6, produced by CSIRO in collaboration with ARCCSS (i.e. CLEX),
# but also includes non-CMIP simulations, especially those used in publications.
#
# Model output from the UM (atmosphere component) has been converted to netCDF format
# using Iris (older runs used cdms2), while output from MOM (ocean) and CICE (sea-ice)
# have been compressed. Restart files for every 10th simulations year are saved along
# with model output, while subdaily data is moved to NCI's massdata system.
#
# For CF-compliant datasets from ACCESS CMIP6 production simulations, which are published
# through the ESGF for CMIP6, please see the local publication node, project fs38
# (my.nci.org.au/mancini/project/fs38).
# For international CMIP6 replication, please see project oi10 (my.nci.org.au/mancini/project/oi10)
#
# Details for each simulation can be found in the `ACCESS Model Output Archive Wiki',
# along with appropriate contacts for the relevant datasets:
#   https://confluence.csiro.au/display/ACCESS/ACCESS+Model+Output+Archive+%28p73%29+Wiki
#
# Subaily data (available for selected simulations) is stored on MDSS:
#   http://climate-cms.wikis.unsw.edu.au/Archiving_data
#   $ mdss -P p73 ls ACCESS_archive/subdaily/
#
#
# Directory descriptions:
#
# /g/data/p73/archive/CMIP6
# Model output from ACCESS CMIP6 production simulations.
#
# /g/data/p73/archive/non-CMIP
# Model output from ACCESS simulations that are not for CMIP6 publication.
#
# /g/data/p73/archive/non-CMIP/CMORised
# CMORised (using https://git.nci.org.au/cm2704/APP4) versions of the non-CMIP model output.
# For publication via CSIRO DAP.
#
# /g/data/p73/archive/machine_learning
# Output from the [name] Machine Learning model.

# %%
# Path to data
ACCESS_ESM_path = "/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn"
ACCESS_CM_path = "/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn"

# %%
ACCESS_ESM_monthly_files = glob.glob(f'{ACCESS_ESM_path}/*month*')
ACCESS_ESM_monthly_files
# Out:
# ['/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19501231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19091231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19171231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19991231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20101231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19421231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19441231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19401231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18691231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18851231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19841231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18771231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19261231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18801231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19051231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18711231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18901231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18661231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19801231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19871231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18561231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18991231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19601231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18821231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19331231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19011231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19731231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19481231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20031231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18831231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19111231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18731231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19311231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19691231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19071231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19061231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19221231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20111231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18861231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20141231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19681231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18601231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19911231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20091231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20041231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18651231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19621231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18921231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19371231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19431231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18871231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19811231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19191231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19931231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19251231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19781231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18571231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19821231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19211231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18741231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19511231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19281231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19901231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18511231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19701231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18811231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19961231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19131231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19571231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20051231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20121231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20001231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19611231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19881231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19081231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19001231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19461231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19151231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18931231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18591231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18501231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19021231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19161231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19451231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19941231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19141231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19891231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18521231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19491231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19771231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19101231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19041231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19351231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18531231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18971231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19031231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19741231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18631231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19241231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20011231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19291231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19591231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20071231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19951231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19861231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19561231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18551231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19541231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18781231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18641231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18751231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18681231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18581231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19391231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19301231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19971231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19411231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19721231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19361231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19651231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18881231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19201231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19121231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19381231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19581231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19711231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18981231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18701231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19791231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19751231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18951231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19671231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18761231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18941231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19641231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19341231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19831231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20131231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18841231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20081231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20021231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19661231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18671231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19761231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19321231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18791231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18541231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18911231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19521231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19981231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19851231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18961231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19551231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19531231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18611231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18891231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18721231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-18621231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19471231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19631231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-20061231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19921231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19231231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19181231',
#  '/g/data/p73/archive/CMIP6/ACCESS-ESM1-5/HI-05/history/ocn/ocean_month.nc-19271231']

# %%
foo = xr.open_dataset(monthly_files[0])
foo
# Out:
# <xarray.Dataset> Size: 17GB
# Dimensions:                          (xt_ocean: 360, yt_ocean: 300, time: 12,
#                                       nv: 2, xu_ocean: 360, yu_ocean: 300,
#                                       st_ocean: 50, st_edges_ocean: 51,
#                                       sw_ocean: 50, sw_edges_ocean: 51,
#                                       grid_xu_ocean: 360, grid_yt_ocean: 300,
#                                       potrho: 80, potrho_edges: 81,
#                                       grid_xt_ocean: 360, grid_yu_ocean: 300)
# Coordinates: (12/20)
#   * xt_ocean                         (xt_ocean) float64 3kB -279.5 ... 79.5
#   * yt_ocean                         (yt_ocean) float64 2kB -77.88 ... 89.77
#   * time                             (time) datetime64[ns] 96B 1950-01-14T12:...
#   * nv                               (nv) float64 16B 1.0 2.0
#   * xu_ocean                         (xu_ocean) float64 3kB -279.0 ... 80.0
#   * yu_ocean                         (yu_ocean) float64 2kB -77.75 ... 90.0
#     ...                               ...
#   * grid_xt_ocean                    (grid_xt_ocean) float64 3kB -279.5 ... 79.5
#   * grid_yu_ocean                    (grid_yu_ocean) float64 2kB -77.75 ... 90.0
#     geolat_c                         (yu_ocean, xu_ocean) float32 432kB ...
#     geolon_c                         (yu_ocean, xu_ocean) float32 432kB ...
#     geolat_t                         (yt_ocean, xt_ocean) float32 432kB ...
#     geolon_t                         (yt_ocean, xt_ocean) float32 432kB ...
# Data variables: (12/206)
#     ht                               (yt_ocean, xt_ocean) float32 432kB ...
#     hu                               (yu_ocean, xu_ocean) float32 432kB ...
#     area_t                           (yt_ocean, xt_ocean) float32 432kB ...
#     area_u                           (yu_ocean, xu_ocean) float32 432kB ...
#     kmt                              (yt_ocean, xt_ocean) float32 432kB ...
#     kmu                              (yu_ocean, xu_ocean) float32 432kB ...
#     ...                               ...
#     wind_power_u                     (time, yu_ocean, xu_ocean) float32 5MB ...
#     wind_power_v                     (time, yu_ocean, xu_ocean) float32 5MB ...
#     average_T1                       (time) datetime64[ns] 96B ...
#     average_T2                       (time) datetime64[ns] 96B ...
#     average_DT                       (time) timedelta64[ns] 96B ...
#     time_bounds                      (time, nv) timedelta64[ns] 192B ...
# Attributes:
#     filename:   ocean_month.nc
#     title:      ACCESS-ESM_CMIP6
#     grid_type:  regular
#     grid_tile:  N/A

# %%
import matplotlib as plt

# %%
year_start = 1990
num_years = 10

# %%
# Create directory on gdata
datadir = '/scratch/xv83/TMIP/data'
start_time, end_time = time_window_strings(year_start, num_years)
start_time_str = start_time.strftime("%b%Y")
end_time_str = end_time.strftime("%b%Y")

outputdir = f'{datadir}/{model}/{experiment}/{ensemble}/{start_time_str}-{end_time_str}'
print(outputdir)
# Out:
# /scratch/xv83/TMIP/data/ACCESS-ESM1-5/historical/r1i1p1f1/Jan1990-Dec1999

# %%
makedirs(outputdir, exist_ok=True)

# %%
########## Start the client and make the `.nc` files ##########
print("Starting client")
client = Client(n_workers=4)#, threads_per_worker=1, memory_limit='16GB') # Note: with 1thread/worker cannot plot thetao. Maybe I need to understand why?
client
# Out:
# Starting client

# %%
# umo dataset
print("Loading umo data")
umo_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "umo",
    frequency = "mon",
)
print("\numo_datadask: ", umo_datadask)
# Out:
# Loading umo data
#
# umo_datadask:  <xarray.Dataset> Size: 43GB
# Dimensions:             (time: 1980, lev: 50, j: 300, i: 360, bnds: 2,
#                          vertices: 4)
# Coordinates:
#   * time                (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 20...
#     time_bnds           (time, bnds) datetime64[ns] 32kB dask.array<chunksize=(120, 2), meta=np.ndarray>
#   * lev                 (lev) float64 400B 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#     lev_bnds            (lev, bnds) float64 800B dask.array<chunksize=(50, 2), meta=np.ndarray>
#   * j                   (j) int32 1kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * i                   (i) int32 1kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#     latitude            (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude           (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     umo                 (time, lev, j, i) float32 43GB dask.array<chunksize=(120, 50, 60, 60), meta=np.ndarray>
# Attributes: (12/58)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             0.0
#     branch_time_in_parent:            21915.0
#     data_specs_version:               01.00.30
#     ...                               ...
#     intake_esm_attrs:member_id:       r1i1p1f1
#     intake_esm_attrs:variable_id:     umo
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:version:         v20191115
#     intake_esm_attrs:_data_format_:   netcdf
#     intake_esm_dataset_key:           l.CMIP.CSIRO.ACCESS-ESM1-5.historical.r...

# %%
# vmo dataset
print("Loading vmo data")
vmo_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "vmo",
    frequency = "mon",
)
print("\nvmo_datadask: ", vmo_datadask)
# Out:
# Loading vmo data
#
# vmo_datadask:  <xarray.Dataset> Size: 43GB
# Dimensions:             (time: 1980, lev: 50, j: 300, i: 360, bnds: 2,
#                          vertices: 4)
# Coordinates:
#   * time                (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 20...
#     time_bnds           (time, bnds) datetime64[ns] 32kB dask.array<chunksize=(120, 2), meta=np.ndarray>
#   * lev                 (lev) float64 400B 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#     lev_bnds            (lev, bnds) float64 800B dask.array<chunksize=(50, 2), meta=np.ndarray>
#   * j                   (j) int32 1kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * i                   (i) int32 1kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#     latitude            (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude           (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     vmo                 (time, lev, j, i) float32 43GB dask.array<chunksize=(120, 50, 60, 60), meta=np.ndarray>
# Attributes: (12/58)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             0.0
#     branch_time_in_parent:            21915.0
#     data_specs_version:               01.00.30
#     ...                               ...
#     intake_esm_attrs:member_id:       r1i1p1f1
#     intake_esm_attrs:variable_id:     vmo
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:version:         v20191115
#     intake_esm_attrs:_data_format_:   netcdf
#     intake_esm_dataset_key:           l.CMIP.CSIRO.ACCESS-ESM1-5.historical.r...

# %%
# mlotst dataset
print("Loading mlotst data")
mlotst_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "mlotst",
    frequency = "mon",
)
print("\nmlotst_datadask: ", mlotst_datadask)
# Out:
# Loading mlotst data
#
# mlotst_datadask:  <xarray.Dataset> Size: 864MB
# Dimensions:             (time: 1980, bnds: 2, j: 300, i: 360, vertices: 4)
# Coordinates:
#   * time                (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 20...
#   * j                   (j) int32 1kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * i                   (i) int32 1kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#     latitude            (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude           (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     time_bnds           (time, bnds) datetime64[ns] 32kB dask.array<chunksize=(1980, 2), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
#     mlotst              (time, j, i) float32 855MB dask.array<chunksize=(1980, 60, 60), meta=np.ndarray>
# Attributes: (12/64)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             0.0
#     branch_time_in_parent:            21915.0
#     creation_date:                    2019-11-15T15:38:06Z
#     ...                               ...
#     intake_esm_attrs:variable_id:     mlotst
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:version:         v20191115
#     intake_esm_attrs:time_range:      185001-201412
#     intake_esm_attrs:_data_format_:   netcdf
#     intake_esm_dataset_key:           l.CMIP.CSIRO.ACCESS-ESM1-5.historical.r...

# %%
# Deal with thkcello for a different script,
# given that its location (fixed or time-dependent) depends on the model and/or project
# # thkcello dataset
# print("Loading thkcello data")
# thkcello_datadask = select_latest_data(searched_cat,
#     dict(
#         chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
#     ),
#     variable_id = "thkcello",
#     frequency = "mon",
# )
# print("\nthkcello_datadask: ", thkcello_datadask)

# %%
# Slice umo dataset for the time period
umo_datadask_sel = umo_datadask.sel(time=slice(start_time, end_time))
# Take the time average of the monthly evaporation (using month length as weights)
umo = umo_datadask_sel["umo"].weighted(umo_datadask_sel.time.dt.days_in_month).mean(dim="time")
umo
# Out:
# <xarray.DataArray 'umo' (lev: 50, j: 300, i: 360)> Size: 43MB
# dask.array<truediv, shape=(50, 300, 360), dtype=float64, chunksize=(50, 60, 60), chunktype=numpy.ndarray>
# Coordinates:
#   * lev        (lev) float64 400B 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#   * j          (j) int32 1kB 0 1 2 3 4 5 6 7 ... 292 293 294 295 296 297 298 299
#   * i          (i) int32 1kB 0 1 2 3 4 5 6 7 ... 352 353 354 355 356 357 358 359
#     latitude   (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude  (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>

# %%
# Slice vmo dataset for the time period
vmo_datadask_sel = vmo_datadask.sel(time=slice(start_time, end_time))
# Take the time average of the monthly evaporation (using month length as weights)
vmo = vmo_datadask_sel["vmo"].weighted(vmo_datadask_sel.time.dt.days_in_month).mean(dim="time")
vmo
# Out:
# <xarray.DataArray 'vmo' (lev: 50, j: 300, i: 360)> Size: 43MB
# dask.array<truediv, shape=(50, 300, 360), dtype=float64, chunksize=(50, 60, 60), chunktype=numpy.ndarray>
# Coordinates:
#   * lev        (lev) float64 400B 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#   * j          (j) int32 1kB 0 1 2 3 4 5 6 7 ... 292 293 294 295 296 297 298 299
#   * i          (i) int32 1kB 0 1 2 3 4 5 6 7 ... 352 353 354 355 356 357 358 359
#     latitude   (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude  (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>

# %%
# Slice mlotst dataset for the time period
mlotst_datadask_sel = mlotst_datadask.sel(time=slice(start_time, end_time))
# Take the time mean of the yearly maximum of mlotst
mlotst_yearlymax = mlotst_datadask_sel.groupby("time.year").max(dim="time")
mlotst_yearlymax
# Out:
# <xarray.Dataset> Size: 75MB
# Dimensions:             (year: 10, bnds: 2, j: 300, i: 360, vertices: 4)
# Coordinates:
#   * j                   (j) int32 1kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * i                   (i) int32 1kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#     latitude            (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude           (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#   * year                (year) int64 80B 1990 1991 1992 1993 ... 1997 1998 1999
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     time_bnds           (year, bnds) datetime64[ns] 160B dask.array<chunksize=(10, 2), meta=np.ndarray>
#     mlotst              (year, j, i) float32 4MB dask.array<chunksize=(10, 60, 60), meta=np.ndarray>
#     vertices_latitude   (year, j, i, vertices) float64 35MB dask.array<chunksize=(10, 60, 60, 2), meta=np.ndarray>
#     vertices_longitude  (year, j, i, vertices) float64 35MB dask.array<chunksize=(10, 60, 60, 2), meta=np.ndarray>
# Attributes: (12/64)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             0.0
#     branch_time_in_parent:            21915.0
#     creation_date:                    2019-11-15T15:38:06Z
#     ...                               ...
#     intake_esm_attrs:variable_id:     mlotst
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:version:         v20191115
#     intake_esm_attrs:time_range:      185001-201412
#     intake_esm_attrs:_data_format_:   netcdf
#     intake_esm_dataset_key:           l.CMIP.CSIRO.ACCESS-ESM1-5.historical.r...

# %%
mlotst = mlotst_yearlymax.mean(dim="year")
mlotst
# Out:
# <xarray.Dataset> Size: 9MB
# Dimensions:             (j: 300, i: 360, vertices: 4)
# Coordinates:
#   * j                   (j) int32 1kB 0 1 2 3 4 5 6 ... 294 295 296 297 298 299
#   * i                   (i) int32 1kB 0 1 2 3 4 5 6 ... 354 355 356 357 358 359
#     latitude            (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     longitude           (j, i) float64 864kB dask.array<chunksize=(60, 60), meta=np.ndarray>
# Dimensions without coordinates: vertices
# Data variables:
#     mlotst              (j, i) float32 432kB dask.array<chunksize=(60, 60), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 3MB dask.array<chunksize=(60, 60, 2), meta=np.ndarray>

# %%
# # Slice thkcello dataset for the time period
# thkcello_datadask_sel = thkcello_datadask.sel(time=slice(start_time, end_time))
# # Take the time average of the monthly evaporation (using month length as weights)
# thkcello = thkcello_datadask_sel["thkcello"].weighted(thkcello_datadask_sel.time.dt.days_in_month).mean(dim="time")

# %%
# Save to netcdfs (and compute!)
umo.to_netcdf(f'{outputdir}/umo.nc', compute=True)
vmo.to_netcdf(f'{outputdir}/vmo.nc', compute=True)
mlotst.to_netcdf(f'{outputdir}/mlotst.nc', compute=True)
# thkcello.to_netcdf(f'{outputdir}/thkcello.nc', compute=True)

# %%
client.close()
