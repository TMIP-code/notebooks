# %% [markdown]
# # Prototype python script for fetching and averaging data
#
# The goal is to be able to create NetCDF files of time-averaged ocean-transport states (`umo`, `vmo`, `uo`, `vo`, and `mlotst`) from any CMIP model of interest. (CMIP5 might require some tweaks as the catalog may use different kwargs (e.g., `souce_id` instead of `model`).
#
# Eventually, this notebook will be turned into a function with these inputs:
# - model
# - experiment
# - ensemble member
# - time period
# that a script can put in a loop to generate lots of datasets.
#
# Down the road, a Julia script (maybe a small package?) can grab the time-averaged data from these files and generate the transport matrices.
#
# Note that this notebook is specific to Gadi at NCI. It may require access to at least one of the following projects (so make sure you add them all in your interactive ARE job submission):
# ```
# gdata/gh0+gdata/oi10+gdata/dk92+gdata/hh5+gdata/rr3+gdata/al33+gdata/fs38
# ```
#
# Warning: No promises made, this is work in progress!

# %% [markdown]
# ## 1. Load packages

# %%
# Ignore warnings
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

# %%
# Import makedirs to create directories where I write new files
from os import makedirs

# %%
# Load dask
from dask.distributed import Client

# Load intake and cosima cookbook
import intake
import cosima_cookbook as cc

# Load xarray for N-dimensional arrays
import xarray as xr

# Load xesmf for regridding
import xesmf as xe

# Load datetime to deal with time formats
import datetime

# Load numpy for numbers!
import numpy as np

# Load xmip for preprocessing (trying to get consistent metadata for making matrices down the road)
from xmip.preprocessing import combined_preprocessing

# Load pandas for DataFrame manipulations
import pandas as pd

# %% [markdown]
# ## 2. Define some functions
#
# (to avoid too much boilerplate code)

# %%
########## functions ##########
print("Defining functions")

def time_window_strings(year_start, num_years):
    """
    return strings for start_time and end_time
    """
    # start_time is first second of year_start
    start_time = datetime.datetime(year_start, 1, 1, 0, 0, 0)
    # end_time is last second of last_year
    end_time = datetime.datetime(year_start + num_years - 1, 12, 31, 23, 59, 59)

    # Return the weighted average
    return start_time, end_time

def find_latest_version(cat):
    """
    find latest version of selected data
    """
    sorted_versions = cat.df.version.to_list()
    sorted_versions.sort()
    latest_version = sorted_versions[-1]
    return latest_version

def select_latest_cat(cat, **kwargs):
    """
    search latest version of selected data
    """
    selectedcat = cat.search(**kwargs)
    latestselectedcat = selectedcat.search(version=find_latest_version(selectedcat))
    return latestselectedcat

def select_latest_data(cat, xarray_open_kwargs, **kwargs):
    latestselectedcat = select_latest_cat(cat, **kwargs)
    xarray_combine_by_coords_kwargs=dict(
        compat="override",
        data_vars="minimal",
        coords="minimal"
    )
    datadask = latestselectedcat.to_dask(
        xarray_open_kwargs=xarray_open_kwargs,
        xarray_combine_by_coords_kwargs=xarray_combine_by_coords_kwargs,
        parallel=True
    )
    return datadask

def cmip_catalog_str(CMIP_version, model):
    """
    Figure out the name of the catalog given the model and CMIP version (NCI/Gadi specific)
    """
    match CMIP_version:
        case 'CMIP5':
            match model:
                case 'ACCESS1-3':
                    cat = "/g/data/dk92/catalog/v2/esm/cmip5-rr3/catalog.json"
                case _:
                    cat = "/g/data/dk92/catalog/v2/esm/cmip5-al33/catalog.json"
        case 'CMIP6':
            match model:
                case 'ACCESS-CM2' | 'ACCESS-ESM1-5':
                    cat = "/g/data/dk92/catalog/v2/esm/cmip6-fs38/catalog.json"
                case _:
                    cat = "/g/data/dk92/catalog/v2/esm/cmip6-oi10/catalog.json"
    return cat
# Out:
# Defining functions

# %% [markdown]
# ## 3. Select the model, experiment, ensemble, and time window
#
# On NCI, the catalog depends not only on the CMIP version but also on the model: For some reason that eludes me, some of the Australian data (including ACCESS1.3, ACCESS-ESM1.5, and ACCESS-CM2) lives in its own ***separate*** catalog. So I need to define these first

# %%
CMIP_version = "CMIP6"

# %%
# Comment/uncomment
model = "ACCESS-ESM1-5"
# model = "not ACCESS" # use this if you don;t know yet which model you want and need to look up some model names first.
model = "GFDL-CM4"

# %%
# Load catalog
cat_str = cmip_catalog_str(CMIP_version, model)
cat_str
# Out:
# '/g/data/dk92/catalog/v2/esm/cmip6-oi10/catalog.json'

# %%
# The catalog
cat = intake.open_esm_datastore(cat_str)
cat
# Out:
# <p><strong>cmip6-oi10 catalog with 276721 dataset(s) from 3295829 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>path</th>
#       <td>3295829</td>
#     </tr>
#     <tr>
#       <th>file_type</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>project_id</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>6520</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>373</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>989</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>34626</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# A little detour to list all the models in the catalog:

# %%
models = np.sort(cat.search(realm = 'ocean').df.source_id.unique())
print(*models, sep = "\n")
# Out:
# ACCESS-OM2
# ACCESS-OM2-025
# AWI-CM-1-1-MR
# AWI-ESM-1-1-LR
# BCC-CSM2-MR
# BCC-ESM1
# CAMS-CSM1-0
# CAS-ESM2-0
# CESM1-1-CAM5-CMIP5
# CESM1-CAM5-SE-HR
# CESM2
# CESM2-FV2
# CESM2-WACCM
# CESM2-WACCM-FV2
# CIESM
# CMCC-CM2-HR4
# CMCC-CM2-SR5
# CMCC-CM2-VHR4
# CMCC-ESM2
# CNRM-CM6-1
# CNRM-CM6-1-HR
# CNRM-ESM2-1
# CanESM5
# CanESM5-1
# CanESM5-CanOE
# E3SM-1-0
# E3SM-1-1
# E3SM-1-1-ECA
# E3SM-2-0
# E3SM-2-0-NARRM
# EC-Earth3
# EC-Earth3-AerChem
# EC-Earth3-CC
# EC-Earth3-LR
# EC-Earth3-Veg
# EC-Earth3-Veg-LR
# FGOALS-f3-H
# FGOALS-f3-L
# FGOALS-g3
# FIO-ESM-2-0
# GFDL-CM4
# GFDL-ESM2M
# GFDL-ESM4
# GFDL-OM4p5B
# GISS-E2-1-G
# GISS-E2-1-G-CC
# GISS-E2-1-H
# GISS-E2-2-G
# GISS-E2-2-H
# HadGEM3-GC31-LL
# HadGEM3-GC31-MM
# ICON-ESM-LR
# IITM-ESM
# INM-CM4-8
# INM-CM5-0
# IPSL-CM5A2-INCA
# IPSL-CM6A-LR
# IPSL-CM6A-LR-INCA
# KACE-1-0-G
# KIOST-ESM
# MCM-UA-1-0
# MIROC-ES2L
# MIROC6
# MPI-ESM-1-2-HAM
# MPI-ESM1-2-HR
# MPI-ESM1-2-LR
# MRI-ESM2-0
# NESM3
# NorCPM1
# NorESM1-F
# NorESM2-LM
# NorESM2-MM
# SAM0-UNICON
# TaiESM1
# TaiESM1-TIMCOM
# TaiESM1-TIMCOM2
# UKESM1-0-LL
# UKESM1-1-LL

# %% [markdown]
# The creation of a matrix can only work if the following set of variables is available:
# - mass transports (`umo` and `vmo`)
# - mixed-layer depth (`mlotst`)
#
# Alternatively, we can use `umo` and `vmo` (in kg/s) can be replaced by `uo` and `vo` (m/s). However, the conversion to mass transport requires the grid-cell volume (`volcello`), grid-cell areas (from vertices and `thkcello`), and density (no variable so I guess constant will do).
#
# So the notebook here will create all the files for transport, if available: `umo`, `vmo`, `uo`, `vo`, `mlotst`.

# %%
experiment = "historical"

# %% [markdown]
# List of members

# %%
members = np.sort(cat.search(source_id = model, realm = 'ocean').df.member_id.unique())
print(*members, sep = "\n")
# Out:
# r1i1p1f1

# %%
# List all models of the catalog that have 
# (variable `umo` or variable `uo`) and (variable `vmo` or variable `vo`) and variable `mlotst`) 
# and display these models as a dictionary where the keys are the models 
# and the values are lists of the members that have these variables
models = np.sort(cat.search(variable_id = ['umo', 'uo', 'vmo', 'vo', 'mlotst']).df.source_id.unique())
models_dict = {}
for model in models:
    members = np.sort(cat.search(source_id = model, variable_id = ['umo', 'uo', 'vmo', 'vo', 'mlotst']).df.member_id.unique())
    models_dict[model] = members
models_dict
# Out:
# {'ACCESS-OM2': array(['r1i1p1f1'], dtype=object),
#  'ACCESS-OM2-025': array(['r1i1p1f1'], dtype=object),
#  'AWI-CM-1-1-MR': array(['r1i1p1f1'], dtype=object),
#  'AWI-ESM-1-1-LR': array(['r1i1p1f1'], dtype=object),
#  'BCC-CSM2-MR': array(['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'], dtype=object),
#  'BCC-ESM1': array(['r1i1p1f1'], dtype=object),
#  'CAMS-CSM1-0': array(['r1i1p1f1', 'r1i1p1f2'], dtype=object),
#  'CAS-ESM2-0': array(['r1i1p1f1'], dtype=object),
#  'CESM1-CAM5-SE-HR': array(['r1i1p1f1'], dtype=object),
#  'CESM2': array(['r101i1p1f1', 'r102i1p1f1', 'r103i1p1f1', 'r1i1p1f1', 'r2i1p1f1',
#         'r3i1p1f1'], dtype=object),
#  'CESM2-FV2': array(['r1i1p1f1'], dtype=object),
#  'CESM2-WACCM': array(['r1i1p1f1'], dtype=object),
#  'CESM2-WACCM-FV2': array(['r1i1p1f1'], dtype=object),
#  'CIESM': array(['r1i1p1f1'], dtype=object),
#  'CMCC-CM2-HR4': array(['r1i1p1f1'], dtype=object),
#  'CMCC-CM2-SR5': array(['r1i1p1f1'], dtype=object),
#  'CMCC-CM2-VHR4': array(['r1i1p1f1'], dtype=object),
#  'CMCC-ESM2': array(['r1i1p1f1'], dtype=object),
#  'CNRM-CM6-1': array(['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2',
#         'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2'],
#        dtype=object),
#  'CNRM-CM6-1-HR': array(['r1i1p1f2'], dtype=object),
#  'CNRM-ESM2-1': array(['r1i1p1f2'], dtype=object),
#  'CanESM5': array(['r10i1p1f1', 'r1i1p1f1', 'r1i1p2f1', 'r2i1p1f1', 'r3i1p1f1',
#         'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1',
#         'r9i1p1f1'], dtype=object),
#  'CanESM5-CanOE': array(['r1i1p2f1'], dtype=object),
#  'E3SM-1-0': array(['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'], dtype=object),
#  'E3SM-1-1': array(['r1i1p1f1'], dtype=object),
#  'E3SM-1-1-ECA': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3': array(['r10i1p1f2', 'r11i1p1f1', 'r12i1p1f2', 'r13i1p1f1', 'r13i1p1f2',
#         'r15i1p1f1', 'r15i1p1f2', 'r16i1p1f2', 'r17i1p1f2', 'r18i1p1f2',
#         'r19i1p1f2', 'r1i1p1f1', 'r1i1p1f2', 'r20i1p1f2', 'r21i1p1f2',
#         'r22i1p1f2', 'r23i1p1f2', 'r24i1p1f2', 'r25i1p1f2', 'r26i1p1f2',
#         'r27i1p1f2', 'r28i1p1f2', 'r29i1p1f2', 'r2i1p1f2', 'r30i1p1f2',
#         'r4i1p1f2', 'r6i1p1f1', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2',
#         'r9i1p1f1'], dtype=object),
#  'EC-Earth3-AerChem': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3-CC': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3-LR': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3-Veg': array(['r12i1p1f1', 'r14i1p1f1', 'r1i1p1f1'], dtype=object),
#  'EC-Earth3-Veg-LR': array(['r1i1p1f1'], dtype=object),
#  'FGOALS-f3-H': array(['r1i1p1f1'], dtype=object),
#  'FGOALS-f3-L': array(['r1i1p1f1'], dtype=object),
#  'FGOALS-g3': array(['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'], dtype=object),
#  'FIO-ESM-2-0': array(['r1i1p1f1'], dtype=object),
#  'GFDL-CM4': array(['r1i1p1f1'], dtype=object),
#  'GFDL-OM4p5B': array(['r1i1p1f1'], dtype=object),
#  'GISS-E2-1-G': array(['r10i1p1f3', 'r10i1p5f2', 'r1i1p1f1', 'r1i1p1f2', 'r1i1p1f3',
#         'r1i1p1f4', 'r1i1p3f1', 'r1i1p5f2', 'r2i1p1f1', 'r2i1p1f2',
#         'r2i1p1f3', 'r2i1p1f4', 'r2i1p3f1', 'r2i1p5f2', 'r3i1p1f1',
#         'r3i1p1f2', 'r3i1p1f3', 'r3i1p1f4', 'r3i1p3f1', 'r3i1p5f2',
#         'r4i1p1f1', 'r4i1p1f2', 'r4i1p1f3', 'r4i1p1f4', 'r4i1p3f1',
#         'r4i1p5f2', 'r5i1p1f1', 'r5i1p1f2', 'r5i1p1f3', 'r5i1p1f4',
#         'r5i1p3f1', 'r5i1p5f2', 'r6i1p1f3', 'r6i1p5f2', 'r7i1p1f3',
#         'r7i1p5f2', 'r8i1p1f3', 'r8i1p5f2', 'r9i1p1f3', 'r9i1p5f2'],
#        dtype=object),
#  'GISS-E2-1-G-CC': array(['r1i1p1f1'], dtype=object),
#  'GISS-E2-1-H': array(['r1i1p1f1', 'r1i1p1f2'], dtype=object),
#  'GISS-E2-2-G': array(['r1i1p1f1', 'r1i1p1f2', 'r1i1p3f1', 'r2i1p1f1', 'r2i1p1f2',
#         'r2i1p3f1', 'r3i1p1f1', 'r3i1p1f2', 'r3i1p3f1', 'r4i1p1f1',
#         'r4i1p1f2', 'r4i1p3f1', 'r5i1p1f1', 'r5i1p1f2', 'r5i1p3f1'],
#        dtype=object),
#  'GISS-E2-2-H': array(['r1i1p1f1'], dtype=object),
#  'HadGEM3-GC31-LL': array(['r10i1p1f3', 'r1i1p1f1', 'r1i1p1f3', 'r2i1p1f3', 'r3i1p1f3',
#         'r4i1p1f3', 'r5i1p1f3', 'r6i1p1f3', 'r7i1p1f3', 'r8i1p1f3',
#         'r9i1p1f3'], dtype=object),
#  'HadGEM3-GC31-MM': array(['r1i1p1f1'], dtype=object),
#  'ICON-ESM-LR': array(['r1i1p1f1'], dtype=object),
#  'IITM-ESM': array(['r1i1p1f1'], dtype=object),
#  'INM-CM4-8': array(['r1i1p1f1'], dtype=object),
#  'INM-CM5-0': array(['r1i1p1f1'], dtype=object),
#  'IPSL-CM5A2-INCA': array(['r1i1p1f1'], dtype=object),
#  'IPSL-CM6A-LR': array(['r10i1p1f1', 'r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1',
#         'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1', 'r9i1p1f1'],
#        dtype=object),
#  'IPSL-CM6A-LR-INCA': array(['r1i1p1f1'], dtype=object),
#  'KIOST-ESM': array(['r1i1p1f1'], dtype=object),
#  'MCM-UA-1-0': array(['r1i1p1f1', 'r1i1p1f2'], dtype=object),
#  'MIROC-ES2L': array(['r10i1p1f242', 'r11i1p1f242', 'r12i1p1f242', 'r13i1p1f242',
#         'r14i1p1f242', 'r15i1p1f242', 'r16i1p1f242', 'r17i1p1f242',
#         'r18i1p1f242', 'r19i1p1f242', 'r1i1p1f2', 'r1i1p1f242',
#         'r20i1p1f242', 'r21i1p1f242', 'r22i1p1f242', 'r23i1p1f242',
#         'r24i1p1f242', 'r25i1p1f242', 'r26i1p1f242', 'r27i1p1f242',
#         'r28i1p1f242', 'r29i1p1f242', 'r2i1p1f242', 'r30i1p1f242',
#         'r3i1p1f242', 'r4i1p1f242', 'r5i1p1f242', 'r6i1p1f242',
#         'r7i1p1f242', 'r8i1p1f242', 'r9i1p1f242'], dtype=object),
#  'MIROC6': array(['r10i1p1f1', 'r11i1p1f1', 'r12i1p1f1', 'r13i1p1f1', 'r14i1p1f1',
#         'r15i1p1f1', 'r16i1p1f1', 'r17i1p1f1', 'r18i1p1f1', 'r19i1p1f1',
#         'r1i1p1f1', 'r20i1p1f1', 'r21i1p1f1', 'r22i1p1f1', 'r23i1p1f1',
#         'r24i1p1f1', 'r25i1p1f1', 'r26i1p1f1', 'r27i1p1f1', 'r28i1p1f1',
#         'r29i1p1f1', 'r2i1p1f1', 'r30i1p1f1', 'r31i1p1f1', 'r32i1p1f1',
#         'r33i1p1f1', 'r34i1p1f1', 'r35i1p1f1', 'r36i1p1f1', 'r37i1p1f1',
#         'r38i1p1f1', 'r39i1p1f1', 'r3i1p1f1', 'r40i1p1f1', 'r41i1p1f1',
#         'r42i1p1f1', 'r43i1p1f1', 'r44i1p1f1', 'r45i1p1f1', 'r46i1p1f1',
#         'r47i1p1f1', 'r48i1p1f1', 'r49i1p1f1', 'r4i1p1f1', 'r50i1p1f1',
#         'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1', 'r9i1p1f1'],
#        dtype=object),
#  'MPI-ESM-1-2-HAM': array(['r1i1p1f1'], dtype=object),
#  'MPI-ESM1-2-HR': array(['r1i1p1f1'], dtype=object),
#  'MPI-ESM1-2-LR': array(['r10i1p1f99', 'r1i1p1f1', 'r1i1p1f99', 'r2i1p1f99', 'r3i1p1f99',
#         'r4i1p1f99', 'r5i1p1f99', 'r6i1p1f99', 'r7i1p1f99', 'r8i1p1f99',
#         'r9i1p1f99'], dtype=object),
#  'MRI-ESM2-0': array(['r1i1p1f1', 'r1i1p2f1', 'r1i1p3f1', 'r1i1p4f1', 'r1i3p1f1',
#         'r2i1p1f1', 'r2i3p1f1', 'r3i1p1f1', 'r3i3p1f1', 'r4i1p1f1',
#         'r4i3p1f1', 'r5i1p1f1', 'r5i3p1f1'], dtype=object),
#  'NESM3': array(['r1i1p1f1'], dtype=object),
#  'NorCPM1': array(['r1i1p1f1'], dtype=object),
#  'NorESM2-LM': array(['r10i1p1f2', 'r1i1p1f1', 'r1i1p1f2', 'r2i1p1f1', 'r2i1p1f2',
#         'r3i1p1f1', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2',
#         'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2'], dtype=object),
#  'NorESM2-MM': array(['r1i1p1f1'], dtype=object),
#  'SAM0-UNICON': array(['r1i1p1f1'], dtype=object),
#  'TaiESM1': array(['r1i1p1f1'], dtype=object),
#  'TaiESM1-TIMCOM': array(['r1i1p1f1', 'r1i1p2f1'], dtype=object),
#  'TaiESM1-TIMCOM2': array(['r1i1p1f1'], dtype=object),
#  'UKESM1-0-LL': array(['r1i1p1f2'], dtype=object)}

# %%
# List all models of the catalog that have 
# `umo` and `vmo` and `mlotst`
# and display these models as a dictionary where the keys are the models 
# and the values are lists of the members that have these variables
models = np.sort(cat.search(variable_id = ['umo', 'uo', 'vmo', 'vo', 'mlotst']).df.source_id.unique())
models_dict = {}
for model in models:
    members = np.sort(cat.search(source_id = model, variable_id = ['umo', 'uo', 'vmo', 'vo', 'mlotst']).df.member_id.unique())
    models_dict[model] = members
models_dict
# Out:
# {'ACCESS-OM2': array(['r1i1p1f1'], dtype=object),
#  'ACCESS-OM2-025': array(['r1i1p1f1'], dtype=object),
#  'AWI-CM-1-1-MR': array(['r1i1p1f1'], dtype=object),
#  'AWI-ESM-1-1-LR': array(['r1i1p1f1'], dtype=object),
#  'BCC-CSM2-MR': array(['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'], dtype=object),
#  'BCC-ESM1': array(['r1i1p1f1'], dtype=object),
#  'CAMS-CSM1-0': array(['r1i1p1f1', 'r1i1p1f2'], dtype=object),
#  'CAS-ESM2-0': array(['r1i1p1f1'], dtype=object),
#  'CESM1-CAM5-SE-HR': array(['r1i1p1f1'], dtype=object),
#  'CESM2': array(['r101i1p1f1', 'r102i1p1f1', 'r103i1p1f1', 'r1i1p1f1', 'r2i1p1f1',
#         'r3i1p1f1'], dtype=object),
#  'CESM2-FV2': array(['r1i1p1f1'], dtype=object),
#  'CESM2-WACCM': array(['r1i1p1f1'], dtype=object),
#  'CESM2-WACCM-FV2': array(['r1i1p1f1'], dtype=object),
#  'CIESM': array(['r1i1p1f1'], dtype=object),
#  'CMCC-CM2-HR4': array(['r1i1p1f1'], dtype=object),
#  'CMCC-CM2-SR5': array(['r1i1p1f1'], dtype=object),
#  'CMCC-CM2-VHR4': array(['r1i1p1f1'], dtype=object),
#  'CMCC-ESM2': array(['r1i1p1f1'], dtype=object),
#  'CNRM-CM6-1': array(['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2',
#         'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2'],
#        dtype=object),
#  'CNRM-CM6-1-HR': array(['r1i1p1f2'], dtype=object),
#  'CNRM-ESM2-1': array(['r1i1p1f2'], dtype=object),
#  'CanESM5': array(['r10i1p1f1', 'r1i1p1f1', 'r1i1p2f1', 'r2i1p1f1', 'r3i1p1f1',
#         'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1',
#         'r9i1p1f1'], dtype=object),
#  'CanESM5-CanOE': array(['r1i1p2f1'], dtype=object),
#  'E3SM-1-0': array(['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'], dtype=object),
#  'E3SM-1-1': array(['r1i1p1f1'], dtype=object),
#  'E3SM-1-1-ECA': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3': array(['r10i1p1f2', 'r11i1p1f1', 'r12i1p1f2', 'r13i1p1f1', 'r13i1p1f2',
#         'r15i1p1f1', 'r15i1p1f2', 'r16i1p1f2', 'r17i1p1f2', 'r18i1p1f2',
#         'r19i1p1f2', 'r1i1p1f1', 'r1i1p1f2', 'r20i1p1f2', 'r21i1p1f2',
#         'r22i1p1f2', 'r23i1p1f2', 'r24i1p1f2', 'r25i1p1f2', 'r26i1p1f2',
#         'r27i1p1f2', 'r28i1p1f2', 'r29i1p1f2', 'r2i1p1f2', 'r30i1p1f2',
#         'r4i1p1f2', 'r6i1p1f1', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2',
#         'r9i1p1f1'], dtype=object),
#  'EC-Earth3-AerChem': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3-CC': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3-LR': array(['r1i1p1f1'], dtype=object),
#  'EC-Earth3-Veg': array(['r12i1p1f1', 'r14i1p1f1', 'r1i1p1f1'], dtype=object),
#  'EC-Earth3-Veg-LR': array(['r1i1p1f1'], dtype=object),
#  'FGOALS-f3-H': array(['r1i1p1f1'], dtype=object),
#  'FGOALS-f3-L': array(['r1i1p1f1'], dtype=object),
#  'FGOALS-g3': array(['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'], dtype=object),
#  'FIO-ESM-2-0': array(['r1i1p1f1'], dtype=object),
#  'GFDL-CM4': array(['r1i1p1f1'], dtype=object),
#  'GFDL-OM4p5B': array(['r1i1p1f1'], dtype=object),
#  'GISS-E2-1-G': array(['r10i1p1f3', 'r10i1p5f2', 'r1i1p1f1', 'r1i1p1f2', 'r1i1p1f3',
#         'r1i1p1f4', 'r1i1p3f1', 'r1i1p5f2', 'r2i1p1f1', 'r2i1p1f2',
#         'r2i1p1f3', 'r2i1p1f4', 'r2i1p3f1', 'r2i1p5f2', 'r3i1p1f1',
#         'r3i1p1f2', 'r3i1p1f3', 'r3i1p1f4', 'r3i1p3f1', 'r3i1p5f2',
#         'r4i1p1f1', 'r4i1p1f2', 'r4i1p1f3', 'r4i1p1f4', 'r4i1p3f1',
#         'r4i1p5f2', 'r5i1p1f1', 'r5i1p1f2', 'r5i1p1f3', 'r5i1p1f4',
#         'r5i1p3f1', 'r5i1p5f2', 'r6i1p1f3', 'r6i1p5f2', 'r7i1p1f3',
#         'r7i1p5f2', 'r8i1p1f3', 'r8i1p5f2', 'r9i1p1f3', 'r9i1p5f2'],
#        dtype=object),
#  'GISS-E2-1-G-CC': array(['r1i1p1f1'], dtype=object),
#  'GISS-E2-1-H': array(['r1i1p1f1', 'r1i1p1f2'], dtype=object),
#  'GISS-E2-2-G': array(['r1i1p1f1', 'r1i1p1f2', 'r1i1p3f1', 'r2i1p1f1', 'r2i1p1f2',
#         'r2i1p3f1', 'r3i1p1f1', 'r3i1p1f2', 'r3i1p3f1', 'r4i1p1f1',
#         'r4i1p1f2', 'r4i1p3f1', 'r5i1p1f1', 'r5i1p1f2', 'r5i1p3f1'],
#        dtype=object),
#  'GISS-E2-2-H': array(['r1i1p1f1'], dtype=object),
#  'HadGEM3-GC31-LL': array(['r10i1p1f3', 'r1i1p1f1', 'r1i1p1f3', 'r2i1p1f3', 'r3i1p1f3',
#         'r4i1p1f3', 'r5i1p1f3', 'r6i1p1f3', 'r7i1p1f3', 'r8i1p1f3',
#         'r9i1p1f3'], dtype=object),
#  'HadGEM3-GC31-MM': array(['r1i1p1f1'], dtype=object),
#  'ICON-ESM-LR': array(['r1i1p1f1'], dtype=object),
#  'IITM-ESM': array(['r1i1p1f1'], dtype=object),
#  'INM-CM4-8': array(['r1i1p1f1'], dtype=object),
#  'INM-CM5-0': array(['r1i1p1f1'], dtype=object),
#  'IPSL-CM5A2-INCA': array(['r1i1p1f1'], dtype=object),
#  'IPSL-CM6A-LR': array(['r10i1p1f1', 'r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1',
#         'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1', 'r9i1p1f1'],
#        dtype=object),
#  'IPSL-CM6A-LR-INCA': array(['r1i1p1f1'], dtype=object),
#  'KIOST-ESM': array(['r1i1p1f1'], dtype=object),
#  'MCM-UA-1-0': array(['r1i1p1f1', 'r1i1p1f2'], dtype=object),
#  'MIROC-ES2L': array(['r10i1p1f242', 'r11i1p1f242', 'r12i1p1f242', 'r13i1p1f242',
#         'r14i1p1f242', 'r15i1p1f242', 'r16i1p1f242', 'r17i1p1f242',
#         'r18i1p1f242', 'r19i1p1f242', 'r1i1p1f2', 'r1i1p1f242',
#         'r20i1p1f242', 'r21i1p1f242', 'r22i1p1f242', 'r23i1p1f242',
#         'r24i1p1f242', 'r25i1p1f242', 'r26i1p1f242', 'r27i1p1f242',
#         'r28i1p1f242', 'r29i1p1f242', 'r2i1p1f242', 'r30i1p1f242',
#         'r3i1p1f242', 'r4i1p1f242', 'r5i1p1f242', 'r6i1p1f242',
#         'r7i1p1f242', 'r8i1p1f242', 'r9i1p1f242'], dtype=object),
#  'MIROC6': array(['r10i1p1f1', 'r11i1p1f1', 'r12i1p1f1', 'r13i1p1f1', 'r14i1p1f1',
#         'r15i1p1f1', 'r16i1p1f1', 'r17i1p1f1', 'r18i1p1f1', 'r19i1p1f1',
#         'r1i1p1f1', 'r20i1p1f1', 'r21i1p1f1', 'r22i1p1f1', 'r23i1p1f1',
#         'r24i1p1f1', 'r25i1p1f1', 'r26i1p1f1', 'r27i1p1f1', 'r28i1p1f1',
#         'r29i1p1f1', 'r2i1p1f1', 'r30i1p1f1', 'r31i1p1f1', 'r32i1p1f1',
#         'r33i1p1f1', 'r34i1p1f1', 'r35i1p1f1', 'r36i1p1f1', 'r37i1p1f1',
#         'r38i1p1f1', 'r39i1p1f1', 'r3i1p1f1', 'r40i1p1f1', 'r41i1p1f1',
#         'r42i1p1f1', 'r43i1p1f1', 'r44i1p1f1', 'r45i1p1f1', 'r46i1p1f1',
#         'r47i1p1f1', 'r48i1p1f1', 'r49i1p1f1', 'r4i1p1f1', 'r50i1p1f1',
#         'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1', 'r9i1p1f1'],
#        dtype=object),
#  'MPI-ESM-1-2-HAM': array(['r1i1p1f1'], dtype=object),
#  'MPI-ESM1-2-HR': array(['r1i1p1f1'], dtype=object),
#  'MPI-ESM1-2-LR': array(['r10i1p1f99', 'r1i1p1f1', 'r1i1p1f99', 'r2i1p1f99', 'r3i1p1f99',
#         'r4i1p1f99', 'r5i1p1f99', 'r6i1p1f99', 'r7i1p1f99', 'r8i1p1f99',
#         'r9i1p1f99'], dtype=object),
#  'MRI-ESM2-0': array(['r1i1p1f1', 'r1i1p2f1', 'r1i1p3f1', 'r1i1p4f1', 'r1i3p1f1',
#         'r2i1p1f1', 'r2i3p1f1', 'r3i1p1f1', 'r3i3p1f1', 'r4i1p1f1',
#         'r4i3p1f1', 'r5i1p1f1', 'r5i3p1f1'], dtype=object),
#  'NESM3': array(['r1i1p1f1'], dtype=object),
#  'NorCPM1': array(['r1i1p1f1'], dtype=object),
#  'NorESM2-LM': array(['r10i1p1f2', 'r1i1p1f1', 'r1i1p1f2', 'r2i1p1f1', 'r2i1p1f2',
#         'r3i1p1f1', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2',
#         'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2'], dtype=object),
#  'NorESM2-MM': array(['r1i1p1f1'], dtype=object),
#  'SAM0-UNICON': array(['r1i1p1f1'], dtype=object),
#  'TaiESM1': array(['r1i1p1f1'], dtype=object),
#  'TaiESM1-TIMCOM': array(['r1i1p1f1', 'r1i1p2f1'], dtype=object),
#  'TaiESM1-TIMCOM2': array(['r1i1p1f1'], dtype=object),
#  'UKESM1-0-LL': array(['r1i1p1f2'], dtype=object)}

# %%
cat.search(variable_id="mlotstmax")
# Out:
# <p><strong>cmip6-oi10 catalog with 10 dataset(s) from 1164 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>path</th>
#       <td>1164</td>
#     </tr>
#     <tr>
#       <th>file_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>project_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>173</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
def list_models_and_members_that_have(cat, variables):
    """
    find the list of models and their members that have all the variables: 'uo', 'vo', and 'mlotst'.
    """
    # Step 1: Filter the dataframe to include only the specified variables
    filtered_df = cat.search(variable_id = variables).df
    
    # Step 2: Group by 'model' and 'member'
    grouped = filtered_df.groupby(['source_id', 'member_id'])
    
    # Step 3: Find groups that contain all three variables
    valid_groups = grouped.filter(lambda x: set(variables).issubset(set(x['variable_id'])))
    
    # Step 4: Get the list of models and their members
    result = valid_groups[['source_id', 'member_id']].drop_duplicates().reset_index(drop=True)
    
    # Step 5: Sort the result by model
    result_sorted = result.sort_values(by='source_id')

    # Setp 6: Regroup by model
    grouped_result_sorted = result_sorted.groupby('source_id')
    
    return grouped_result_sorted.apply(display)

# %%
def summary_variable_availability(df):

    # Step 1: Filter the dataframe to include only the specified variables
    filtered_df_1 = df[df['variable_id'].isin(['umo', 'vmo'])]
    filtered_df_2 = df[df['variable_id'].isin(['uo', 'vo'])]
    filtered_df_3 = df[df['variable_id'].isin(['mlotst'])]
    filtered_df_4 = df[df['variable_id'].isin(['mlotstmax'])]
    
    # Step 2: Group by 'source_id' and 'member_id'
    grouped_1 = filtered_df_1.groupby(['experiment_id', 'source_id', 'member_id'])
    grouped_2 = filtered_df_2.groupby(['experiment_id', 'source_id', 'member_id'])
    grouped_3 = filtered_df_3.groupby(['experiment_id', 'source_id', 'member_id'])
    grouped_4 = filtered_df_4.groupby(['experiment_id', 'source_id', 'member_id'])
    
    # Step 3: Find groups that contain all the variables in each set
    valid_groups_1 = grouped_1.filter(lambda x: set(['umo', 'vmo']).issubset(set(x['variable_id'])))
    valid_groups_2 = grouped_2.filter(lambda x: set(['uo', 'vo']).issubset(set(x['variable_id'])))
    valid_groups_3 = grouped_3.filter(lambda x: set(['mlotst']).issubset(set(x['variable_id'])))
    valid_groups_4 = grouped_4.filter(lambda x: set(['mlotstmax']).issubset(set(x['variable_id'])))
    
    # Step 4: Get the list of source_id and their member_id for each set
    result_1 = valid_groups_1[['experiment_id', 'source_id', 'member_id']].drop_duplicates().reset_index(drop=True)
    result_2 = valid_groups_2[['experiment_id', 'source_id', 'member_id']].drop_duplicates().reset_index(drop=True)
    result_3 = valid_groups_3[['experiment_id', 'source_id', 'member_id']].drop_duplicates().reset_index(drop=True)
    result_4 = valid_groups_4[['experiment_id', 'source_id', 'member_id']].drop_duplicates().reset_index(drop=True)
    
    # Step 5: Group by 'source_id' and aggregate member_id into a list for each set
    final_result_1 = result_1.groupby(['experiment_id', 'source_id'])['member_id'].apply(list).reset_index()
    final_result_2 = result_2.groupby(['experiment_id', 'source_id'])['member_id'].apply(list).reset_index()
    final_result_3 = result_3.groupby(['experiment_id', 'source_id'])['member_id'].apply(list).reset_index()
    final_result_4 = result_4.groupby(['experiment_id', 'source_id'])['member_id'].apply(list).reset_index()
    
    # Step 6: Merge the results into a single dataframe
    merged_result_1 = pd.merge(final_result_1, final_result_2, on=['experiment_id', 'source_id'], how='outer', suffixes=('_umo_vmo', '_uo_vo'))
    merged_result_2 = pd.merge(merged_result_1, final_result_3, on=['experiment_id', 'source_id'], how='outer', suffixes=('', '_mlotst'))
    merged_result_3 = pd.merge(merged_result_2, final_result_4, on=['experiment_id', 'source_id'], how='outer', suffixes=('', '_mlotstmax'))

    final_restult = merged_result_3.sort_values(by='source_id')
    
    return final_restult

# %%
summary_variable_availability(cat.df)
# Out:
#            experiment_id          source_id  \
# 236                omip2         ACCESS-OM2
# 237                omip2     ACCESS-OM2-025
# 0                1pctCO2      AWI-CM-1-1-MR
# 342               ssp245      AWI-CM-1-1-MR
# 49          abrupt-4xCO2      AWI-CM-1-1-MR
# 307               ssp126      AWI-CM-1-1-MR
# 251            piControl      AWI-CM-1-1-MR
# 417               ssp585      AWI-CM-1-1-MR
# 164           historical      AWI-CM-1-1-MR
# 1                1pctCO2     AWI-ESM-1-1-LR
# 165           historical     AWI-ESM-1-1-LR
# 252            piControl     AWI-ESM-1-1-LR
# 343               ssp245        BCC-CSM2-MR
# 2                1pctCO2        BCC-CSM2-MR
# 50          abrupt-4xCO2        BCC-CSM2-MR
# 308               ssp126        BCC-CSM2-MR
# 138             hist-nat        BCC-CSM2-MR
# 166           historical        BCC-CSM2-MR
# 253            piControl        BCC-CSM2-MR
# 418               ssp585        BCC-CSM2-MR
# 115             hist-GHG        BCC-CSM2-MR
# 127             hist-aer        BCC-CSM2-MR
# 3                1pctCO2           BCC-ESM1
# 51          abrupt-4xCO2           BCC-ESM1
# 167           historical           BCC-ESM1
# 254            piControl           BCC-ESM1
# 52          abrupt-4xCO2        CAMS-CSM1-0
# 168           historical        CAMS-CSM1-0
# 344               ssp245        CAMS-CSM1-0
# 255            piControl        CAMS-CSM1-0
# 309               ssp126        CAMS-CSM1-0
# 4                1pctCO2        CAMS-CSM1-0
# 419               ssp585        CAMS-CSM1-0
# 420               ssp585         CAS-ESM2-0
# 53          abrupt-4xCO2         CAS-ESM2-0
# 310               ssp126         CAS-ESM2-0
# 219                omip1         CAS-ESM2-0
# 345               ssp245         CAS-ESM2-0
# 256            piControl         CAS-ESM2-0
# 169           historical         CAS-ESM2-0
# 5                1pctCO2         CAS-ESM2-0
# 110            hist-1950   CESM1-CAM5-SE-HR
# 99          control-1950   CESM1-CAM5-SE-HR
# 107       highres-future   CESM1-CAM5-SE-HR
# 384           ssp245-aer              CESM2
# 220                omip1              CESM2
# 54          abrupt-4xCO2              CESM2
# 128             hist-aer              CESM2
# 116             hist-GHG              CESM2
# 170           historical              CESM2
# 6                1pctCO2              CESM2
# 238                omip2              CESM2
# 257            piControl              CESM2
# 139             hist-nat              CESM2
# 7                1pctCO2          CESM2-FV2
# 171           historical          CESM2-FV2
# 55          abrupt-4xCO2          CESM2-FV2
# 258            piControl          CESM2-FV2
# 259            piControl        CESM2-WACCM
# 311               ssp126        CESM2-WACCM
# 8                1pctCO2        CESM2-WACCM
# 172           historical        CESM2-WACCM
# 56          abrupt-4xCO2        CESM2-WACCM
# 346               ssp245        CESM2-WACCM
# 421               ssp585        CESM2-WACCM
# 9                1pctCO2    CESM2-WACCM-FV2
# 173           historical    CESM2-WACCM-FV2
# 57          abrupt-4xCO2    CESM2-WACCM-FV2
# 260            piControl    CESM2-WACCM-FV2
# 10               1pctCO2              CIESM
# 174           historical              CIESM
# 58          abrupt-4xCO2              CIESM
# 347               ssp245              CIESM
# 312               ssp126              CIESM
# 422               ssp585              CIESM
# 261            piControl              CIESM
# 175           historical       CMCC-CM2-HR4
# 11               1pctCO2       CMCC-CM2-HR4
# 239                omip2       CMCC-CM2-HR4
# 59          abrupt-4xCO2       CMCC-CM2-HR4
# 12               1pctCO2       CMCC-CM2-SR5
# 262            piControl       CMCC-CM2-SR5
# 176           historical       CMCC-CM2-SR5
# 221                omip1       CMCC-CM2-SR5
# 423               ssp585       CMCC-CM2-SR5
# 313               ssp126       CMCC-CM2-SR5
# 348               ssp245       CMCC-CM2-SR5
# 60          abrupt-4xCO2       CMCC-CM2-SR5
# 240                omip2       CMCC-CM2-SR5
# 100         control-1950      CMCC-CM2-VHR4
# 108       highres-future      CMCC-CM2-VHR4
# 111            hist-1950      CMCC-CM2-VHR4
# 177           historical          CMCC-ESM2
# 13               1pctCO2          CMCC-ESM2
# 222                omip1          CMCC-ESM2
# 263            piControl          CMCC-ESM2
# 61          abrupt-4xCO2          CMCC-ESM2
# 349               ssp245          CMCC-ESM2
# 424               ssp585          CMCC-ESM2
# 314               ssp126          CMCC-ESM2
# 62          abrupt-4xCO2         CNRM-CM6-1
# 14               1pctCO2         CNRM-CM6-1
# 350               ssp245         CNRM-CM6-1
# 129             hist-aer         CNRM-CM6-1
# 264            piControl         CNRM-CM6-1
# 178           historical         CNRM-CM6-1
# 223                omip1         CNRM-CM6-1
# 241                omip2         CNRM-CM6-1
# 117             hist-GHG         CNRM-CM6-1
# 315               ssp126         CNRM-CM6-1
# 425               ssp585         CNRM-CM6-1
# 140             hist-nat         CNRM-CM6-1
# 242                omip2      CNRM-CM6-1-HR
# 351               ssp245      CNRM-CM6-1-HR
# 179           historical      CNRM-CM6-1-HR
# 63          abrupt-4xCO2      CNRM-CM6-1-HR
# 316               ssp126      CNRM-CM6-1-HR
# 426               ssp585      CNRM-CM6-1-HR
# 265            piControl      CNRM-CM6-1-HR
# 15               1pctCO2      CNRM-CM6-1-HR
# 427               ssp585        CNRM-ESM2-1
# 180           historical        CNRM-ESM2-1
# 266            piControl        CNRM-ESM2-1
# 224                omip1        CNRM-ESM2-1
# 317               ssp126        CNRM-ESM2-1
# 16               1pctCO2        CNRM-ESM2-1
# 352               ssp245        CNRM-ESM2-1
# 64          abrupt-4xCO2        CNRM-ESM2-1
# 141             hist-nat            CanESM5
# 160            hist-volc            CanESM5
# 407           ssp245-nat            CanESM5
# 428               ssp585            CanESM5
# 118             hist-GHG            CanESM5
# 181           historical            CanESM5
# 113             hist-CO2            CanESM5
# 225                omip1            CanESM5
# 17               1pctCO2            CanESM5
# 412       ssp245-stratO3            CanESM5
# 267            piControl            CanESM5
# 154         hist-stratO3            CanESM5
# 65          abrupt-4xCO2            CanESM5
# 318               ssp126            CanESM5
# 353               ssp245            CanESM5
# 378           ssp245-GHG            CanESM5
# 385           ssp245-aer            CanESM5
# 130             hist-aer            CanESM5
# 149             hist-sol            CanESM5
# 226                omip1      CanESM5-CanOE
# 18               1pctCO2           E3SM-1-0
# 66          abrupt-4xCO2           E3SM-1-0
# 119             hist-GHG           E3SM-1-0
# 268            piControl           E3SM-1-0
# 182           historical           E3SM-1-0
# 183           historical           E3SM-1-1
# 269            piControl           E3SM-1-1
# 429               ssp585           E3SM-1-1
# 270            piControl       E3SM-1-1-ECA
# 184           historical       E3SM-1-1-ECA
# 227                omip1          EC-Earth3
# 243                omip2          EC-Earth3
# 415               ssp370          EC-Earth3
# 430               ssp585          EC-Earth3
# 354               ssp245          EC-Earth3
# 185           historical          EC-Earth3
# 389    ssp245-cov-fossil          EC-Earth3
# 393  ssp245-cov-modgreen          EC-Earth3
# 397  ssp245-cov-strgreen          EC-Earth3
# 401         ssp245-covid          EC-Earth3
# 271            piControl          EC-Earth3
# 319               ssp126          EC-Earth3
# 67          abrupt-4xCO2  EC-Earth3-AerChem
# 186           historical  EC-Earth3-AerChem
# 19               1pctCO2  EC-Earth3-AerChem
# 355               ssp245       EC-Earth3-CC
# 187           historical       EC-Earth3-CC
# 20               1pctCO2       EC-Earth3-CC
# 68          abrupt-4xCO2       EC-Earth3-CC
# 431               ssp585       EC-Earth3-CC
# 272            piControl       EC-Earth3-CC
# 273            piControl       EC-Earth3-LR
# 274            piControl      EC-Earth3-Veg
# 21               1pctCO2      EC-Earth3-Veg
# 320               ssp126      EC-Earth3-Veg
# 356               ssp245      EC-Earth3-Veg
# 416               ssp370      EC-Earth3-Veg
# 69          abrupt-4xCO2      EC-Earth3-Veg
# 432               ssp585      EC-Earth3-Veg
# 188           historical      EC-Earth3-Veg
# 433               ssp585   EC-Earth3-Veg-LR
# 321               ssp126   EC-Earth3-Veg-LR
# 357               ssp245   EC-Earth3-Veg-LR
# 275            piControl   EC-Earth3-Veg-LR
# 189           historical   EC-Earth3-Veg-LR
# 112            hist-1950        FGOALS-f3-H
# 109       highres-future        FGOALS-f3-H
# 244                omip2        FGOALS-f3-H
# 101         control-1950        FGOALS-f3-H
# 322               ssp126        FGOALS-f3-L
# 276            piControl        FGOALS-f3-L
# 434               ssp585        FGOALS-f3-L
# 245                omip2        FGOALS-f3-L
# 228                omip1        FGOALS-f3-L
# 358               ssp245        FGOALS-f3-L
# 190           historical        FGOALS-f3-L
# 70          abrupt-4xCO2        FGOALS-f3-L
# 22               1pctCO2        FGOALS-f3-L
# 131             hist-aer          FGOALS-g3
# 191           historical          FGOALS-g3
# 71          abrupt-4xCO2          FGOALS-g3
# 142             hist-nat          FGOALS-g3
# 323               ssp126          FGOALS-g3
# 359               ssp245          FGOALS-g3
# 435               ssp585          FGOALS-g3
# 277            piControl          FGOALS-g3
# 120             hist-GHG          FGOALS-g3
# 436               ssp585        FIO-ESM-2-0
# 72          abrupt-4xCO2        FIO-ESM-2-0
# 192           historical        FIO-ESM-2-0
# 324               ssp126        FIO-ESM-2-0
# 360               ssp245        FIO-ESM-2-0
# 23               1pctCO2        FIO-ESM-2-0
# 437               ssp585           GFDL-CM4
# 73          abrupt-4xCO2           GFDL-CM4
# 24               1pctCO2           GFDL-CM4
# 361               ssp245           GFDL-CM4
# 193           historical           GFDL-CM4
# 278            piControl           GFDL-CM4
# 229                omip1           GFDL-CM4
# 230                omip1        GFDL-OM4p5B
# 161            hist-volc        GISS-E2-1-G
# 386           ssp245-aer        GISS-E2-1-G
# 194           historical        GISS-E2-1-G
# 155         hist-stratO3        GISS-E2-1-G
# 402         ssp245-covid        GISS-E2-1-G
# 413       ssp245-stratO3        GISS-E2-1-G
# 150             hist-sol        GISS-E2-1-G
# 408           ssp245-nat        GISS-E2-1-G
# 143             hist-nat        GISS-E2-1-G
# 159         hist-totalO3        GISS-E2-1-G
# 279            piControl        GISS-E2-1-G
# 325               ssp126        GISS-E2-1-G
# 74          abrupt-4xCO2        GISS-E2-1-G
# 25               1pctCO2        GISS-E2-1-G
# 132             hist-aer        GISS-E2-1-G
# 121             hist-GHG        GISS-E2-1-G
# 379           ssp245-GHG        GISS-E2-1-G
# 280            piControl     GISS-E2-1-G-CC
# 195           historical     GISS-E2-1-G-CC
# 438               ssp585        GISS-E2-1-H
# 326               ssp126        GISS-E2-1-H
# 281            piControl        GISS-E2-1-H
# 362               ssp245        GISS-E2-1-H
# 75          abrupt-4xCO2        GISS-E2-1-H
# 26               1pctCO2        GISS-E2-1-H
# 196           historical        GISS-E2-1-H
# 27               1pctCO2        GISS-E2-2-G
# 151             hist-sol        GISS-E2-2-G
# 282            piControl        GISS-E2-2-G
# 76          abrupt-4xCO2        GISS-E2-2-G
# 283            piControl        GISS-E2-2-H
# 28               1pctCO2        GISS-E2-2-H
# 197           historical        GISS-E2-2-H
# 77          abrupt-4xCO2        GISS-E2-2-H
# 78          abrupt-4xCO2    HadGEM3-GC31-LL
# 122             hist-GHG    HadGEM3-GC31-LL
# 144             hist-nat    HadGEM3-GC31-LL
# 380           ssp245-GHG    HadGEM3-GC31-LL
# 439               ssp585    HadGEM3-GC31-LL
# 284            piControl    HadGEM3-GC31-LL
# 133             hist-aer    HadGEM3-GC31-LL
# 285            piControl    HadGEM3-GC31-MM
# 29               1pctCO2        ICON-ESM-LR
# 198           historical        ICON-ESM-LR
# 286            piControl        ICON-ESM-LR
# 79          abrupt-4xCO2        ICON-ESM-LR
# 287            piControl           IITM-ESM
# 30               1pctCO2           IITM-ESM
# 327               ssp126          INM-CM4-8
# 80          abrupt-4xCO2          INM-CM4-8
# 440               ssp585          INM-CM4-8
# 199           historical          INM-CM4-8
# 31               1pctCO2          INM-CM4-8
# 363               ssp245          INM-CM4-8
# 288            piControl          INM-CM4-8
# 441               ssp585          INM-CM5-0
# 200           historical          INM-CM5-0
# 364               ssp245          INM-CM5-0
# 328               ssp126          INM-CM5-0
# 289            piControl          INM-CM5-0
# 81          abrupt-4xCO2          INM-CM5-0
# 32               1pctCO2          INM-CM5-0
# 290            piControl    IPSL-CM5A2-INCA
# 82          abrupt-4xCO2    IPSL-CM5A2-INCA
# 33               1pctCO2    IPSL-CM5A2-INCA
# 201           historical    IPSL-CM5A2-INCA
# 329               ssp126       IPSL-CM6A-LR
# 231                omip1       IPSL-CM6A-LR
# 442               ssp585       IPSL-CM6A-LR
# 409           ssp245-nat       IPSL-CM6A-LR
# 83          abrupt-4xCO2       IPSL-CM6A-LR
# 123             hist-GHG       IPSL-CM6A-LR
# 202           historical       IPSL-CM6A-LR
# 365               ssp245       IPSL-CM6A-LR
# 156         hist-stratO3       IPSL-CM6A-LR
# 291            piControl       IPSL-CM6A-LR
# 134             hist-aer       IPSL-CM6A-LR
# 34               1pctCO2       IPSL-CM6A-LR
# 145             hist-nat       IPSL-CM6A-LR
# 381           ssp245-GHG       IPSL-CM6A-LR
# 84          abrupt-4xCO2  IPSL-CM6A-LR-INCA
# 203           historical  IPSL-CM6A-LR-INCA
# 330               ssp126          KIOST-ESM
# 292            piControl          KIOST-ESM
# 85          abrupt-4xCO2          KIOST-ESM
# 443               ssp585          KIOST-ESM
# 366               ssp245          KIOST-ESM
# 35               1pctCO2          KIOST-ESM
# 204           historical          KIOST-ESM
# 36               1pctCO2         MCM-UA-1-0
# 331               ssp126         MCM-UA-1-0
# 367               ssp245         MCM-UA-1-0
# 205           historical         MCM-UA-1-0
# 293            piControl         MCM-UA-1-0
# 86          abrupt-4xCO2         MCM-UA-1-0
# 444               ssp585         MCM-UA-1-0
# 368               ssp245         MIROC-ES2L
# 390    ssp245-cov-fossil         MIROC-ES2L
# 394  ssp245-cov-modgreen         MIROC-ES2L
# 398  ssp245-cov-strgreen         MIROC-ES2L
# 87          abrupt-4xCO2         MIROC-ES2L
# 403         ssp245-covid         MIROC-ES2L
# 206           historical         MIROC-ES2L
# 37               1pctCO2         MIROC-ES2L
# 445               ssp585         MIROC-ES2L
# 294            piControl         MIROC-ES2L
# 332               ssp126         MIROC-ES2L
# 232                omip1             MIROC6
# 295            piControl             MIROC6
# 382           ssp245-GHG             MIROC6
# 38               1pctCO2             MIROC6
# 246                omip2             MIROC6
# 124             hist-GHG             MIROC6
# 369               ssp245             MIROC6
# 162            hist-volc             MIROC6
# 387           ssp245-aer             MIROC6
# 102              faf-all             MIROC6
# 446               ssp585             MIROC6
# 207           historical             MIROC6
# 135             hist-aer             MIROC6
# 157         hist-stratO3             MIROC6
# 88          abrupt-4xCO2             MIROC6
# 333               ssp126             MIROC6
# 103             faf-heat             MIROC6
# 104      faf-passiveheat             MIROC6
# 105           faf-stress             MIROC6
# 106            faf-water             MIROC6
# 152             hist-sol             MIROC6
# 146             hist-nat             MIROC6
# 410           ssp245-nat             MIROC6
# 414       ssp245-stratO3             MIROC6
# 114             hist-CO2             MIROC6
# 296            piControl    MPI-ESM-1-2-HAM
# 39               1pctCO2    MPI-ESM-1-2-HAM
# 89          abrupt-4xCO2    MPI-ESM-1-2-HAM
# 208           historical    MPI-ESM-1-2-HAM
# 370               ssp245      MPI-ESM1-2-HR
# 90          abrupt-4xCO2      MPI-ESM1-2-HR
# 447               ssp585      MPI-ESM1-2-HR
# 297            piControl      MPI-ESM1-2-HR
# 209           historical      MPI-ESM1-2-HR
# 40               1pctCO2      MPI-ESM1-2-HR
# 334               ssp126      MPI-ESM1-2-HR
# 210           historical      MPI-ESM1-2-LR
# 41               1pctCO2      MPI-ESM1-2-LR
# 395  ssp245-cov-modgreen      MPI-ESM1-2-LR
# 399  ssp245-cov-strgreen      MPI-ESM1-2-LR
# 391    ssp245-cov-fossil      MPI-ESM1-2-LR
# 335               ssp126      MPI-ESM1-2-LR
# 298            piControl      MPI-ESM1-2-LR
# 404         ssp245-covid      MPI-ESM1-2-LR
# 371               ssp245      MPI-ESM1-2-LR
# 448               ssp585      MPI-ESM1-2-LR
# 91          abrupt-4xCO2      MPI-ESM1-2-LR
# 153             hist-sol         MRI-ESM2-0
# 336               ssp126         MRI-ESM2-0
# 396  ssp245-cov-modgreen         MRI-ESM2-0
# 405         ssp245-covid         MRI-ESM2-0
# 211           historical         MRI-ESM2-0
# 449               ssp585         MRI-ESM2-0
# 392    ssp245-cov-fossil         MRI-ESM2-0
# 400  ssp245-cov-strgreen         MRI-ESM2-0
# 299            piControl         MRI-ESM2-0
# 92          abrupt-4xCO2         MRI-ESM2-0
# 42               1pctCO2         MRI-ESM2-0
# 233                omip1         MRI-ESM2-0
# 163            hist-volc         MRI-ESM2-0
# 147             hist-nat         MRI-ESM2-0
# 372               ssp245         MRI-ESM2-0
# 247                omip2         MRI-ESM2-0
# 136             hist-aer         MRI-ESM2-0
# 158         hist-stratO3         MRI-ESM2-0
# 125             hist-GHG         MRI-ESM2-0
# 212           historical              NESM3
# 373               ssp245              NESM3
# 43               1pctCO2              NESM3
# 337               ssp126              NESM3
# 93          abrupt-4xCO2              NESM3
# 450               ssp585              NESM3
# 300            piControl              NESM3
# 301            piControl            NorCPM1
# 213           historical            NorCPM1
# 451               ssp585         NorESM2-LM
# 148             hist-nat         NorESM2-LM
# 406         ssp245-covid         NorESM2-LM
# 137             hist-aer         NorESM2-LM
# 126             hist-GHG         NorESM2-LM
# 214           historical         NorESM2-LM
# 234                omip1         NorESM2-LM
# 94          abrupt-4xCO2         NorESM2-LM
# 248                omip2         NorESM2-LM
# 411           ssp245-nat         NorESM2-LM
# 338               ssp126         NorESM2-LM
# 302            piControl         NorESM2-LM
# 388           ssp245-aer         NorESM2-LM
# 383           ssp245-GHG         NorESM2-LM
# 44               1pctCO2         NorESM2-LM
# 374               ssp245         NorESM2-LM
# 95          abrupt-4xCO2         NorESM2-MM
# 215           historical         NorESM2-MM
# 339               ssp126         NorESM2-MM
# 45               1pctCO2         NorESM2-MM
# 375               ssp245         NorESM2-MM
# 303            piControl         NorESM2-MM
# 96          abrupt-4xCO2        SAM0-UNICON
# 46               1pctCO2        SAM0-UNICON
# 216           historical        SAM0-UNICON
# 304            piControl        SAM0-UNICON
# 305            piControl            TaiESM1
# 47               1pctCO2            TaiESM1
# 97          abrupt-4xCO2            TaiESM1
# 376               ssp245            TaiESM1
# 452               ssp585            TaiESM1
# 340               ssp126            TaiESM1
# 217           historical            TaiESM1
# 235                omip1     TaiESM1-TIMCOM
# 249                omip2     TaiESM1-TIMCOM
# 250                omip2    TaiESM1-TIMCOM2
# 377               ssp245        UKESM1-0-LL
# 341               ssp126        UKESM1-0-LL
# 98          abrupt-4xCO2        UKESM1-0-LL
# 306            piControl        UKESM1-0-LL
# 48               1pctCO2        UKESM1-0-LL
# 218           historical        UKESM1-0-LL
# 453               ssp585        UKESM1-0-LL
#
#                                                              member_id_umo_vmo  \
# 236                                                                        NaN
# 237                                                                        NaN
# 0                                                                          NaN
# 342                                                                        NaN
# 49                                                                         NaN
# 307                                                                        NaN
# 251                                                                        NaN
# 417                                                                        NaN
# 164                                                                        NaN
# 1                                                                          NaN
# 165                                                                        NaN
# 252                                                                        NaN
# 343                                                                 [r1i1p1f1]
# 2                                                                          NaN
# 50                                                                         NaN
# 308                                                                        NaN
# 138                                                                        NaN
# 166                                                                 [r1i1p1f1]
# 253                                                                 [r1i1p1f1]
# 418                                                                 [r1i1p1f1]
# 115                                                                        NaN
# 127                                                                        NaN
# 3                                                                          NaN
# 51                                                                         NaN
# 167                                                                 [r1i1p1f1]
# 254                                                                 [r1i1p1f1]
# 52                                                                         NaN
# 168                                                                        NaN
# 344                                                                        NaN
# 255                                                                        NaN
# 309                                                                        NaN
# 4                                                                          NaN
# 419                                                                        NaN
# 420                                                                 [r1i1p1f1]
# 53                                                                         NaN
# 310                                                                        NaN
# 219                                                                        NaN
# 345                                                                 [r1i1p1f1]
# 256                                                                 [r1i1p1f1]
# 169                                                                 [r1i1p1f1]
# 5                                                                          NaN
# 110                                                                        NaN
# 99                                                                         NaN
# 107                                                                        NaN
# 384                                                                        NaN
# 220                                                                        NaN
# 54                                                                         NaN
# 128                                                                        NaN
# 116                                                                        NaN
# 170                                                                        NaN
# 6                                                                          NaN
# 238                                                                        NaN
# 257                                                                        NaN
# 139                                                                        NaN
# 7                                                                          NaN
# 171                                                                        NaN
# 55                                                                         NaN
# 258                                                                        NaN
# 259                                                                        NaN
# 311                                                                        NaN
# 8                                                                          NaN
# 172                                                                        NaN
# 56                                                                         NaN
# 346                                                                        NaN
# 421                                                                        NaN
# 9                                                                          NaN
# 173                                                                        NaN
# 57                                                                         NaN
# 260                                                                        NaN
# 10                                                                         NaN
# 174                                                                        NaN
# 58                                                                         NaN
# 347                                                                        NaN
# 312                                                                        NaN
# 422                                                                        NaN
# 261                                                                        NaN
# 175                                                                 [r1i1p1f1]
# 11                                                                         NaN
# 239                                                                        NaN
# 59                                                                         NaN
# 12                                                                         NaN
# 262                                                                 [r1i1p1f1]
# 176                                                                 [r1i1p1f1]
# 221                                                                        NaN
# 423                                                                 [r1i1p1f1]
# 313                                                                        NaN
# 348                                                                 [r1i1p1f1]
# 60                                                                         NaN
# 240                                                                        NaN
# 100                                                                        NaN
# 108                                                                        NaN
# 111                                                                        NaN
# 177                                                                 [r1i1p1f1]
# 13                                                                         NaN
# 222                                                                        NaN
# 263                                                                 [r1i1p1f1]
# 61                                                                         NaN
# 349                                                                 [r1i1p1f1]
# 424                                                                 [r1i1p1f1]
# 314                                                                        NaN
# 62                                                                         NaN
# 14                                                                         NaN
# 350                                                                 [r1i1p1f2]
# 129                                                                        NaN
# 264                                                                 [r1i1p1f2]
# 178                                                                 [r1i1p1f2]
# 223                                                                        NaN
# 241                                                                        NaN
# 117                                                                        NaN
# 315                                                                        NaN
# 425                                                                 [r1i1p1f2]
# 140                                                                        NaN
# 242                                                                        NaN
# 351                                                                 [r1i1p1f2]
# 179                                                                 [r1i1p1f2]
# 63                                                                         NaN
# 316                                                                        NaN
# 426                                                                 [r1i1p1f2]
# 265                                                                 [r1i1p1f2]
# 15                                                                         NaN
# 427                                                                 [r1i1p1f2]
# 180                                                                 [r1i1p1f2]
# 266                                                                 [r1i1p1f2]
# 224                                                                        NaN
# 317                                                                        NaN
# 16                                                                         NaN
# 352                                                                 [r1i1p1f2]
# 64                                                                         NaN
# 141                                                                        NaN
# 160                                                                        NaN
# 407                                                                        NaN
# 428                                                                 [r1i1p1f1]
# 118                                                                        NaN
# 181                                                                 [r1i1p1f1]
# 113                                                                        NaN
# 225                                                                        NaN
# 17                                                                         NaN
# 412                                                                        NaN
# 267                                                                 [r1i1p1f1]
# 154                                                                        NaN
# 65                                                                         NaN
# 318                                                                        NaN
# 353                                                                 [r1i1p1f1]
# 378                                                                        NaN
# 385                                                                        NaN
# 130                                                                        NaN
# 149                                                                        NaN
# 226                                                                        NaN
# 18                                                                         NaN
# 66                                                                         NaN
# 119                                                                        NaN
# 268                                                                        NaN
# 182                                                                        NaN
# 183                                                                        NaN
# 269                                                                        NaN
# 429                                                                        NaN
# 270                                                                        NaN
# 184                                                                        NaN
# 227                                                                        NaN
# 243                                                                        NaN
# 415                      [r15i1p1f1, r11i1p1f1, r9i1p1f1, r13i1p1f1, r6i1p1f1]
# 430                      [r15i1p1f1, r6i1p1f1, r1i1p1f1, r13i1p1f1, r11i1p1f1]
# 354  [r13i1p1f1, r1i1p1f2, r11i1p1f1, r1i1p1f1, r6i1p1f1, r9i1p1f1, r15i1p1f1]
# 185            [r1i1p1f1, r9i1p1f1, r15i1p1f1, r6i1p1f1, r11i1p1f1, r13i1p1f1]
# 389                                                                        NaN
# 393                                                                        NaN
# 397                                                                        NaN
# 401                                                                        NaN
# 271                                                                 [r1i1p1f1]
# 319                      [r11i1p1f1, r15i1p1f1, r13i1p1f1, r6i1p1f1, r9i1p1f1]
# 67                                                                         NaN
# 186                                                                 [r1i1p1f1]
# 19                                                                         NaN
# 355                                                                 [r1i1p1f1]
# 187                                                                 [r1i1p1f1]
# 20                                                                         NaN
# 68                                                                         NaN
# 431                                                                 [r1i1p1f1]
# 272                                                                 [r1i1p1f1]
# 273                                                                 [r1i1p1f1]
# 274                                                                 [r1i1p1f1]
# 21                                                                         NaN
# 320                                                     [r14i1p1f1, r12i1p1f1]
# 356                                           [r1i1p1f1, r12i1p1f1, r14i1p1f1]
# 416                                                                [r12i1p1f1]
# 69                                                                         NaN
# 432                                                      [r1i1p1f1, r12i1p1f1]
# 188                                           [r12i1p1f1, r14i1p1f1, r1i1p1f1]
# 433                                                                 [r1i1p1f1]
# 321                                                                        NaN
# 357                                                                 [r1i1p1f1]
# 275                                                                 [r1i1p1f1]
# 189                                                                 [r1i1p1f1]
# 112                                                                        NaN
# 109                                                                        NaN
# 244                                                                        NaN
# 101                                                                        NaN
# 322                                                                        NaN
# 276                                                                 [r1i1p1f1]
# 434                                                                 [r1i1p1f1]
# 245                                                                        NaN
# 228                                                                        NaN
# 358                                                                 [r1i1p1f1]
# 190                                                                 [r1i1p1f1]
# 70                                                                         NaN
# 22                                                                         NaN
# 131                                                                        NaN
# 191                                                                 [r1i1p1f1]
# 71                                                                         NaN
# 142                                                                        NaN
# 323                                                                        NaN
# 359                                                                 [r1i1p1f1]
# 435                                                                 [r1i1p1f1]
# 277                                                                 [r1i1p1f1]
# 120                                                                        NaN
# 436                                                                        NaN
# 72                                                                         NaN
# 192                                                                        NaN
# 324                                                                        NaN
# 360                                                                        NaN
# 23                                                                         NaN
# 437                                                                        NaN
# 73                                                                         NaN
# 24                                                                         NaN
# 361                                                                        NaN
# 193                                                                        NaN
# 278                                                                        NaN
# 229                                                                        NaN
# 230                                                                        NaN
# 161                                                                        NaN
# 386                                                                        NaN
# 194                                                       [r1i1p1f2, r1i1p1f1]
# 155                                                                        NaN
# 402                                                                        NaN
# 413                                                                        NaN
# 150                                                                        NaN
# 408                                                                        NaN
# 143                                                                        NaN
# 159                                                                        NaN
# 279                                                       [r1i1p1f1, r1i1p1f2]
# 325                                                                        NaN
# 74                                                                         NaN
# 25                                                                         NaN
# 132                                                                        NaN
# 121                                                                        NaN
# 379                                                                        NaN
# 280                                                                 [r1i1p1f1]
# 195                                                                 [r1i1p1f1]
# 438                                                                 [r1i1p1f2]
# 326                                                                        NaN
# 281                                                                 [r1i1p1f1]
# 362                                                                 [r1i1p1f2]
# 75                                                                         NaN
# 26                                                                         NaN
# 196                                                       [r1i1p1f1, r1i1p1f2]
# 27                                                                         NaN
# 151                                                                        NaN
# 282                                                                 [r1i1p1f1]
# 76                                                                         NaN
# 283                                                                 [r1i1p1f1]
# 28                                                                         NaN
# 197                                                                 [r1i1p1f1]
# 77                                                                         NaN
# 78                                                                  [r1i1p1f3]
# 122                                                                        NaN
# 144                                                                        NaN
# 380                                                                        NaN
# 439                                                                 [r1i1p1f3]
# 284                                                                 [r1i1p1f1]
# 133                                                                        NaN
# 285                                                                 [r1i1p1f1]
# 29                                                                         NaN
# 198                                                                        NaN
# 286                                                                        NaN
# 79                                                                         NaN
# 287                                                                        NaN
# 30                                                                         NaN
# 327                                                                        NaN
# 80                                                                         NaN
# 440                                                                        NaN
# 199                                                                        NaN
# 31                                                                         NaN
# 363                                                                        NaN
# 288                                                                        NaN
# 441                                                                        NaN
# 200                                                                        NaN
# 364                                                                        NaN
# 328                                                                        NaN
# 289                                                                        NaN
# 81                                                                         NaN
# 32                                                                         NaN
# 290                                                                 [r1i1p1f1]
# 82                                                                         NaN
# 33                                                                         NaN
# 201                                                                 [r1i1p1f1]
# 329                                                                        NaN
# 231                                                                        NaN
# 442                                                                 [r1i1p1f1]
# 409                                                                        NaN
# 83                                                                         NaN
# 123                                                                        NaN
# 202                                                                 [r1i1p1f1]
# 365                                                                 [r1i1p1f1]
# 156                                                                        NaN
# 291                                                                 [r1i1p1f1]
# 134                                                                        NaN
# 34                                                                         NaN
# 145                                                                        NaN
# 381                                                                        NaN
# 84                                                                         NaN
# 203                                                                 [r1i1p1f1]
# 330                                                                        NaN
# 292                                                                 [r1i1p1f1]
# 85                                                                         NaN
# 443                                                                 [r1i1p1f1]
# 366                                                                 [r1i1p1f1]
# 35                                                                         NaN
# 204                                                                 [r1i1p1f1]
# 36                                                                         NaN
# 331                                                                        NaN
# 367                                                                        NaN
# 205                                                                        NaN
# 293                                                                        NaN
# ...
# 189                                                    NaN
# 112                                                    NaN
# 109                                                    NaN
# 244                                                    NaN
# 101                                                    NaN
# 322                                                    NaN
# 276                                                    NaN
# 434                                                    NaN
# 245                                                    NaN
# 228                                                    NaN
# 358                                                    NaN
# 190                                                    NaN
# 70                                                     NaN
# 22                                                     NaN
# 131                                                    NaN
# 191                                                    NaN
# 71                                                     NaN
# 142                                                    NaN
# 323                                                    NaN
# 359                                                    NaN
# 435                                                    NaN
# 277                                                    NaN
# 120                                                    NaN
# 436                                                    NaN
# 72                                                     NaN
# 192                                                    NaN
# 324                                                    NaN
# 360                                                    NaN
# 23                                                     NaN
# 437                                                    NaN
# 73                                                     NaN
# 24                                                     NaN
# 361                                                    NaN
# 193                                                    NaN
# 278                                                    NaN
# 229                                                    NaN
# 230                                                    NaN
# 161                                                    NaN
# 386                                                    NaN
# 194                                                    NaN
# 155                                                    NaN
# 402                                                    NaN
# 413                                                    NaN
# 150                                                    NaN
# 408                                                    NaN
# 143                                                    NaN
# 159                                                    NaN
# 279                                                    NaN
# 325                                                    NaN
# 74                                                     NaN
# 25                                                     NaN
# 132                                                    NaN
# 121                                                    NaN
# 379                                                    NaN
# 280                                                    NaN
# 195                                                    NaN
# 438                                                    NaN
# 326                                                    NaN
# 281                                                    NaN
# 362                                                    NaN
# 75                                                     NaN
# 26                                                     NaN
# 196                                                    NaN
# 27                                                     NaN
# 151                                                    NaN
# 282                                                    NaN
# 76                                                     NaN
# 283                                                    NaN
# 28                                                     NaN
# 197                                                    NaN
# 77                                                     NaN
# 78                                              [r1i1p1f3]
# 122                                                    NaN
# 144                                                    NaN
# 380                                                    NaN
# 439                                             [r1i1p1f3]
# 284                                             [r1i1p1f1]
# 133                                                    NaN
# 285                                                    NaN
# 29                                                     NaN
# 198                                                    NaN
# 286                                                    NaN
# 79                                                     NaN
# 287                                                    NaN
# 30                                                     NaN
# 327                                                    NaN
# 80                                                     NaN
# 440                                                    NaN
# 199                                                    NaN
# 31                                                     NaN
# 363                                                    NaN
# 288                                                    NaN
# 441                                                    NaN
# 200                                                    NaN
# 364                                                    NaN
# 328                                                    NaN
# 289                                                    NaN
# 81                                                     NaN
# 32                                                     NaN
# 290                                                    NaN
# 82                                                     NaN
# 33                                                     NaN
# 201                                                    NaN
# 329                                                    NaN
# 231                                                    NaN
# 442                                                    NaN
# 409                                                    NaN
# 83                                                     NaN
# 123                                                    NaN
# 202                                                    NaN
# 365                                                    NaN
# 156                                                    NaN
# 291                                                    NaN
# 134                                                    NaN
# 34                                                     NaN
# 145                                                    NaN
# 381                                                    NaN
# 84                                                     NaN
# 203                                                    NaN
# 330                                                    NaN
# 292                                                    NaN
# 85                                                     NaN
# 443                                                    NaN
# 366                                                    NaN
# 35                                                     NaN
# 204                                                    NaN
# 36                                                     NaN
# 331                                                    NaN
# 367                                                    NaN
# 205                                                    NaN
# 293                                                    NaN
# 86                                                     NaN
# 444                                                    NaN
# 368                                                    NaN
# 390                                                    NaN
# 394                                                    NaN
# 398                                                    NaN
# 87                                                     NaN
# 403                                                    NaN
# 206                                                    NaN
# 37                                                     NaN
# 445                                                    NaN
# 294                                                    NaN
# 332                                                    NaN
# 232                                                    NaN
# 295                                                    NaN
# 382                                                    NaN
# 38                                                     NaN
# 246                                                    NaN
# 124                                                    NaN
# 369                                                    NaN
# 162                                                    NaN
# 387                                                    NaN
# 102                                                    NaN
# 446                                                    NaN
# 207                                                    NaN
# 135                                                    NaN
# 157                                                    NaN
# 88                                                     NaN
# 333                                                    NaN
# 103                                                    NaN
# 104                                                    NaN
# 105                                                    NaN
# 106                                                    NaN
# 152                                                    NaN
# 146                                                    NaN
# 410                                                    NaN
# 414                                                    NaN
# 114                                                    NaN
# 296                                                    NaN
# 39                                                     NaN
# 89                                                     NaN
# 208                                                    NaN
# 370                                                    NaN
# 90                                                     NaN
# 447                                                    NaN
# 297                                                    NaN
# 209                                                    NaN
# 40                                                     NaN
# 334                                                    NaN
# 210                                                    NaN
# 41                                                     NaN
# 395                                                    NaN
# 399                                                    NaN
# 391                                                    NaN
# 335                                                    NaN
# 298                                                    NaN
# 404                                                    NaN
# 371                                                    NaN
# 448                                                    NaN
# 91                                                     NaN
# 153                                                    NaN
# 336                                                    NaN
# 396                                                    NaN
# 405                                                    NaN
# 211                                                    NaN
# 449                                                    NaN
# 392                                                    NaN
# 400                                                    NaN
# 299                                                    NaN
# 92                                                     NaN
# 42                                                     NaN
# 233                                                    NaN
# 163                                                    NaN
# 147                                                    NaN
# 372                                                    NaN
# 247                                                    NaN
# 136                                                    NaN
# 158                                                    NaN
# 125                                                    NaN
# 212                                                    NaN
# 373                                                    NaN
# 43                                                     NaN
# 337                                                    NaN
# 93                                                     NaN
# 450                                                    NaN
# 300                                                    NaN
# 301                                                    NaN
# 213                                                    NaN
# 451                                                    NaN
# 148                                                    NaN
# 406                                                    NaN
# 137                                                    NaN
# 126                                                    NaN
# 214                                                    NaN
# 234                                                    NaN
# 94                                                     NaN
# 248                                                    NaN
# 411                                                    NaN
# 338                                                    NaN
# 302                                                    NaN
# 388                                                    NaN
# 383                                                    NaN
# 44                                                     NaN
# 374                                                    NaN
# 95                                                     NaN
# 215                                                    NaN
# 339                                                    NaN
# 45                                                     NaN
# 375                                                    NaN
# 303                                                    NaN
# 96                                                     NaN
# 46                                                     NaN
# 216                                                    NaN
# 304                                                    NaN
# 305                                                    NaN
# 47                                                     NaN
# 97                                                     NaN
# 376                                                    NaN
# 452                                                    NaN
# 340                                                    NaN
# 217                                                    NaN
# 235                                                    NaN
# 249                                                    NaN
# 250                                                    NaN
# 377                                                    NaN
# 341                                                    NaN
# 98                                                     NaN
# 306                                                    NaN
# 48                                                     NaN
# 218                                                    NaN
# 453                                                    NaN

# %%
cat.search(source_id = "GFDL-CM4", experiment_id = "historical", realm="ocean", variable_id="mlotst").df.variable_id.unique()
# Out:
# array([], dtype=object)

# %%
list_models_and_members_that_have(cat, ['uo', 'vo', 'mlotst'])
# Out:
#         source_id member_id
# 22  AWI-CM-1-1-MR  r1i1p1f1
#          source_id member_id
# 28  AWI-ESM-1-1-LR  r1i1p1f1
#       source_id member_id
# 31  CAMS-CSM1-0  r1i1p1f1
#      source_id member_id
# 38  CAS-ESM2-0  r1i1p1f1
#    source_id member_id
# 43     CESM2  r1i1p1f1
#     source_id member_id
# 44  CESM2-FV2  r1i1p1f1
#       source_id member_id
# 35  CESM2-WACCM  r1i1p1f1
#           source_id member_id
# 45  CESM2-WACCM-FV2  r1i1p1f1
#        source_id member_id
# 42  CMCC-CM2-HR4  r1i1p1f1
#        source_id member_id
# 34  CMCC-CM2-SR5  r1i1p1f1
#     source_id member_id
# 33  CMCC-ESM2  r1i1p1f1
#      source_id member_id
# 14  CNRM-CM6-1  r1i1p1f2
#         source_id member_id
# 13  CNRM-CM6-1-HR  r1i1p1f2
#       source_id member_id
# 15  CNRM-ESM2-1  r1i1p1f2
#    source_id member_id
# 11   CanESM5  r1i1p1f1
#    source_id member_id
# 17  E3SM-1-0  r1i1p1f1
#    source_id member_id
# 20  E3SM-1-1  r1i1p1f1
#        source_id member_id
# 18  E3SM-1-1-ECA  r1i1p1f1
#    source_id  member_id
# 5  EC-Earth3  r13i1p1f1
# 9  EC-Earth3   r9i1p1f1
# 8  EC-Earth3   r6i1p1f1
# 7  EC-Earth3  r11i1p1f1
# 6  EC-Earth3  r15i1p1f1
# 2  EC-Earth3   r1i1p1f1
#            source_id member_id
# 4  EC-Earth3-AerChem  r1i1p1f1
#       source_id member_id
# 3  EC-Earth3-CC  r1i1p1f1
#         source_id  member_id
# 10  EC-Earth3-Veg  r12i1p1f1
# 1   EC-Earth3-Veg  r14i1p1f1
#           source_id member_id
# 0  EC-Earth3-Veg-LR  r1i1p1f1
#       source_id member_id
# 39  FGOALS-f3-L  r1i1p1f1
#     source_id member_id
# 40  FGOALS-g3  r1i1p1f1
#    source_id member_id
# 27  GFDL-CM4  r1i1p1f1
#           source_id member_id
# 21  HadGEM3-GC31-LL  r1i1p1f3
# 16  HadGEM3-GC31-LL  r1i1p1f1
#       source_id member_id
# 41  ICON-ESM-LR  r1i1p1f1
#        source_id member_id
# 12  IPSL-CM6A-LR  r1i1p1f1
#             source_id member_id
# 47  IPSL-CM6A-LR-INCA  r1i1p1f1
#     source_id member_id
# 23  KIOST-ESM  r1i1p1f1
#    source_id member_id
# 26    MIROC6  r1i1p1f1
#           source_id member_id
# 29  MPI-ESM-1-2-HAM  r1i1p1f1
#         source_id member_id
# 32  MPI-ESM1-2-HR  r1i1p1f1
#         source_id member_id
# 37  MPI-ESM1-2-LR  r1i1p1f1
#      source_id member_id
# 36  MRI-ESM2-0  r1i1p1f1
#    source_id member_id
# 19     NESM3  r1i1p1f1
#    source_id member_id
# 30   NorCPM1  r1i1p1f1
#      source_id member_id
# 25  NorESM2-LM  r1i1p1f1
#      source_id member_id
# 24  NorESM2-MM  r1i1p1f1
#          source_id member_id
# 46  TaiESM1-TIMCOM  r1i1p1f1
# Empty DataFrame
# Columns: []
# Index: []

# %%
ensemble = "r1i1p1f1"

# %%
model = "GFDL-CM4" # Redefine it here because a for loop above overwrote it (the famous Jupyter notebooks state flaw)

# %%
year_start = 1870
num_years = 30

# %%
def variable_availability_check(cat, **kwargs):
    """
    List the relevant variables available and if more is needed.
    """
    searched_cat = cat.search(**kwargs)
    umo_cat = searched_cat.search(variable_id = "umo")
    vmo_cat = searched_cat.search(variable_id = "vmo")
    uo_cat = searched_cat.search(variable_id = "uo")
    vo_cat = searched_cat.search(variable_id = "vo")
    mlotstmo_cat = searched_cat.search(variable_id = "mlotst")

    print("\numo:\n")
    print(available_time_window(umo_cat))
    print("\nvmo:\n")
    print(available_time_window(vmo_cat))
    print("\nuo:\n")
    print(available_time_window(uo_cat))
    print("\nvo:\n")
    print(available_time_window(vo_cat))
    print("\nmlotst:\n")
    print(available_time_window(mlotstmo_cat))

    return


def available_time_window(cat):
    time_ranges = cat.df.time_range.unique()
    idx = np.argsort([int(foo[0:4]) for foo in time_ranges if foo != 'na'])
    # return time_ranges[idx]
    return time_ranges[idx]

# %%
model, experiment, ensemble
# Out:
# ('GFDL-CM4', 'historical', 'r1i1p1f1')

# %%
variable_availability_check(cat,
    source_id = model,
    experiment_id = experiment,
    member_id = ensemble,    
    realm = 'ocean'
)
# Out:
# umo:
#
# []
#
# vmo:
#
# []
#
# uo:
#
# ['185001-186912' '187001-188912' '189001-190912' '191001-192912'
#  '193001-194912' '195001-196912' '197001-198912' '199001-200912'
#  '201001-201412']
#
# vo:
#
# ['185001-186912' '187001-188912' '189001-190912' '191001-192912'
#  '193001-194912' '195001-196912' '197001-198912' '199001-200912'
#  '201001-201412']
#
# mlotst:
#
# []

# %%
# Check that catalog contains the data requested before creating empty directories
searched_cat = cat.search(
    source_id = model,
    experiment_id = experiment,
    member_id = ensemble,
    variable_id = ["uo", "vo", "mlotst"],
    realm = 'ocean')
np.sort(searched_cat.df.source_id.unique())
# Out:
# array([], dtype=object)

# %%
searched_searched_cat = searched_cat.search(variable_id = "uo")
searched_searched_cat.df.variable_id.unique()
# Out:
# array([], dtype=object)

# %%
np.sort([int(foo[0:4]) for foo in searched_cat.df.time_range.unique() if foo != 'na'])
# Out:
# array([], dtype=float64)

# %%
# Create directory on gdata
datadir = '/g/data/gh0/BP/TMIP/data/'
start_time, end_time = time_window_strings(year_start, num_years)
start_time_str = start_time.strftime("%b%Y")
end_time_str = end_time.strftime("%b%Y")

outputdir = f'{datadir}/{model}/{experiment}/{ensemble}/{start_time_str}-{end_time_str}'
print(outputdir)
makedirs(outputdir, exist_ok=True)
# Out:
# /g/data/gh0/BP/TMIP/data//UKESM1-0-LL/historical/r1i1p1f1/Jan1870-Dec1899

# %%
########## Start the client and make the `.nc` files ##########
print("Starting client")
client = Client(n_workers=4)#, threads_per_worker=1, memory_limit='16GB') # Note: with 1thread/worker cannot plot thetao. Maybe I need to understand why?
# Out:
# Starting client

# %%
# umo dataset
print("Loading umo data")
umo_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "umo",
    frequency = "mon",
)
print("\numo_datadask: ", umo_datadask)
# Out:
# Loading umo data
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[119], line 3
#       1 # umo dataset
#       2 print("Loading umo data")
# ----> 3 umo_datadask = select_latest_data(searched_cat,
#       4     dict(
#       5         chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
#       6     ),
#       7     variable_id = "umo",
#       8     frequency = "mon",
#       9 )
#      10 print("\numo_datadask: ", umo_datadask)
#
# Cell In[96], line 34, in select_latest_data(cat, xarray_open_kwargs, **kwargs)
#      33 def select_latest_data(cat, xarray_open_kwargs, **kwargs):
# ---> 34     latestselectedcat = select_latest_cat(cat, **kwargs)
#      35     xarray_combine_by_coords_kwargs=dict(
#      36         compat="override",
#      37         data_vars="minimal",
#      38         coords="minimal"
#      39     )
#      40     datadask = latestselectedcat.to_dask(
#      41         xarray_open_kwargs=xarray_open_kwargs,
#      42         xarray_combine_by_coords_kwargs=xarray_combine_by_coords_kwargs,
#      43         parallel=True
#      44     )
#
# Cell In[96], line 30, in select_latest_cat(cat, **kwargs)
#      26 """
#      27 search latest version of selected data
#      28 """
#      29 selectedcat = cat.search(**kwargs)
# ---> 30 latestselectedcat = selectedcat.search(version=find_latest_version(selectedcat))
#      31 return latestselectedcat
#
# Cell In[96], line 22, in find_latest_version(cat)
#      20 sorted_versions = cat.df.version.to_list()
#      21 sorted_versions.sort()
# ---> 22 latest_version = sorted_versions[-1]
#      23 return latest_version
#
# IndexError: list index out of range

# %%
# vmo dataset
print("Loading vmo data")
vmo_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "vmo",
    frequency = "mon",
)
print("\nvmo_datadask: ", vmo_datadask)

# %%
# mlotst dataset
print("Loading mlotst data")
mlotst_datadask = select_latest_data(searched_cat,
    dict(
        chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
    ),
    variable_id = "mlotst",
    frequency = "mon",
)
print("\nmlotst_datadask: ", mlotst_datadask)

# %%
# Deal with thkcello for a different script,
# given that its location (fixed or time-dependent) depends on the model and/or project
# # thkcello dataset
# print("Loading thkcello data")
# thkcello_datadask = select_latest_data(searched_cat,
#     dict(
#         chunks={'i': 60, 'j': 60, 'time': -1, 'lev':50}
#     ),
#     variable_id = "thkcello",
#     frequency = "mon",
# )
# print("\nthkcello_datadask: ", thkcello_datadask)

# %%
# Slice umo dataset for the time period
umo_datadask_sel = umo_datadask.sel(time=slice(start_time, end_time))
# Take the time average of the monthly evaporation (using month length as weights)
umo = umo_datadask_sel["umo"].weighted(umo_datadask_sel.time.dt.days_in_month).mean(dim="time")
umo

# %%
# Slice vmo dataset for the time period
vmo_datadask_sel = vmo_datadask.sel(time=slice(start_time, end_time))
# Take the time average of the monthly evaporation (using month length as weights)
vmo = vmo_datadask_sel["vmo"].weighted(vmo_datadask_sel.time.dt.days_in_month).mean(dim="time")
vmo

# %%
# Slice mlotst dataset for the time period
mlotst_datadask_sel = mlotst_datadask.sel(time=slice(start_time, end_time))
# Take the time mean of the yearly maximum of mlotst
mlotst_yearlymax = mlotst_datadask_sel.groupby("time.year").max(dim="time")
mlotst_yearlymax

# %%
mlotst = mlotst_yearlymax.mean(dim="year")
mlotst

# %%
# # Slice thkcello dataset for the time period
# thkcello_datadask_sel = thkcello_datadask.sel(time=slice(start_time, end_time))
# # Take the time average of the monthly evaporation (using month length as weights)
# thkcello = thkcello_datadask_sel["thkcello"].weighted(thkcello_datadask_sel.time.dt.days_in_month).mean(dim="time")

# %%
# Save to netcdfs (and compute!)
umo.to_netcdf(f'{outputdir}/umo.nc', compute=True)
vmo.to_netcdf(f'{outputdir}/vmo.nc', compute=True)
mlotst.to_netcdf(f'{outputdir}/mlotst.nc', compute=True)
# thkcello.to_netcdf(f'{outputdir}/thkcello.nc', compute=True)

# %%
client.close()
